# %% [markdown]
# # Set Membership Coursework

# %%
import random
import string
import timeit
from bitarray import bitarray

# %% [markdown]
# ## 1. Implementeation

# %% [markdown]
# ### Sequential Search

# %%
class SequentialSearchSet():
    
    def __init__(self):
        self.items = []           
        
    def insertElement(self, element):
        self.items.append(element)
        return True   

    def searchElement(self, element):
        found = False     
        for item1 in self.items:
            if item1 == element:
                found = True
            else:
                found = False
        return found

# %% [markdown]
# Time Complexity:
# - Insert an element is O(n^2)
# - Search an element is O(n)
#
# Space Complexity:
# - O(n)

# %% [markdown]
# ### Binary Search Tree

# %%
class Node:
    
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

    def get(self, element):
        if self.value == element:
            return True
        elif element < self.value and self.left:
            return self.left.get(element)
        elif element > self.value and self.right:
            return self.right.get(element)
        return False

    def put(self, element):
        if self.value == None:
            self.value = element
            return True
        elif element == self.value:
            self.value = element
            return True
        elif element < self.value:
            if self.left is None:
                self.left = Node(element)
                return True
            else: 
                self.left.put(element)
        elif element > self.value:
            if self.right is None:
                self.right = Node(element)
                return True
            else: 
                self.right.put(element)
        return False

class BinarySearchTreeSet:
    
    def __init__(self):
        self.bst = Node(None)

    def insertElement(self, element):
        inserted = False
        inserted = self.bst.put(element) 
        return inserted

    def searchElement(self, element):     
        found = False 
        found = self.bst.get(element)
        return found

# %% [markdown]
# ### Balanced Search Tree

# %%
# Red-Black Search Tree

class BalancedSearchTreeSet:
    R = True
    B = False
    # R refers to Red; B refers to Black
    
    class Nodes:
        def __init__(self, val, colour):
            self.val = val
            self.colour = colour
            self.left = None
            self.right = None
            
    def __init__(self):
        self.root = None
        
    def searchElement(self, element):
        return self.search(self.root, element)
    
    def search(self, node, val):
        if node is None:
            return False
        else:
            if node.val == val:
                return True
            elif node.val > val:
                return self.search(node.left, val)
            else:
                return self.search(node.right, val)
    
    def insertElement(self, element):
        self.root = self.insert(self.root, element)
        self.root.colour = self.B


    def insert(self, node, val):
        if node is None:
            return self.Nodes(val, self.R)

        if val < node.val:
            node.left = self.insert(node.left, val)
        elif val > node.val:
            node.right = self.insert(node.right, val)
        else:
            # value already exists, do nothing
            return node

        # perform rotations and colour flips
        if self.isR(node.right) and not self.isR(node.left):
            node = self.leftRotate(node)
        if self.isR(node.left) and self.isR(node.left.left):
            node = self.rightRotate(node)
        if self.isR(node.left) and self.isR(node.right):
            self.flipColour(node)

        return node

    def isR(self, node):
        if node is None:
            return False
        return node.colour == self.R
    
    def leftRotate(self, node):
        x = node.right
        node.right = x.left
        x.left = node
        x.colour = node.colour
        node.colour = self.R
        return x
    
    def rightRotate(self, node):
        x = node.left
        node.left = x.right
        x.right = node
        x.colour = node.colour
        node.colour = self.R
        return x
    
    def flipColour(self, node):
        node.colour = not node.colour
        node.left.colour = self.B
        node.right.colour = self.B

# %% [markdown]
# Time Complexity:
#
# - Insert an element is O(log n)
# - Search an element is O(log n)
#
# Space Complexity:
#
# - O(n)

# %% [markdown]
# ### Bloom Filter

# %%
class BloomFilterSet:
    
    def __init__(self):
        self.HashFunctions = None
        self.hashNum = 0
        self.size = 0
        self.bitArray = None
    
    def initVariables(self, ItemNum, FPProb, HashFunctions):
        # ItemNum : int, Number of items expected to be stored in bloom filter
        # FPProb : float, False Positive probability in decimal
        # HashFunctions: list, number of hash functions to use
        self.HashFunctions = HashFunctions
        self.hashNum = len(HashFunctions)
        # Total size of bit array
        self.size = self.getSize(ItemNum, FPProb)
        # Bit array of given size, and initialize all bits as 0 (False)
        self.bitArray = bitarray(self.size)
        self.bitArray.setall(0)

    def insertElement(self, element):
        inserted = False
        tempIndex = []
        for function in self.HashFunctions:
            index = function(element) % self.size
            self.bitArray[index] = True
            tempIndex.append(self.bitArray[index])
        if False not in tempIndex:
            inserted = True
        return inserted

    def searchElement(self, element):
        found = False
        count = 0
        for function in self.HashFunctions:
            index = function(element) % self.size
            if not self.bitArray[index] == False:
                count += 1
        if count == len(self.HashFunctions):
            found = True
        return found

    def getSize(self, n, p):
        # m = -(n * lg(p)) / (lg(2)^2)
        # n : number of items expected to be stored in filter
        # p : False Positive probability in decimal
        m = -(n * self.myLog(p)) / (self.myLog(2) ** 2)
        return int(m)
    
    def myLog(self, n):
        if n <= 0:
            raise ValueError("logarithm is undefined for non-positive values")
        if n == 1:
            return 0
        if n < 1:
            # log(xn) = -log(1/n) for n < 1
            return -self.myLog(1 / n)
        # Use the taylor series approximation for log(n) where |n-1| < 1
        taylor = (n - 1) / float(n + 1)
        term = taylor
        total = taylor
        num = 1
        while abs(term) > 1e-15:
            num += 2
            term *= taylor * taylor / float(num * (num - 1))
            total += term
        return 2 * total

# %%
def builtinHash(string):
    return hash(string)

def bernsteinHash(string):
    hashValue = 5381
    for char in string:
        hashValue = ((hashValue << 5) + hashValue) + ord(char)
    return hashValue

def fnvHash(string):
    hashValue = 2166136261
    for char in string:
        hashValue = (hashValue * 16777619) ^ ord(char)
    return hashValue

def jenkinsHash(string):
    hashValue = 0
    for char in string:
        hashValue += ord(char)
        hashValue += (hashValue << 10)
        hashValue ^= (hashValue >> 6)
    hashValue += (hashValue << 3)
    hashValue ^= (hashValue >> 11)
    hashValue += (hashValue << 15)
    return hashValue

def djb2Hash(string):
    hashValue = 5381
    for char in string:
        hashValue = ((hashValue << 5) + hashValue) + ord(char)
    return hashValue

def sdbmHash(string):
    hashValue = 0
    for char in string:
        hashValue = ord(char) + (hashValue << 6) + (hashValue << 16) - hashValue
    return hashValue

def fnv1aHash(string):
    hashValue = 2166136261
    for char in string:
        hashValue ^= ord(char)
        hashValue *= 16777619
    return hashValue

# %%
Alphabets = list(string.ascii_letters)
randomword = []
for a in range(10000):
    temp = ''.join(random.choice(Alphabets) for t in range(random.randint(100, 200)))
    randomword.append(temp)

functions = [builtinHash, bernsteinHash, fnvHash, jenkinsHash, 
             djb2Hash, sdbmHash, fnv1aHash]
bf = BloomFilterSet()
bf.initVariables(10000, 0.01, functions)
testnum = 0
for ws in randomword:
    if bf.searchElement(ws) == True:
        testnum += 1

print("The False-Positive-Rate: ", testnum / len(randomword))
# Out:
# The False-Positive-Rate:  0.0

# %% [markdown]
# Time Complexity:
# - Creating the Bloom filter is O(kn)
# - Insert and Search an element: O(k)
# - k is the number of hash functions and n is the number of elements
#
# Space Complexity:
# - O(kb), where k is the number of hash functions and b is the bits number

# %% [markdown]
# ## 2. Experimentally Evaluation

# %% [markdown]
# ### Using Real Data

# %%
def ReadFile(filepath):
    with open(filepath) as f:
        for line in f:
            words = line.strip().split()
    return words

# %%
words1 = ReadFile("./data/testfiles/test1-mobydick.txt")
words2 = ReadFile("./data/testfiles/test2-warpeace.txt")
words3 = ReadFile("./data/testfiles/test3-dickens.txt")

files = {"'test1-mobydick.txt'": words1, "'test2-warpeace.txt'": words2,
         "'test3-dickens.txt'": words3}
print(len(words1), len(words2), len(words3))
# Out:
# 209329 564236 5149661

# %%
wordsforsearch = []
with open("./data/testfiles/test-search.txt") as fsearch:
    for line in fsearch:
        wordsforsearch.append(line.strip())
        
len(wordsforsearch)
# Out:
# 544

# %%
hashFunctions = [builtinHash, bernsteinHash, fnvHash, jenkinsHash, 
                 djb2Hash, sdbmHash, fnv1aHash]

# %% [markdown]
# #### The total amount of time of all insert operations

# %%
def InsertTime(classname, datadict):
    classlist = []
    ts = []
    for key in datadict.keys():
        algorithm = classname()
        InsertStart = timeit.default_timer()
        
        for word in datadict[key]:
            t = algorithm.insertElement(word)
            ts.append(t)
        InsertEnd = timeit.default_timer()
        InsertTime = InsertEnd - InsertStart
        print("Insert time taken for", key, "is :", InsertTime)
        classlist.append(algorithm)
    return classlist, ts

# %%
# Sequential Search
SEQs, ts = InsertTime(SequentialSearchSet, files)
ts
# Out:
# Insert time taken for 'test1-mobydick.txt' is : 0.06122780000009698
# Insert time taken for 'test2-warpeace.txt' is : 0.13648160000002463
# Insert time taken for 'test3-dickens.txt' is : 1.2856124000002183
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  ...]

# %%
# Binary Search Tree
BSTs, ts = InsertTime(BinarySearchTreeSet, files)
ts
# Out:
# Insert time taken for 'test1-mobydick.txt' is : 1.0800027000000227
# Insert time taken for 'test2-warpeace.txt' is : 2.945534700000053
# Insert time taken for 'test3-dickens.txt' is : 21.58591229999979
# [True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  ...]

# %%
# Balanced Search Tree
RBTs, ts = InsertTime(BalancedSearchTreeSet, files)
ts
# Out:
# Insert time taken for 'test1-mobydick.txt' is : 2.7771121000000676
# Insert time taken for 'test2-warpeace.txt' is : 5.6984951999997975
# Insert time taken for 'test3-dickens.txt' is : 62.95919090000007
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
# Bloom Filter
BFs = []
ts = []
for key in files.keys():
    algorithm = BloomFilterSet()
    algorithm.initVariables(len(files[key]), 0.01, hashFunctions)
    
    InsertStart = timeit.default_timer()
    for word in files[key]:
        t = algorithm.insertElement(word)
        ts.append(t)
    InsertEnd = timeit.default_timer()
    InsertTime = InsertEnd - InsertStart
    print("Insert time taken for", key, "is :", InsertTime)
    BFs.append(algorithm)
ts
# Out:
# Insert time taken for 'test1-mobydick.txt' is : 2.5939674000001105
# Insert time taken for 'test2-warpeace.txt' is : 5.784217100000205
# Insert time taken for 'test3-dickens.txt' is : 53.65548170000011
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  ...]

# %% [markdown]
# #### The total amount of time of search operations

# %%
def SearchTime(objects, searchdata):
    for obj in objects:
        SearchStart = timeit.default_timer()
        for ws in searchdata:
            obj.searchElement(ws)
        SearchEnd = timeit.default_timer()
        SearchTime = SearchEnd - SearchStart
        print("Search time taken for 'test-search.txt' in file", 
              objects.index(obj)+1, "is :", SearchTime)

# %%
# Sequential Search Tree
SearchTime(SEQs, wordsforsearch)
# Out:
# Search time taken for 'test-search.txt' in file 1 is : 9.931449599999723
# Search time taken for 'test-search.txt' in file 2 is : 27.314137600000322
# Search time taken for 'test-search.txt' in file 3 is : 275.07406850000007

# %%
# Binary Search Tree
SearchTime(BSTs, wordsforsearch)
# Out:
# Search time taken for 'test-search.txt' in file 1 is : 0.007458699999915552
# Search time taken for 'test-search.txt' in file 2 is : 0.007272499999999127
# Search time taken for 'test-search.txt' in file 3 is : 0.006699300000036601

# %%
# Balanced Search Tree
SearchTime(RBTs, wordsforsearch)
# Out:
# Search time taken for 'test-search.txt' in file 1 is : 0.006438599999910366
# Search time taken for 'test-search.txt' in file 2 is : 0.006815900000219699
# Search time taken for 'test-search.txt' in file 3 is : 0.0067853999998988

# %%
# Bloom Filter
SearchTime(BFs, wordsforsearch)
# Out:
# Search time taken for 'test-search.txt' in file 1 is : 0.009318900000380381
# Search time taken for 'test-search.txt' in file 2 is : 0.009477800000240677
# Search time taken for 'test-search.txt' in file 3 is : 0.009106699999847478

# %%
# Missing Value Checker
# Delete it when it is found

def MissingValueChecking(list):
    i = 0
    lst_iter = iter(list)
    while True:
        element = next(lst_iter,"end")
        if element == "end":
            break
        if element is None:
            i += 1
            list.remove(element)
    print("The file contains %d None values" % i)
    return list

testList = [1,2,3,None,4,5,6,7,8,9,None]

MissingValueChecking(words1)
MissingValueChecking(words2)
MissingValueChecking(words3) # All 3 files given contain no None value
MissingValueChecking(testList) # initial file with 2 Nones
MissingValueChecking(testList) # return a list without None
# Out:
# The file contains 0 None values
# The file contains 0 None values
# The file contains 0 None values
# The file contains 2 None values
# The file contains 0 None values
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ### Using Synthetic Data

# %% [markdown]
# ### different conditions:
# - Duplicate cases
# - Longer String length
# - Adding numbers and symbols in each string
# - String list in ascending/descending order
# - Missing values
# - ......

# %%
class TestDataGenerator():

    def __init__(self):
        self.syntheticData = []
        self.strLen = 0
        self.percentage = 0.0

    def setParams(self, strLen, percentage):
        self.strLen = strLen
        self.percentage = percentage
    
    def generateData(self, size):
        data = []
        alphabets = list(string.ascii_letters)
        charlist = string.printable

#         # Normal Case
#         data = [''.join(random.choice(alphabets) for _ in range(random.randint(5, 10))) for _ in range(size)]

#         # Long String   
#         data1 = [''.join(random.choice(alphabets) for _ in range(self.strLen)) for _ in range(size)]

#         # Special String
#         data2 = [''.join(random.sample(charlist, random.randint(5, 10))) for _ in range(size)]

        # Normal Case
        while len(data) < size:
            temp = ''.join(random.choice(alphabets) for _ in range(random.randint(4, 10)))
            if temp not in data:
                data.append(temp)

        # Long String
        data1 = []
        while len(data1) < size:
            temp1 = ''.join(random.choice(alphabets) for _ in range(self.strLen))
            if temp1 not in data1:
                data1.append(temp1)

        # Special String
        data2 = []
        while len(data2) < size:
            temp2 = ''.join(random.sample(charlist, random.randint(4, 10)))
            if temp2 not in data2:
                data2.append(temp2)

        # Ascending Order
        data3 = self.mergeSort(data.copy())

        # String with missing values and duplicate values
        num6 = round(size * 0.2)
        temp6 = data[ : num6]
        data5 = [None if i >= num6 and random.random() < self.percentage else data[i] for i in range(size)]
        data6 = [random.choice(temp6) if i >= num6 and random.random() < self.percentage else data[i] for i in range(size)]

        # Descending Order
        data4 = data3[::-1]

        self.syntheticData.append(data)
        self.syntheticData.append(data1)
        self.syntheticData.append(data2)
        self.syntheticData.append(data3)
        self.syntheticData.append(data4)
        self.syntheticData.append(data5)
        self.syntheticData.append(data6)
        return self.syntheticData

    
    def generateData2(self, strLen, percentage):
#         data, data1, data2 = [""] * self.size, [""] * self.size, [""] * self.size
        data, data1, data2 = [], [], []
        charlist = string.printable
#         i, j, k = 0, 0, 0
        while len(data) < self.size and len(data1) < self.size and len(data2) < self.size:
            # Normal Case
            temp = ''.join(random.choice(self.alphabets) for _ in range(random.randint(5, 10)))
            if temp not in data:
                data.append(temp)
            # Long String   
            temp1 = ''.join(random.choice(self.alphabets) for _ in range(strLen))
            if temp1 not in data1:
                data1.append(temp1)
            # Special String
            temp2 = ''.join(random.choice(charlist) for _ in range(random.randint(5, 10)))
            if temp2 not in data2:
                data2.append(temp2)
        print(0,1,2)
#         for i in range(self.size):
#             # Normal Case
#             data[i] = ''.join(random.choice(self.alphabets) for _ in range(random.randint(2, 15)))
#             # Long String   
#             data1[i] = ''.join(random.choice(self.alphabets) for _ in range(strLen))
#             # Special String
#             data2[i] = ''.join(random.choice(charlist) for _ in range(random.randint(2, 15)))
            
        # Ascending Order
        data3 = self.mergeSort(data.copy())
        # Descending Order
        data4 = data3[::-1]
        print(3,4)
        data5, data6 = data.copy(), data.copy()
        # String with missing values
        num6 = round(self.size * 0.1)
        temp6 = data6[ : num6]
        for _ in range(round(percentage * self.size)):
            index = random.choice(range(num6, self.size))
            # String with missing values
            data5[index] = None
            # String with duplicate values
            data6[index] = random.choice(temp6)
        
        self.syntheticData.append(data)
        self.syntheticData.append(data1)
        self.syntheticData.append(data2)
        self.syntheticData.append(data3)
        self.syntheticData.append(data4)
        self.syntheticData.append(data5)
        self.syntheticData.append(data6)
        return self.syntheticData
    
    def mergeSort(self, arr):
        n = len(arr)
        size = 1
        while size < n:
            for i in range(0, n, 2*size):
                left = arr[i : i+size]
                right = arr[i+size : i+2*size]
                merged = []
                l = r = 0
                while l < len(left) and r < len(right):
                    if left[l] < right[r]:
                        merged.append(left[l])
                        l += 1
                    else:
                        merged.append(right[r])
                        r += 1
                merged += left[l:]
                merged += right[r:]
                arr[i : i+len(merged)] = merged
            size *= 2
        return arr

# %%
dataGenerate = TestDataGenerator()
dataGenerate.setParams(100, 0.6)
SyntheticDataList = dataGenerate.generateData(100000)
SyntheticDataList
# Out:
# [['AwJEQuI',
#   'JogMUobE',
#   'OOwHqWg',
#   'YGciQh',
#   'vLBoINjD',
#   'JYiyVmJl',
#   'CuheAkFe',
#   'RafBNveEF',
#   'owCpaPt',
#   'bJIGNdYji',
#   'QoYzAb',
#   'DfUJJJeH',
#   'ldgW',
#   'bEHdxwY',
#   'CkgQd',
#   'obOAsAGap',
#   'ZAeUHi',
#   'lQNVgaEs',
#   'JNwK',
#   'PCGtifYyo',
#   'UUId',
#   'wqttYu',
#   'nnnjdogywZ',
#   'RnfgdQaj',
#   'zPNmHP',
#   'PvCqRqDB',
#   'XMvHMBZgd',
#   'VylrLDZX',
#   'DZYXIWm',
#   'DjOS',
#   'dPYFP',
#   'wIBOYSQBZ',
#   'lhgO',
#   'qEnlkeyeii',
#   'hJUwR',
#   'EBhVCvAax',
#   'JImVwgp',
#   'VLwWdtRkTI',
#   'sSOXSaZMVz',
#   'LgurCYR',
#   'eBgmzRP',
#   'QjxRXfsan',
#   'ONTin',
#   'vPhpdT',
#   'RayWGm',
#   'YMXtkZa',
#   'PuBSAVNgg',
#   'ubdLfL',
#   'NLaqBWg',
#   'WGFpDSxw',
#   'tmxdAE',
#   'pKGfSltvGr',
#   'civnPOFett',
#   'OgztCqIact',
#   'RuRsTkawxj',
#   'DZbY',
#   'kyxqJnw',
#   'hvJG',
#   'zRZYd',
#   'yGCiG',
#   'IDsTp',
#   'twUmd',
#   'GIMH',
#   'oueqV',
#   'ZMyKKwZqt',
#   'AheGYzsPVi',
#   'mzTPp',
#   'NiWNdu',
#   'oAqUoakW',
#   'STWSjwv',
#   'sCDg',
#   'Kvmihy',
#   'FgsQUc',
#   'BXGsXww',
#   'ZXwQaO',
#   'tyTuZ',
#   'uBmqjhD',
#   'JZsrayr',
#   'kowM',
#   'AYPXu',
#   'qKnBaFDzm',
#   'klexuIoifk',
#   'PMNwUgd',
#   'vOUB',
#   'iZgOZc',
#   'uWhAvnCA',
#   'NlSmgfWsgu',
#   'YiArUDZ',
#   'glSeFfQKfk',
#   'SCreaScm',
#   'lPqsxywO',
#   'YBAjZpNgew',
#   'IlBAEhvOs',
#   'hLwY',
#   'CdSPvuC',
#   'ySMgmx',
#   'GMSkxX',
#   'yEbOKMv',
#   'gOyIoM',
#   'zNQs',
#   'yianjvZ',
#   'vstxo',
#   'sGDTwNGWOb',
#   'IAzzUdsK',
#   'EwJIRF',
#   'cBjUj',
#   'aiGXUCfGC',
#   'iMORUpsQnn',
#   'tzoZe',
#   'bQHM',
#   'kwEj',
#   'XsKcR',
#   'eOgfM',
#   'amqqxsh',
#   'tUGhhK',
#   'SJyKq',
#   'eQsaBjl',
#   'hDhgmtMaD',
#   'WPXjEfnhCa',
#   'zeBz',
#   'zwjxIlq',
#   'NxziEUExXg',
#   'UPkoBwcQ',
#   'QQmSTP',
#   'kQomSwDQ',
#   'KzjoFh',
#   'TIRmQxhJi',
#   'SVBaVweZQn',
#   'xBqnMtn',
#   'IbMdMhQqoI',
#   'uZlN',
#   'FuTsXNuymR',
#   'wByCegtvfO',
#   'cHeQx',
#   'IPzj',
#   'LmbUPu',
#   'DxaXtS',
#   'mhFhALX',
#   'qSmxjFUA',
#   'UEqk',
#   'dRmLI',
#   'ktnWCigrv',
#   'WZTiOFgMj',
#   'QrhFcftRRH',
#   'LLGVw',
#   'OuOXxK',
#   'xPfmt',
#   'vadQBcndhw',
#   'vvFojEiVq',
#   'qlwfcSyG',
#   'BOsHvQDkc',
#   'hwya',
#   'CjEBvSNW',
#   'IhcZQxd',
#   'cHQWD',
#   'rRUmogPDUE',
#   'zFzgiIvb',
#   'WVNtJHVPIl',
#   'EEGQRAnPht',
#   'wPzM',
#   'AaiQGvX',
#   'GuLojLyC',
#   'noSdrA',
#   'uXcEck',
#   'GjYC',
#   'IBZPbBLE',
#   'NQYAhcdH',
#   'ZYsPFJT',
#   'RryweddlGg',
#   'qcYrnfpq',
#   'JIJjtwpjmG',
#   'jQxFdBSB',
#   'TWQBEc',
#   'NVrbhyfz',
#   'AcPXLK',
#   'SEDmu',
#   'uidiRiW',
#   'syIzfagwW',
#   'HBla',
#   'RlMViWn',
#   'bhTV',
#   'fOalUq',
#   'GvYRuiQb',
#   'CmLoziZRY',
#   'kIgrN',
#   'hiaDihmH',
#   'xSHp',
#   'LbDgz',
#   'HnfgU',
#   'qOlWnxLIx',
#   'OkbU',
#   'QQKEdUQAWd',
#   'iNZFnM',
#   'DmYi',
#   'TJNM',
#   'smunZ',
#   'xksVur',
#   'BifnH',
#   'StYt',
#   'VAsFalrLL',
#   'cnTAGwdG',
#   'spfP',
#   'VFgz',
#   'FBedWayEsZ',
#   'caQgYFijcp',
#   'UmTlxi',
#   'CzcPFEZfx',
#   'UPGSb',
#   'oFqrRQBEr',
#   'NPTmbaeqN',
#   'twhwj',
#   'nNnA',
#   'tHdbTjCKLL',
#   'alDOUGRzf',
#   'Lgwb',
#   'XfPJDnAwP',
#   'HuHrLNnZ',
#   'tXem',
#   'bMdUv',
#   'pvfC',
#   'wMPCAH',
#   'HpCne',
#   'ZPaMpBklwT',
#   'DQsuComTR',
#   'WCbWR',
#   'OZtkEaXUZe',
#   'yIoUUn',
#   'dHATx',
#   'RJUfa',
#   'DJNYwFkCb',
#   'fqZYIbdBS',
#   'mNnZEf',
#   'fmOP',
#   'XvrTE',
#   'FhaDe',
#   'lbadUw',
#   'XdSeqwhom',
#   'YyAmv',
#   'vXmI',
#   'EnRRWD',
#   'lXGsUfuy',
#   'CyMcuueX',
#   'FJhwnKn',
#   'JojX',
#   'dwhydjTDGp',
#   'ITwb',
#   'aAcd',
#   'TSXjwBk',
#   'fctQyQKle',
#   'MXwVmu',
#   'oxJy',
#   'zHLqPKFOQ',
#   'ZuTUN',
#   'BRRctFaHjr',
#   'EyCH',
#   'JuGot',
#   'YrYtgE',
#   'Sdls',
#   'SogBpmWqMP',
#   'mXlU',
#   'oPvy',
#   'oYAQwvma',
#   'CSNJTeiT',
#   'RpUSxu',
#   'HeJgi',
#   'DaTYZR',
#   'iNEMZL',
#   'WQbEpxPt',
#   'dUIqZ',
#   'tTMqE',
#   'Gftr',
#   'wtJteLLw',
#   'fvkrH',
#   'DJZUB',
#   'IvfWnC',
#   'QigvgnDdY',
#   'GLNzuD',
#   'eSnFxRb',
#   'NTdKChuyqs',
#   'YVFznhKRF',
#   'JspRl',
#   'aUloayYQ',
#   'uQzIHF',
#   'PpUprYC',
#   'HnAPvXXfIv',
#   'lpZFYX',
#   'OIauefFF',
#   'lMOMkYwOg',
#   'zIBVUqbhqZ',
#   'xIbIKSi',
#   'LXBCQxtaDm',
#   'wsXcgLAT',
#   'syIQGL',
#   'heev',
#   'UYloqMlT',
#   'hoiiQdbU',
#   'uzpg',
#   'fzqcyG',
#   'mYSJ',
#   'zUSY',
#   'rHNrlk',
#   'ZbImyiTGE',
#   'gAmwINMT',
#   'XMtK',
#   'hGQyWXyvC',
#   'BjiKRIYFQ',
#   'HkuADbzHW',
#   'tWrs',
#   'lXfrknb',
#   'ErDeE',
#   'SiFz',
#   'PDuo',
#   'UgiST',
#   'ZFbJS',
#   'otTzpZI',
#   'UbFkTAX',
#   'sjQuWbI',
#   'bZsuuJk',
#   'AFQwQJKjD',
#   'MwDzvRJjr',
#   'kDcVlfoh',
#   'KYVUZAdN',
#   'AckaU',
#   'jVwVGRL',
#   'keOTOFEvPz',
#   'MdyOCW',
#   'WhMDPUJTx',
#   'SDKZVQNANi',
#   'KaBW',
#   'dBGhPVBkKy',
#   'jMasxcvh',
#   'oyJkCug',
#   'BEkxqY',
#   'RwgOka',
#   'xUiQENBXj',
#   'lJaymHq',
#   'klKTobto',
#   'HWyp',
#   'TGAayTmkFM',
#   'qQJTHer',
#   'fzTnPkLxjU',
#   'VcxZPKvhi',
#   'fmJZ',
#   'GuirDvxnlp',
#   'vBUE',
#   'veWW',
#   'cSAnX',
#   'zVdwp',
#   'lZKVCsiPq',
#   'qZiQj',
#   'zAjKJtH',
#   'smsodsDKu',
#   'dvRoCj',
#   'qLhvbXmps',
#   'EUNUi',
#   'SEsc',
#   'hFyg',
#   'HQdTPA',
#   'MCRHVktS',
#   'pGFhhgEiYM',
#   'IxsMX',
#   'nilnv',
#   'QqZwDa',
#   'fxLFrtoy',
#   'oIyQFemwV',
#   'gjurk',
#   'nGcNLSOhh',
#   'TGatk',
#   'PRhGYBI',
#   'KpePHvU',
#   'REpKLYX',
#   'euxhYAcN',
#   'ZNbHSWedRD',
#   'vCpr',
#   'ljOlMWPabX',
#   'nRhjuhw',
#   'TYGYDTArc',
#   'ZRiUitRHr',
#   'nNmV',
#   'fNMcHIRKCD',
#   'eSRiQThTgm',
#   'wjaLK',
#   'gyoQeCtih',
#   'oqYnCzrLbN',
#   'iiFSYqj',
#   'fDOd',
#   'LQEqlr',
#   'PIZyYbs',
#   'dJoKcFAUDZ',
#   'SWjDd',
#   'zVgT',
#   'bREMnEQq',
#   'AdEOdRUYiZ',
#   'CKwhUsgtg',
#   'tBGbAnjiO',
#   'SWxDCW',
#   'nBblG',
#   'AxYYs',
#   'RriT',
#   'bfSyJ',
#   'IZGS',
#   'glLWEEp',
#   'xQvhyZ',
#   'ayMbd',
#   'tdUqz',
#   'ZJjVAQ',
#   'uLJYtkcqwX',
#   'CAdp',
#   'UAVHBJaTw',
#   'zraTxcIZ',
#   'kQdD',
#   'ArJAhfeyzR',
#   'GSHL',
#   'OnYvHOfocQ',
#   'qWva',
#   'ABwpAojj',
#   'akQb',
#   'SjYD',
#   'NzuPyyCf',
#   'mtgfFdn',
#   'HTuxfUzM',
#   'EHVqfhRWw',
#   'yuaWHWcfGa',
#   'cXuvlw',
#   'lbnbrSL',
#   'YafSy',
#   'NDvDcEKFN',
#   'qAEQNVpQgX',
#   'QdgVbH',
#   'rJRKW',
#   'jKuA',
#   'PYnVgFWMAN',
#   'HpTqEyVMBi',
#   'RzXsJsPd',
#   'wEUtlsX',
#   'MqIZ',
#   'FVwJJlvl',
#   'yfqCUWI',
#   'WpTZjvvssv',
#   'LsJHZv',
#   'cZTVXjHfA',
#   'FJDRIcAHKv',
#   'Qeoij',
#   'mFbj',
#   'KWPmmidoi',
#   'OwEAjL',
#   'sJyBjEuN',
#   'hZbY',
#   'KnIGqF',
#   'EpIC',
#   'aCUWZRfwHW',
#   'dybYG',
#   'UBVXTDYQ',
#   'QDbRVgBVTt',
#   'ikzOIGnjAy',
#   'IsJSB',
#   'YzUWQhR',
#   'FdoU',
#   'CzxLhc',
#   'zZCJB',
#   'RcdQK',
#   'BENmhrn',
#   'TgiHna',
#   'PpmgogUgiO',
#   'WSkUHYQkEu',
#   'pTzCn',
#   'JlYvam',
#   'JEHNQAQR',
#   'zLhjS',
#   'tzKU',
#   'ujwr',
#   'MxqgQUvke',
#   'DsPyzM',
#   'KwcodnIiu',
#   'IwrXjEkP',
#   'oNillFpAwc',
#   'FkcpgIUEoT',
#   'JhEyVEg',
#   'XXDQsgT',
#   'WDZeHwz',
#   'ptArBxqo',
#   'fdYqu',
#   'bcRnK',
#   'OmOEX',
#   'bpDjlZkIqJ',
#   'vceQpf',
#   'pEKzKVbfku',
#   'bxZZa',
#   'BuyhwH',
#   'uaNWJU',
#   'YUDFPPOay',
#   'StJCj',
#   'weseMsQNlZ',
#   'nyrXTWmFR',
#   'PYXUI',
#   'onnkl',
#   'IvZxBdxy',
#   'aOYVHkI',
#   'MjaPUAXEgM',
#   'YCmXhZqA',
#   'qlqcJkrnv',
#   'AWmr',
#   'hccSk',
#   'qjbGk',
#   'Pdanisp',
#   'NnWNKPZj',
#   'eIauscZtiT',
#   'jbuRwLwuA',
#   'QTlMGxzYn',
#   'BZbDtS',
#   'zOBPhInj',
#   'KvpA',
#   'VxDk',
#   'YRHmgqgS',
#   'QQYv',
#   'ZMPq',
#   'jwSnLXLkf',
#   'vmalSenX',
#   'JSDGCm',
#   'xKMGSy',
#   'uICFglNW',
#   'QiaHd',
#   'FVVBIAhpc',
#   'tfALf',
#   'lIYxMjczbH',
#   'gYeUA',
#   'ULlXicyz',
#   'YBIFQHoWdX',
#   'ImrejATfS',
#   'rjofNTkjZ',
#   'zyPVqXIsSH',
#   'sGEDkk',
#   'vYxfnWe',
#   'BWLqJP',
#   'ZkpNHkPRS',
#   'moXybJ',
#   'AjKY',
#   'fhEWCzdFny',
#   'iqPcUac',
#   'fFKB',
#   'xSMIeqn',
#   'lucfTVJDE',
#   'oiUmNR',
#   'CnDpE',
#   'dQSmfNyfHK',
#   'htqCq',
#   'OziJDh',
#   'qGFmTS',
#   'OWQVC',
#   'dvCmeGeJ',
#   'iiKo',
#   'pGaSxldT',
#   'KxGUBSIOZ',
#   'BQszB',
#   'AUTEpjQ',
#   'DQvyXn',
#   'VWjFQwQQCb',
#   'jHHkLvqBD',
#   'hWNdMM',
#   'thFpofppw',
#   'hveVMilmW',
#   'RnEsRdk',
#   'rmFOUDJi',
#   'nTer',
#   'OMtRvrleZ',
#   'iItxa',
#   'dgqKMR',
#   'DrNwmPeIBy',
#   'zARCqit',
#   'HKOPbOXq',
#   'riyQJ',
#   'Xycd',
#   'Txrlqrwjd',
#   'GUAoadjlb',
#   'xQlh',
#   'sJHFn',
#   'vxNXqZ',
#   'kNJPJCJ',
#   'UzmEU',
#   'WEEBGEgrMB',
#   'oMXq',
#   'RqyUlEbAF',
#   'KrnpyEQ',
#   'TIdHy',
#   'ivPNU',
#   'eJPgG',
#   'YkPifMI',
#   'teGmaKpa',
#   'wkLvgoD',
#   'OCOOmEpf',
#   'CSqBWRM',
#   'ptPqfcA',
#   'zzLONBDq',
#   'ibQgFAGx',
#   'JKPiM',
#   'kDQbPkHEv',
#   'QHcFpN',
#   'QzAnF',
#   'UIIfy',
#   'xgjuArASFE',
#   'KWHFKImBYY',
#   'OtCg',
#   'KQnPw',
#   'RoGlH',
#   'ziahiPeX',
#   'VPOIyartZS',
#   'CVGjRNjt',
#   'ptBvKiv',
#   'jwTHHdfDF',
#   'JaHBXPWlTr',
#   'etMTUDjY',
#   'KRvHzCKT',
#   'XccgK',
#   'UTMSKyUG',
#   'OafRbbm',
#   'troMKIq',
#   'LxuIwNTCb',
#   'CGkrPyV',
#   'xASO',
#   'OYDv',
#   'GgedqmsPdc',
#   'tfyqilmmvi',
#   'ssMQQ',
#   'SLCvRsWqgz',
#   'LReMQFK',
#   'itfuD',
#   'hlKvmkx',
#   'PvuQzC',
#   'TrTv',
#   'mYGRshaDkp',
#   'nrJHNeeRY',
#   'GBbZiEUM',
#   'gdeqxD',
#   'iXnqxs',
#   'PefB',
#   'npaDCDr',
#   'psWSCcIp',
#   'JAgmrgGuk',
#   'ESlnxP',
#   'vZTrfy',
#   'QyzmgQrkT',
#   'ezRYXhNwke',
#   'aOYoTlHpc',
#   'MmoGs',
#   'dxcfFR',
#   'xXYiwrFhZH',
#   'UOUsNXUjg',
#   'iABRx',
#   'KXfpkKY',
#   'mwaKpeYWez',
#   'ulKAM',
#   'fuDlL',
#   'zGPAjUcXg',
#   'ZQvnJOSP',
#   'QLxg',
#   'cpiECojXUS',
#   'VGkmCj',
#   'LrROfA',
#   'qcZl',
#   'OteJI',
#   'eGHJuDqo',
#   'SPDcGN',
#   'LFUMfilv',
#   'kWjtBrz',
#   'ClTLJT',
#   'QElwImm',
#   'jqjRgJ',
#   'KJseipEwcJ',
#   'UqhP',
#   'nNwNaMZTkV',
#   'pmxCZKJqaH',
#   'vHxvbp',
#   'EucIsf',
#   'KSGf',
#   'lxlWhMB',
#   'peFP',
#   'tSWKkN',
#   'pevVeHWBlp',
#   'TcVV',
#   'dgVFW',
#   'cqMCU',
#   'wSUPCnjit',
#   'ZcUpmxp',
#   'wlJljpF',
#   'FiGS',
#   'GdHKRugs',
#   'WXzKtu',
#   'UGjsxjacB',
#   'yliz',
#   'vXcBQtlM',
#   'bTXQsUpU',
#   'ZYsU',
#   'tkmgwUh',
#   'ZRKL',
#   'gMIUeYd',
#   'dFvUuE',
#   'GvmSMowfbk',
#   'ENDT',
#   'nAsrjOOgX',
#   'HGAUFz',
#   'XpmUiH',
#   'msuTSj',
#   'zIojJk',
#   'fwZYdiBGS',
#   'EqGnDYc',
#   'adMWjyWd',
#   'DhhtDzDsf',
#   'jwxxUNET',
#   'nMFgMaWk',
#   'pjIVUS',
#   'qlwav',
#   'aYgPZHj',
#   'lDhOk',
#   'LWCoFygmt',
#   'LSuW',
#   'uHYyxRe',
#   'saLjxM',
#   'GGflEM',
#   'FRsBFCDTao',
#   'pxDZ',
#   'MjpJq',
#   'XMnWQgrzp',
#   'yxkEOfD',
#   'BSzAdeTrAe',
#   'WAoA',
#   'TfPN',
#   'NwlAIKpau',
#   'YAPkVHad',
#   'ZLWBOh',
#   'lqIHLdCGY',
#   'NHYIuN',
#   'ydTqAp',
#   'nmeWlsZi',
#   'wASxbdP',
#   'cRHWatoi',
#   'OAgbaL',
#   'WBVj',
#   'tjOVXXQS',
#   'CTxSZhTKTy',
#   'uMjmSpF',
#   'zBloNNMY',
#   'ILSD',
#   'EqLxEqs',
#   'szxyj',
#   'zXWnIjrZk',
#   'IvrsUEUA',
#   'gJCLjmEB',
#   'bgXyFxz',
#   'OksJrMugTf',
#   'spVbgeWNr',
#   'FVaEcdUEN',
#   'xrsBteEEk',
#   'sbBBndaBaW',
#   'npCs',
#   'ZNnhpv',
#   'YDIKrpn',
#   'btilsG',
#   'YoVO',
#   'pddJgN',
#   'YypiESpHk',
#   'YgbrwVrlqF',
#   'zrhTeyNizw',
#   'gyaU',
#   'gUjohr',
#   'FeHYTraB',
#   'YWGiOYeOXv',
#   'jFTgdAOvv',
#   'ZChH',
#   'ZFzuVAm',
#   'clejCml',
#   'FvvsQQ',
#   'vXjX',
#   'PzxRq',
#   'pNBmhyW',
#   'bPqZpxG',
#   'qXscoylj',
#   'LQdPafqagk',
#   'NjPov',
#   'xdsWfaTAiZ',
#   'qPUxRfPpgq',
#   'uqrbxjlO',
#   'ajBvahmb',
#   'mmNeAyO',
#   'DziL',
#   'zhDnanUVgH',
#   'YKfr',
#   'maLSFBYDeQ',
#   'KHpZuLCzu',
#   'CEGVGL',
#   'vFHnLwZtPd',
#   'WoRQgGGt',
#   'wIBrR',
#   'glsiXou',
#   'eHpcMrSWzW',
#   'yGhFf',
#   'ynarP',
#   'ItVrURu',
#   'VtoTci',
#   'RtlDwev',
#   'JJoBEpEL',
#   'ynUmgXX',
#   'zIcFyWAlxs',
#   'RGLc',
#   'YDQMK',
#   'pdSN',
#   'tFlAdVj',
#   'KuAOJvTD',
#   'DMcxzOumQ',
#   'WXHeKA',
#   'dWmI',
#   'LCUjzGM',
#   'ToIxMGxszi',
#   'dawFPX',
#   'AqlZWy',
#   'MGzJ',
#   'bXId',
#   'SkgM',
#   'tXleoT',
#   'fsAoieqTuD',
#   'NjkWi',
#   'EbtSQV',
#   'piIrTmO',
#   'DhGMie',
#   'WVILzsqA',
#   'woszWXU',
#   'fuGwJ',
#   'FnMtwtjS',
#   'qEAJoEwa',
#   'ZdIYuyOb',
#   'AcjjLx',
#   'ZcKzHU',
#   'VsCQxqMWRG',
#   'yxEhARXr',
#   'jgdtdEGUd',
#   'bVHp',
#   'YnYviHU',
#   'ZejmACn',
#   'qHAxJ',
#   'uUIktRmuH',
#   'rGDwcMRZd',
#   'ghsXWcflN',
#   'iNHjSrw',
#   'biais',
#   'acWDBE',
#   'NsJL',
#   'BYpv',
#   'SwFXRUqzL',
#   'DRLWNMw',
#   'qoQIQoS',
#   'WZzDcmg',
#   'tFzMD',
#   'LopokG',
#   'HKExuO',
#   'jkDLHbMLKj',
#   'PlGhIX',
#   'mUkeTav',
#   'wKLUYmytvg',
#   'DTwPyF',
#   'YxMitWNg',
#   'yhQPBWBZ',
#   'WBVFfRK',
#   'HSxW',
#   'MxGl',
#   'geumkaX',
#   'HXvq',
#   'iIygvWnvhn',
#   'TGWhLeRjE',
#   'JFgxzNXpH',
#   'aAgzHPd',
#   'JDUMQfvDT',
#   'bmHUYxo',
#   'tNqxMdCEH',
#   'gyeFW',
#   'MEFMPGLJlk',
#   'oTet',
#   'teLVNZ',
#   'bmUxF',
#   'CJkpK',
#   'ZmkuOecJS',
#   'FgTISNYvv',
#   'wtvmxbxPHj',
#   'PjdHwgrwZ',
#   'RHwWGBWj',
#   'DPrSL',
#   'LqhXqeY',
#   'WdlrGz',
#   'mFmPFux',
#   'qojYf',
#   'astDRvhYY',
#   'yJsGSv',
#   'OUzdFOf',
#   'msoJx',
#   'eXXBr',
#   'AXJaCw',
#   'UfQYIMIm',
#   'mibHOvsCU',
#   'KGTH',
#   'oGnlAT',
#   'eivXO',
#   'QSZrL',
#   'BqSGylUOSl',
#   'BWASvuN',
#   'oDiUyX',
#   'TOeaIKA',
#   'ciCUdM',
#   'INYe',
#   'kCwF',
#   'SSfjr',
#   'XqKBULxxD',
#   'kzPf',
#   'WBAmLizII',
#   'FQQdvQsntb',
#   'wIolLGC',
#   'uevCqZ',
#   'SfQDSF',
#   'btxuRaL',
#   'aOYrUyqehD',
#   'znJPleZsPU',
#   'SIEMsS',
#   'mLMTO',
#   'JMejvTdoW',
#   'CVHmjZ',
#   'eNmmK',
#   'EWiQ',
#   'ZJWv',
#   'qnHzytkQ',
#   'JlaEp',
#   'cNUSuOx',
#   'gEGLWApK',
#   'wUzY',
#   'slhOiHjz',
#   'wPfPwt',
#   'DGPSRMInoF',
#   'awaoLoYJ',
#   'eZJSfKlUh',
#   'lgaPszfdMI',
#   'ZHzczzl',
#   'NamxI',
#   'xAXBAM',
#   'KvGy',
#   'nuZoavl',
#   'wVPVddqz',
#   'nARqdoY',
#   'nCRFwz',
#   'fNycusbOj',
#   'JpYlrn',
#   'tvfmSljlf',
#   'wvPPuBW',
#   'VfvMf',
#   'azoXm',
#   'eUGByAvDF',
#   'XuHkTk',
#   'oEXJa',
#   'qQdlDUWMYB',
#   'wwmGYfvr',
#   'VmTvGAkT',
#   'WCJxA',
#   'wwAHlOl',
#   'nFmqKh',
#   'ISZjfs',
#   'BYJWoYXyWD',
#   'aRlSqGBz',
#   'KhnHmfwyB',
#   'LPopI',
#   'dyxjQEUUcu',
#   'GVBnOF',
#   'JtvL',
#   'FxtaTx',
#   'ThfbFXqpX',
#   'QfaDRQjMmz',
#   'LjOtqe',
#   'wBezca',
#   'GJeZ',
#   'uWDxJTQE',
#   'jElbfED',
#   'sjNGqevCE',
#   'vdOa',
#   'KRiKUDf',
#   'QbMYLqz',
#   'VIlHVZqO',
#   'JqjyjvaNu',
#   'ReJrhogcEt',
#   'lOYHz',
#   'drWQbWYdNS',
#   'oXUb',
#   'ScDCrM',
#   'yijaaRqhAh',
#   'LCeTfMN',
#   'RuTHAMv',
#   'XzDw',
#   'BIrWorstt',
#   'wRcK',
#   'HMAZIIcc',
#   'fNGlKDpz',
#   'gUlxtGy',
#   'MofXNzg',
#   'cWnMP',
#   'srwpFGdMSc',
#   'GqDC',
#   'ujJc',
#   ...],
#  ['RKepkvGoqylOgPluDgORIvTbKDcKyxSXSZzaZuARkYxUybZgAHimRDnacYNvzPEOuswwlMneulfmVmShetoXUivizxrjNMiXwtIr',
#   'aoocAZaLvuLlCdMhmSHBodZgVKmhQkpBanrjamwCHIDMTReCcQCzTVGdayMxNvdhKCCjwPbNZRQPcUdxQDToRjtaFUurgmzQpqMT',
#   'VSvxAabSQMnqAwLtknBqQItlnMbcRQzTRRuXATOvoBeBBYVXsPAqSPoQUBQqxcqCpHvzvXUOzpRkDKHWcvxLQBWJxxjdNyYFowzd',
#   'FQNUpALneFUISCAKdjSwOpKljKnAqVwOZnmQLZGurDUthENtCNvUVomPVVtsWRSJsBBXDdFZLvgbSZTfqluhPCgpfiAnRVlnJcOR',
#   'rMKenRgoOoHBZkjKDeixBFRFxRrlLzivTCHeIIUMzMAJIOQrBtXXNVqwGEmzJmTlbiEFTmoKKLgkhQIfPFqoOKImbUFpcswfWroi',
#   'omlHwKPaODZeYoKeRDtYzmzxNiIXIlGmIyVwpZjkdmMpyXnCsmOlZyFpauhJScUnOoxZcPekaAuBkzlmpYKkquJrhPwLDepKamuS',
#   'sTdvNuwajNvqEuTjVQcyuGSekGxwYLNsZqQVIqDgAAnpNuzxbLNQglZYnDbZHZvPoQCyydHdMmoYQqmTbAbEneLHPvEbajqomvHO',
#   'THcUCmwxnBldaRuzAYpcBBSsxPDJHnTXNksPOrmxGepqdvpERfjveUTZisqRZsyqyvWBrdlBnRqfcnSqOetHVnvqhvkxhduyUmPJ',
#   'CHmyxkhsifIYnEVJuJWVsQwYeXysnBxQHNXGtCiZqODatYCdNSmiwFAouylSwcGvgqMybTeZflQcGFsFmwjRzyuKiWXLyxzCAkES',
#   'WUEZIlHxVjAdgvRTDMEypbAjILczQScaMCPpDLbFBLoVdsXzthTnOuddWrJiiDcEIOQkaAjgpuktPJcSvyTOFIpdySgfjmVfsCfW',
#   'iKmyXfwiLjvIzcerSdibHkNapiKzVFvFENVPbpWXGILYEcCLcsvEuiDiXtMRlgDkntmCFOpACFQbMubzekKlFEBZkYIrzdLIRpLw',
#   'nWehIOQWEZUzSBTrGsBnVAzevUXuFamCwlXAARjjuBpakFwqYcdmzDefonBOTlzyIfPRkltcxoPcvdzRIKOyQdduPLwbYEXsVbXh',
#   'VnVZhsIQbSLWRlQGcQHgtoocDXONaJlwwHGjywbSbgdhNSqsUqvAbwVIQElNkRoEkeLnxiCKpOjrcRkSSqhotVOFMCnKxPiMQixy',
#   'sAksPDRRBIHcKrZMJzXwerEpgUWJcfhXcVvrbSvcJLWgEfURsKweGXujHFtPVKRpHECtZhxXZtQBXZCuyXVnaqWKacBgPxzwlzyT',
#   'vOtngsmbjquAXshujJZbqwQvnPACNcBCCYaUVdTVxUPhWoBMdBLNKlBSAGXPukaXegLnMeqNABWoRpczfggRSrZNilxkHYrRlLMw',
# ...
#   'gyaU',
#   'gUjohr',
#   'FeHYTraB',
#   'YWGiOYeOXv',
#   'jFTgdAOvv',
#   'ZChH',
#   'ZFzuVAm',
#   'clejCml',
#   'FvvsQQ',
#   'vXjX',
#   'PzxRq',
#   'pNBmhyW',
#   'bPqZpxG',
#   'qXscoylj',
#   'LQdPafqagk',
#   'NjPov',
#   'xdsWfaTAiZ',
#   'qPUxRfPpgq',
#   'uqrbxjlO',
#   'ajBvahmb',
#   'mmNeAyO',
#   'DziL',
#   'zhDnanUVgH',
#   'YKfr',
#   'maLSFBYDeQ',
#   'KHpZuLCzu',
#   'CEGVGL',
#   'vFHnLwZtPd',
#   'WoRQgGGt',
#   'wIBrR',
#   'glsiXou',
#   'eHpcMrSWzW',
#   'yGhFf',
#   'ynarP',
#   'ItVrURu',
#   'VtoTci',
#   'RtlDwev',
#   'JJoBEpEL',
#   'ynUmgXX',
#   'zIcFyWAlxs',
#   'RGLc',
#   'YDQMK',
#   'pdSN',
#   'tFlAdVj',
#   'KuAOJvTD',
#   'DMcxzOumQ',
#   'WXHeKA',
#   'dWmI',
#   'LCUjzGM',
#   'ToIxMGxszi',
#   'dawFPX',
#   'AqlZWy',
#   'MGzJ',
#   'bXId',
#   'SkgM',
#   'tXleoT',
#   'fsAoieqTuD',
#   'NjkWi',
#   'EbtSQV',
#   'piIrTmO',
#   'DhGMie',
#   'WVILzsqA',
#   'woszWXU',
#   'fuGwJ',
#   'FnMtwtjS',
#   'qEAJoEwa',
#   'ZdIYuyOb',
#   'AcjjLx',
#   'ZcKzHU',
#   'VsCQxqMWRG',
#   'yxEhARXr',
#   'jgdtdEGUd',
#   'bVHp',
#   'YnYviHU',
#   'ZejmACn',
#   'qHAxJ',
#   'uUIktRmuH',
#   'rGDwcMRZd',
#   'ghsXWcflN',
#   'iNHjSrw',
#   'biais',
#   'acWDBE',
#   'NsJL',
#   'BYpv',
#   'SwFXRUqzL',
#   'DRLWNMw',
#   'qoQIQoS',
#   'WZzDcmg',
#   'tFzMD',
#   'LopokG',
#   'HKExuO',
#   'jkDLHbMLKj',
#   'PlGhIX',
#   'mUkeTav',
#   'wKLUYmytvg',
#   'DTwPyF',
#   'YxMitWNg',
#   'yhQPBWBZ',
#   'WBVFfRK',
#   'HSxW',
#   'MxGl',
#   'geumkaX',
#   'HXvq',
#   'iIygvWnvhn',
#   'TGWhLeRjE',
#   'JFgxzNXpH',
#   'aAgzHPd',
#   'JDUMQfvDT',
#   'bmHUYxo',
#   'tNqxMdCEH',
#   'gyeFW',
#   'MEFMPGLJlk',
#   'oTet',
#   'teLVNZ',
#   'bmUxF',
#   'CJkpK',
#   'ZmkuOecJS',
#   'FgTISNYvv',
#   'wtvmxbxPHj',
#   'PjdHwgrwZ',
#   'RHwWGBWj',
#   'DPrSL',
#   'LqhXqeY',
#   'WdlrGz',
#   'mFmPFux',
#   'qojYf',
#   'astDRvhYY',
#   'yJsGSv',
#   'OUzdFOf',
#   'msoJx',
#   'eXXBr',
#   'AXJaCw',
#   'UfQYIMIm',
#   'mibHOvsCU',
#   'KGTH',
#   'oGnlAT',
#   'eivXO',
#   'QSZrL',
#   'BqSGylUOSl',
#   'BWASvuN',
#   'oDiUyX',
#   'TOeaIKA',
#   'ciCUdM',
#   'INYe',
#   'kCwF',
#   'SSfjr',
#   'XqKBULxxD',
#   'kzPf',
#   'WBAmLizII',
#   'FQQdvQsntb',
#   'wIolLGC',
#   'uevCqZ',
#   'SfQDSF',
#   'btxuRaL',
#   'aOYrUyqehD',
#   'znJPleZsPU',
#   'SIEMsS',
#   'mLMTO',
#   'JMejvTdoW',
#   'CVHmjZ',
#   'eNmmK',
#   'EWiQ',
#   'ZJWv',
#   'qnHzytkQ',
#   'JlaEp',
#   'cNUSuOx',
#   'gEGLWApK',
#   'wUzY',
#   'slhOiHjz',
#   'wPfPwt',
#   'DGPSRMInoF',
#   'awaoLoYJ',
#   'eZJSfKlUh',
#   'lgaPszfdMI',
#   'ZHzczzl',
#   'NamxI',
#   'xAXBAM',
#   'KvGy',
#   'nuZoavl',
#   'wVPVddqz',
#   'nARqdoY',
#   'nCRFwz',
#   'fNycusbOj',
#   'JpYlrn',
#   'tvfmSljlf',
#   'wvPPuBW',
#   'VfvMf',
#   'azoXm',
#   'eUGByAvDF',
#   'XuHkTk',
#   'oEXJa',
#   'qQdlDUWMYB',
#   'wwmGYfvr',
#   'VmTvGAkT',
#   'WCJxA',
#   'wwAHlOl',
#   'nFmqKh',
#   'ISZjfs',
#   'BYJWoYXyWD',
#   'aRlSqGBz',
#   'KhnHmfwyB',
#   'LPopI',
#   'dyxjQEUUcu',
#   'GVBnOF',
#   'JtvL',
#   'FxtaTx',
#   'ThfbFXqpX',
#   'QfaDRQjMmz',
#   'LjOtqe',
#   'wBezca',
#   'GJeZ',
#   'uWDxJTQE',
#   'jElbfED',
#   'sjNGqevCE',
#   'vdOa',
#   'KRiKUDf',
#   'QbMYLqz',
#   'VIlHVZqO',
#   'JqjyjvaNu',
#   'ReJrhogcEt',
#   'lOYHz',
#   'drWQbWYdNS',
#   'oXUb',
#   'ScDCrM',
#   'yijaaRqhAh',
#   'LCeTfMN',
#   'RuTHAMv',
#   'XzDw',
#   'BIrWorstt',
#   'wRcK',
#   'HMAZIIcc',
#   'fNGlKDpz',
#   'gUlxtGy',
#   'MofXNzg',
#   'cWnMP',
#   'srwpFGdMSc',
#   'GqDC',
#   'ujJc',
#   ...],
#  ['AwJEQuI',
#   'JogMUobE',
#   'OOwHqWg',
#   'YGciQh',
#   'vLBoINjD',
#   'JYiyVmJl',
#   'CuheAkFe',
#   'RafBNveEF',
#   'owCpaPt',
#   'bJIGNdYji',
#   'QoYzAb',
#   'DfUJJJeH',
#   'ldgW',
#   'bEHdxwY',
#   'CkgQd',
#   'obOAsAGap',
#   'ZAeUHi',
#   'lQNVgaEs',
#   'JNwK',
#   'PCGtifYyo',
#   'UUId',
#   'wqttYu',
#   'nnnjdogywZ',
#   'RnfgdQaj',
#   'zPNmHP',
#   'PvCqRqDB',
#   'XMvHMBZgd',
#   'VylrLDZX',
#   'DZYXIWm',
#   'DjOS',
#   'dPYFP',
#   'wIBOYSQBZ',
#   'lhgO',
#   'qEnlkeyeii',
#   'hJUwR',
#   'EBhVCvAax',
#   'JImVwgp',
#   'VLwWdtRkTI',
#   'sSOXSaZMVz',
#   'LgurCYR',
#   'eBgmzRP',
#   'QjxRXfsan',
#   'ONTin',
#   'vPhpdT',
#   'RayWGm',
#   'YMXtkZa',
#   'PuBSAVNgg',
#   'ubdLfL',
#   'NLaqBWg',
#   'WGFpDSxw',
#   'tmxdAE',
#   'pKGfSltvGr',
#   'civnPOFett',
#   'OgztCqIact',
#   'RuRsTkawxj',
#   'DZbY',
#   'kyxqJnw',
#   'hvJG',
#   'zRZYd',
#   'yGCiG',
#   'IDsTp',
#   'twUmd',
#   'GIMH',
#   'oueqV',
#   'ZMyKKwZqt',
#   'AheGYzsPVi',
#   'mzTPp',
#   'NiWNdu',
#   'oAqUoakW',
#   'STWSjwv',
#   'sCDg',
#   'Kvmihy',
#   'FgsQUc',
#   'BXGsXww',
#   'ZXwQaO',
#   'tyTuZ',
#   'uBmqjhD',
#   'JZsrayr',
#   'kowM',
#   'AYPXu',
#   'qKnBaFDzm',
#   'klexuIoifk',
#   'PMNwUgd',
#   'vOUB',
#   'iZgOZc',
#   'uWhAvnCA',
#   'NlSmgfWsgu',
#   'YiArUDZ',
#   'glSeFfQKfk',
#   'SCreaScm',
#   'lPqsxywO',
#   'YBAjZpNgew',
#   'IlBAEhvOs',
#   'hLwY',
#   'CdSPvuC',
#   'ySMgmx',
#   'GMSkxX',
#   'yEbOKMv',
#   'gOyIoM',
#   'zNQs',
#   'yianjvZ',
#   'vstxo',
#   'sGDTwNGWOb',
#   'IAzzUdsK',
#   'EwJIRF',
#   'cBjUj',
#   'aiGXUCfGC',
#   'iMORUpsQnn',
#   'tzoZe',
#   'bQHM',
#   'kwEj',
#   'XsKcR',
#   'eOgfM',
#   'amqqxsh',
#   'tUGhhK',
#   'SJyKq',
#   'eQsaBjl',
#   'hDhgmtMaD',
#   'WPXjEfnhCa',
#   'zeBz',
#   'zwjxIlq',
#   'NxziEUExXg',
#   'UPkoBwcQ',
#   'QQmSTP',
#   'kQomSwDQ',
#   'KzjoFh',
#   'TIRmQxhJi',
#   'SVBaVweZQn',
#   'xBqnMtn',
#   'IbMdMhQqoI',
#   'uZlN',
#   'FuTsXNuymR',
#   'wByCegtvfO',
#   'cHeQx',
#   'IPzj',
#   'LmbUPu',
#   'DxaXtS',
#   'mhFhALX',
#   'qSmxjFUA',
#   'UEqk',
#   'dRmLI',
#   'ktnWCigrv',
#   'WZTiOFgMj',
#   'QrhFcftRRH',
#   'LLGVw',
#   'OuOXxK',
#   'xPfmt',
#   'vadQBcndhw',
#   'vvFojEiVq',
#   'qlwfcSyG',
#   'BOsHvQDkc',
#   'hwya',
#   'CjEBvSNW',
#   'IhcZQxd',
#   'cHQWD',
#   'rRUmogPDUE',
#   'zFzgiIvb',
#   'WVNtJHVPIl',
#   'EEGQRAnPht',
#   'wPzM',
#   'AaiQGvX',
#   'GuLojLyC',
#   'noSdrA',
#   'uXcEck',
#   'GjYC',
#   'IBZPbBLE',
#   'NQYAhcdH',
#   'ZYsPFJT',
#   'RryweddlGg',
#   'qcYrnfpq',
#   'JIJjtwpjmG',
#   'jQxFdBSB',
#   'TWQBEc',
#   'NVrbhyfz',
#   'AcPXLK',
#   'SEDmu',
#   'uidiRiW',
#   'syIzfagwW',
#   'HBla',
#   'RlMViWn',
#   'bhTV',
#   'fOalUq',
#   'GvYRuiQb',
#   'CmLoziZRY',
#   'kIgrN',
#   'hiaDihmH',
#   'xSHp',
#   'LbDgz',
#   'HnfgU',
#   'qOlWnxLIx',
#   'OkbU',
#   'QQKEdUQAWd',
#   'iNZFnM',
#   'DmYi',
#   'TJNM',
#   'smunZ',
#   'xksVur',
#   'BifnH',
#   'StYt',
#   'VAsFalrLL',
#   'cnTAGwdG',
#   'spfP',
#   'VFgz',
#   'FBedWayEsZ',
#   'caQgYFijcp',
#   'UmTlxi',
#   'CzcPFEZfx',
#   'UPGSb',
#   'oFqrRQBEr',
#   'NPTmbaeqN',
#   'twhwj',
#   'nNnA',
#   'tHdbTjCKLL',
#   'alDOUGRzf',
#   'Lgwb',
#   'XfPJDnAwP',
#   'HuHrLNnZ',
#   'tXem',
#   'bMdUv',
#   'pvfC',
#   'wMPCAH',
#   'HpCne',
#   'ZPaMpBklwT',
#   'DQsuComTR',
#   'WCbWR',
#   'OZtkEaXUZe',
#   'yIoUUn',
#   'dHATx',
#   'RJUfa',
#   'DJNYwFkCb',
#   'fqZYIbdBS',
#   'mNnZEf',
#   'fmOP',
#   'XvrTE',
#   'FhaDe',
#   'lbadUw',
#   'XdSeqwhom',
#   'YyAmv',
#   'vXmI',
#   'EnRRWD',
#   'lXGsUfuy',
#   'CyMcuueX',
#   'FJhwnKn',
#   'JojX',
#   'dwhydjTDGp',
#   'ITwb',
#   'aAcd',
#   'TSXjwBk',
#   'fctQyQKle',
#   'MXwVmu',
#   'oxJy',
#   'zHLqPKFOQ',
#   'ZuTUN',
#   'BRRctFaHjr',
#   'EyCH',
#   'JuGot',
#   'YrYtgE',
#   'Sdls',
#   'SogBpmWqMP',
#   'mXlU',
#   'oPvy',
#   'oYAQwvma',
#   'CSNJTeiT',
#   'RpUSxu',
#   'HeJgi',
#   'DaTYZR',
#   'iNEMZL',
#   'WQbEpxPt',
#   'dUIqZ',
#   'tTMqE',
#   'Gftr',
#   'wtJteLLw',
#   'fvkrH',
#   'DJZUB',
#   'IvfWnC',
#   'QigvgnDdY',
#   'GLNzuD',
#   'eSnFxRb',
#   'NTdKChuyqs',
#   'YVFznhKRF',
#   'JspRl',
#   'aUloayYQ',
#   'uQzIHF',
#   'PpUprYC',
#   'HnAPvXXfIv',
#   'lpZFYX',
#   'OIauefFF',
#   'lMOMkYwOg',
#   'zIBVUqbhqZ',
#   'xIbIKSi',
#   'LXBCQxtaDm',
#   'wsXcgLAT',
#   'syIQGL',
#   'heev',
#   'UYloqMlT',
#   'hoiiQdbU',
#   'uzpg',
#   'fzqcyG',
#   'mYSJ',
#   'zUSY',
#   'rHNrlk',
#   'ZbImyiTGE',
#   'gAmwINMT',
#   'XMtK',
#   'hGQyWXyvC',
#   'BjiKRIYFQ',
#   'HkuADbzHW',
#   'tWrs',
#   'lXfrknb',
#   'ErDeE',
#   'SiFz',
#   'PDuo',
#   'UgiST',
#   'ZFbJS',
#   'otTzpZI',
#   'UbFkTAX',
#   'sjQuWbI',
#   'bZsuuJk',
#   'AFQwQJKjD',
#   'MwDzvRJjr',
#   'kDcVlfoh',
#   'KYVUZAdN',
#   'AckaU',
#   'jVwVGRL',
#   'keOTOFEvPz',
#   'MdyOCW',
#   'WhMDPUJTx',
#   'SDKZVQNANi',
#   'KaBW',
#   'dBGhPVBkKy',
#   'jMasxcvh',
#   'oyJkCug',
#   'BEkxqY',
#   'RwgOka',
#   'xUiQENBXj',
#   'lJaymHq',
#   'klKTobto',
#   'HWyp',
#   'TGAayTmkFM',
#   'qQJTHer',
#   'fzTnPkLxjU',
#   'VcxZPKvhi',
#   'fmJZ',
#   'GuirDvxnlp',
#   'vBUE',
#   'veWW',
#   'cSAnX',
#   'zVdwp',
#   'lZKVCsiPq',
#   'qZiQj',
#   'zAjKJtH',
#   'smsodsDKu',
#   'dvRoCj',
#   'qLhvbXmps',
#   'EUNUi',
#   'SEsc',
#   'hFyg',
#   'HQdTPA',
#   'MCRHVktS',
#   'pGFhhgEiYM',
#   'IxsMX',
#   'nilnv',
#   'QqZwDa',
#   'fxLFrtoy',
#   'oIyQFemwV',
#   'gjurk',
#   'nGcNLSOhh',
#   'TGatk',
#   'PRhGYBI',
#   'KpePHvU',
#   'REpKLYX',
#   'euxhYAcN',
#   'ZNbHSWedRD',
#   'vCpr',
#   'ljOlMWPabX',
#   'nRhjuhw',
#   'TYGYDTArc',
#   'ZRiUitRHr',
#   'nNmV',
#   'fNMcHIRKCD',
#   'eSRiQThTgm',
#   'wjaLK',
#   'gyoQeCtih',
#   'oqYnCzrLbN',
#   'iiFSYqj',
#   'fDOd',
#   'LQEqlr',
#   'PIZyYbs',
#   'dJoKcFAUDZ',
#   'SWjDd',
#   'zVgT',
#   'bREMnEQq',
#   'AdEOdRUYiZ',
#   'CKwhUsgtg',
#   'tBGbAnjiO',
#   'SWxDCW',
#   'nBblG',
#   'AxYYs',
#   'RriT',
#   'bfSyJ',
#   'IZGS',
#   'glLWEEp',
#   'xQvhyZ',
#   'ayMbd',
#   'tdUqz',
#   'ZJjVAQ',
#   'uLJYtkcqwX',
#   'CAdp',
#   'UAVHBJaTw',
#   'zraTxcIZ',
#   'kQdD',
#   'ArJAhfeyzR',
#   'GSHL',
#   'OnYvHOfocQ',
#   'qWva',
#   'ABwpAojj',
#   'akQb',
#   'SjYD',
#   'NzuPyyCf',
#   'mtgfFdn',
#   'HTuxfUzM',
#   'EHVqfhRWw',
#   'yuaWHWcfGa',
#   'cXuvlw',
#   'lbnbrSL',
#   'YafSy',
#   'NDvDcEKFN',
#   'qAEQNVpQgX',
#   'QdgVbH',
#   'rJRKW',
#   'jKuA',
#   'PYnVgFWMAN',
#   'HpTqEyVMBi',
#   'RzXsJsPd',
#   'wEUtlsX',
#   'MqIZ',
#   'FVwJJlvl',
#   'yfqCUWI',
#   'WpTZjvvssv',
#   'LsJHZv',
#   'cZTVXjHfA',
#   'FJDRIcAHKv',
#   'Qeoij',
#   'mFbj',
#   'KWPmmidoi',
#   'OwEAjL',
#   'sJyBjEuN',
#   'hZbY',
#   'KnIGqF',
#   'EpIC',
#   'aCUWZRfwHW',
#   'dybYG',
#   'UBVXTDYQ',
#   'QDbRVgBVTt',
#   'ikzOIGnjAy',
#   'IsJSB',
#   'YzUWQhR',
#   'FdoU',
#   'CzxLhc',
#   'zZCJB',
#   'RcdQK',
#   'BENmhrn',
#   'TgiHna',
#   'PpmgogUgiO',
#   'WSkUHYQkEu',
#   'pTzCn',
#   'JlYvam',
#   'JEHNQAQR',
#   'zLhjS',
#   'tzKU',
#   'ujwr',
#   'MxqgQUvke',
#   'DsPyzM',
#   'KwcodnIiu',
#   'IwrXjEkP',
#   'oNillFpAwc',
#   'FkcpgIUEoT',
#   'JhEyVEg',
#   'XXDQsgT',
#   'WDZeHwz',
#   'ptArBxqo',
#   'fdYqu',
#   'bcRnK',
#   'OmOEX',
#   'bpDjlZkIqJ',
#   'vceQpf',
#   'pEKzKVbfku',
#   'bxZZa',
#   'BuyhwH',
#   'uaNWJU',
#   'YUDFPPOay',
#   'StJCj',
#   'weseMsQNlZ',
#   'nyrXTWmFR',
#   'PYXUI',
#   'onnkl',
#   'IvZxBdxy',
#   'aOYVHkI',
#   'MjaPUAXEgM',
#   'YCmXhZqA',
#   'qlqcJkrnv',
#   'AWmr',
#   'hccSk',
#   'qjbGk',
#   'Pdanisp',
#   'NnWNKPZj',
#   'eIauscZtiT',
#   'jbuRwLwuA',
#   'QTlMGxzYn',
#   'BZbDtS',
#   'zOBPhInj',
#   'KvpA',
#   'VxDk',
#   'YRHmgqgS',
#   'QQYv',
#   'ZMPq',
#   'jwSnLXLkf',
#   'vmalSenX',
#   'JSDGCm',
#   'xKMGSy',
#   'uICFglNW',
#   'QiaHd',
#   'FVVBIAhpc',
#   'tfALf',
#   'lIYxMjczbH',
#   'gYeUA',
#   'ULlXicyz',
#   'YBIFQHoWdX',
#   'ImrejATfS',
#   'rjofNTkjZ',
#   'zyPVqXIsSH',
#   'sGEDkk',
#   'vYxfnWe',
#   'BWLqJP',
#   'ZkpNHkPRS',
#   'moXybJ',
#   'AjKY',
#   'fhEWCzdFny',
#   'iqPcUac',
#   'fFKB',
#   'xSMIeqn',
#   'lucfTVJDE',
#   'oiUmNR',
#   'CnDpE',
#   'dQSmfNyfHK',
#   'htqCq',
#   'OziJDh',
#   'qGFmTS',
#   'OWQVC',
#   'dvCmeGeJ',
#   'iiKo',
#   'pGaSxldT',
#   'KxGUBSIOZ',
#   'BQszB',
#   'AUTEpjQ',
#   'DQvyXn',
#   'VWjFQwQQCb',
#   'jHHkLvqBD',
#   'hWNdMM',
#   'thFpofppw',
#   'hveVMilmW',
#   'RnEsRdk',
#   'rmFOUDJi',
#   'nTer',
#   'OMtRvrleZ',
#   'iItxa',
#   'dgqKMR',
#   'DrNwmPeIBy',
#   'zARCqit',
#   'HKOPbOXq',
#   'riyQJ',
#   'Xycd',
#   'Txrlqrwjd',
#   'GUAoadjlb',
#   'xQlh',
#   'sJHFn',
#   'vxNXqZ',
#   'kNJPJCJ',
#   'UzmEU',
#   'WEEBGEgrMB',
#   'oMXq',
#   'RqyUlEbAF',
#   'KrnpyEQ',
#   'TIdHy',
#   'ivPNU',
#   'eJPgG',
#   'YkPifMI',
#   'teGmaKpa',
#   'wkLvgoD',
#   'OCOOmEpf',
#   'CSqBWRM',
#   'ptPqfcA',
#   'zzLONBDq',
#   'ibQgFAGx',
#   'JKPiM',
#   'kDQbPkHEv',
#   'QHcFpN',
#   'QzAnF',
#   'UIIfy',
#   'xgjuArASFE',
#   'KWHFKImBYY',
#   'OtCg',
#   'KQnPw',
#   'RoGlH',
#   'ziahiPeX',
#   'VPOIyartZS',
#   'CVGjRNjt',
#   'ptBvKiv',
#   'jwTHHdfDF',
#   'JaHBXPWlTr',
#   'etMTUDjY',
#   'KRvHzCKT',
#   'XccgK',
#   'UTMSKyUG',
#   'OafRbbm',
#   'troMKIq',
#   'LxuIwNTCb',
#   'CGkrPyV',
#   'xASO',
#   'OYDv',
#   'GgedqmsPdc',
#   'tfyqilmmvi',
#   'ssMQQ',
#   'SLCvRsWqgz',
#   'LReMQFK',
#   'itfuD',
#   'hlKvmkx',
#   'PvuQzC',
#   'TrTv',
#   'mYGRshaDkp',
#   'nrJHNeeRY',
#   'GBbZiEUM',
#   'gdeqxD',
#   'iXnqxs',
#   'PefB',
#   'npaDCDr',
#   'psWSCcIp',
#   'JAgmrgGuk',
#   'ESlnxP',
#   'vZTrfy',
#   'QyzmgQrkT',
#   'ezRYXhNwke',
#   'aOYoTlHpc',
#   'MmoGs',
#   'dxcfFR',
#   'xXYiwrFhZH',
#   'UOUsNXUjg',
#   'iABRx',
#   'KXfpkKY',
#   'mwaKpeYWez',
#   'ulKAM',
#   'fuDlL',
#   'zGPAjUcXg',
#   'ZQvnJOSP',
#   'QLxg',
#   'cpiECojXUS',
#   'VGkmCj',
#   'LrROfA',
#   'qcZl',
#   'OteJI',
#   'eGHJuDqo',
#   'SPDcGN',
#   'LFUMfilv',
#   'kWjtBrz',
#   'ClTLJT',
#   'QElwImm',
#   'jqjRgJ',
#   'KJseipEwcJ',
#   'UqhP',
#   'nNwNaMZTkV',
#   'pmxCZKJqaH',
#   'vHxvbp',
#   'EucIsf',
#   'KSGf',
#   'lxlWhMB',
#   'peFP',
#   'tSWKkN',
#   'pevVeHWBlp',
#   'TcVV',
#   'dgVFW',
#   'cqMCU',
#   'wSUPCnjit',
#   'ZcUpmxp',
#   'wlJljpF',
#   'FiGS',
#   'GdHKRugs',
#   'WXzKtu',
#   'UGjsxjacB',
#   'yliz',
#   'vXcBQtlM',
#   'bTXQsUpU',
#   'ZYsU',
#   'tkmgwUh',
#   'ZRKL',
#   'gMIUeYd',
#   'dFvUuE',
#   'GvmSMowfbk',
#   'ENDT',
#   'nAsrjOOgX',
#   'HGAUFz',
#   'XpmUiH',
#   'msuTSj',
#   'zIojJk',
#   'fwZYdiBGS',
#   'EqGnDYc',
#   'adMWjyWd',
#   'DhhtDzDsf',
#   'jwxxUNET',
#   'nMFgMaWk',
#   'pjIVUS',
#   'qlwav',
#   'aYgPZHj',
#   'lDhOk',
#   'LWCoFygmt',
#   'LSuW',
#   'uHYyxRe',
#   'saLjxM',
#   'GGflEM',
#   'FRsBFCDTao',
#   'pxDZ',
#   'MjpJq',
#   'XMnWQgrzp',
#   'yxkEOfD',
#   'BSzAdeTrAe',
#   'WAoA',
#   'TfPN',
#   'NwlAIKpau',
#   'YAPkVHad',
#   'ZLWBOh',
#   'lqIHLdCGY',
#   'NHYIuN',
#   'ydTqAp',
#   'nmeWlsZi',
#   'wASxbdP',
#   'cRHWatoi',
#   'OAgbaL',
#   'WBVj',
#   'tjOVXXQS',
#   'CTxSZhTKTy',
#   'uMjmSpF',
#   'zBloNNMY',
#   'ILSD',
#   'EqLxEqs',
#   'szxyj',
#   'zXWnIjrZk',
#   'IvrsUEUA',
#   'gJCLjmEB',
#   'bgXyFxz',
#   'OksJrMugTf',
#   'spVbgeWNr',
#   'FVaEcdUEN',
#   'xrsBteEEk',
#   'sbBBndaBaW',
#   'npCs',
#   'ZNnhpv',
#   'YDIKrpn',
#   'btilsG',
#   'YoVO',
#   'pddJgN',
#   'YypiESpHk',
#   'YgbrwVrlqF',
#   'zrhTeyNizw',
#   'gyaU',
#   'gUjohr',
#   'FeHYTraB',
#   'YWGiOYeOXv',
#   'jFTgdAOvv',
#   'ZChH',
#   'ZFzuVAm',
#   'clejCml',
#   'FvvsQQ',
#   'vXjX',
#   'PzxRq',
#   'pNBmhyW',
#   'bPqZpxG',
#   'qXscoylj',
#   'LQdPafqagk',
#   'NjPov',
#   'xdsWfaTAiZ',
#   'qPUxRfPpgq',
#   'uqrbxjlO',
#   'ajBvahmb',
#   'mmNeAyO',
#   'DziL',
#   'zhDnanUVgH',
#   'YKfr',
#   'maLSFBYDeQ',
#   'KHpZuLCzu',
#   'CEGVGL',
#   'vFHnLwZtPd',
#   'WoRQgGGt',
#   'wIBrR',
#   'glsiXou',
#   'eHpcMrSWzW',
#   'yGhFf',
#   'ynarP',
#   'ItVrURu',
#   'VtoTci',
#   'RtlDwev',
#   'JJoBEpEL',
#   'ynUmgXX',
#   'zIcFyWAlxs',
#   'RGLc',
#   'YDQMK',
#   'pdSN',
#   'tFlAdVj',
#   'KuAOJvTD',
#   'DMcxzOumQ',
#   'WXHeKA',
#   'dWmI',
#   'LCUjzGM',
#   'ToIxMGxszi',
#   'dawFPX',
#   'AqlZWy',
#   'MGzJ',
#   'bXId',
#   'SkgM',
#   'tXleoT',
#   'fsAoieqTuD',
#   'NjkWi',
#   'EbtSQV',
#   'piIrTmO',
#   'DhGMie',
#   'WVILzsqA',
#   'woszWXU',
#   'fuGwJ',
#   'FnMtwtjS',
#   'qEAJoEwa',
#   'ZdIYuyOb',
#   'AcjjLx',
#   'ZcKzHU',
#   'VsCQxqMWRG',
#   'yxEhARXr',
#   'jgdtdEGUd',
#   'bVHp',
#   'YnYviHU',
#   'ZejmACn',
#   'qHAxJ',
#   'uUIktRmuH',
#   'rGDwcMRZd',
#   'ghsXWcflN',
#   'iNHjSrw',
#   'biais',
#   'acWDBE',
#   'NsJL',
#   'BYpv',
#   'SwFXRUqzL',
#   'DRLWNMw',
#   'qoQIQoS',
#   'WZzDcmg',
#   'tFzMD',
#   'LopokG',
#   'HKExuO',
#   'jkDLHbMLKj',
#   'PlGhIX',
#   'mUkeTav',
#   'wKLUYmytvg',
#   'DTwPyF',
#   'YxMitWNg',
#   'yhQPBWBZ',
#   'WBVFfRK',
#   'HSxW',
#   'MxGl',
#   'geumkaX',
#   'HXvq',
#   'iIygvWnvhn',
#   'TGWhLeRjE',
#   'JFgxzNXpH',
#   'aAgzHPd',
#   'JDUMQfvDT',
#   'bmHUYxo',
#   'tNqxMdCEH',
#   'gyeFW',
#   'MEFMPGLJlk',
#   'oTet',
#   'teLVNZ',
#   'bmUxF',
#   'CJkpK',
#   'ZmkuOecJS',
#   'FgTISNYvv',
#   'wtvmxbxPHj',
#   'PjdHwgrwZ',
#   'RHwWGBWj',
#   'DPrSL',
#   'LqhXqeY',
#   'WdlrGz',
#   'mFmPFux',
#   'qojYf',
#   'astDRvhYY',
#   'yJsGSv',
#   'OUzdFOf',
#   'msoJx',
#   'eXXBr',
#   'AXJaCw',
#   'UfQYIMIm',
#   'mibHOvsCU',
#   'KGTH',
#   'oGnlAT',
#   'eivXO',
#   'QSZrL',
#   'BqSGylUOSl',
#   'BWASvuN',
#   'oDiUyX',
#   'TOeaIKA',
#   'ciCUdM',
#   'INYe',
#   'kCwF',
#   'SSfjr',
#   'XqKBULxxD',
#   'kzPf',
#   'WBAmLizII',
#   'FQQdvQsntb',
#   'wIolLGC',
#   'uevCqZ',
#   'SfQDSF',
#   'btxuRaL',
#   'aOYrUyqehD',
#   'znJPleZsPU',
#   'SIEMsS',
#   'mLMTO',
#   'JMejvTdoW',
#   'CVHmjZ',
#   'eNmmK',
#   'EWiQ',
#   'ZJWv',
#   'qnHzytkQ',
#   'JlaEp',
#   'cNUSuOx',
#   'gEGLWApK',
#   'wUzY',
#   'slhOiHjz',
#   'wPfPwt',
#   'DGPSRMInoF',
#   'awaoLoYJ',
#   'eZJSfKlUh',
#   'lgaPszfdMI',
#   'ZHzczzl',
#   'NamxI',
#   'xAXBAM',
#   'KvGy',
#   'nuZoavl',
#   'wVPVddqz',
#   'nARqdoY',
#   'nCRFwz',
#   'fNycusbOj',
#   'JpYlrn',
#   'tvfmSljlf',
#   'wvPPuBW',
#   'VfvMf',
#   'azoXm',
#   'eUGByAvDF',
#   'XuHkTk',
#   'oEXJa',
#   'qQdlDUWMYB',
#   'wwmGYfvr',
#   'VmTvGAkT',
#   'WCJxA',
#   'wwAHlOl',
#   'nFmqKh',
#   'ISZjfs',
#   'BYJWoYXyWD',
#   'aRlSqGBz',
#   'KhnHmfwyB',
#   'LPopI',
#   'dyxjQEUUcu',
#   'GVBnOF',
#   'JtvL',
#   'FxtaTx',
#   'ThfbFXqpX',
#   'QfaDRQjMmz',
#   'LjOtqe',
#   'wBezca',
#   'GJeZ',
#   'uWDxJTQE',
#   'jElbfED',
#   'sjNGqevCE',
#   'vdOa',
#   'KRiKUDf',
#   'QbMYLqz',
#   'VIlHVZqO',
#   'JqjyjvaNu',
#   'ReJrhogcEt',
#   'lOYHz',
#   'drWQbWYdNS',
#   'oXUb',
#   'ScDCrM',
#   'yijaaRqhAh',
#   'LCeTfMN',
#   'RuTHAMv',
#   'XzDw',
#   'BIrWorstt',
#   'wRcK',
#   'HMAZIIcc',
#   'fNGlKDpz',
#   'gUlxtGy',
#   'MofXNzg',
#   'cWnMP',
#   'srwpFGdMSc',
#   'GqDC',
#   'ujJc',
#   ...]]

# %%
SyntheticDataNames = ["Normal", "Long String", "Special String", "Ascending Order", "Descending Order", 
                      "String with missing values", "String with duplicate values"]

# %%
synSearchList = []
for datalist in SyntheticDataList[0 : 3]:
    num = round(len(datalist) * 0.3)
    templist = []
    while len(templist) < num:
        tempdata = random.choice(datalist)
        if tempdata not in templist:
            templist.append(tempdata)
    synSearchList.append(templist)

for _ in range(4):
    synSearchList.append(synSearchList[0].copy())
synSearchList
# Out:
# [['pwmkyAklSi',
#   'iSUAEXTe',
#   'KEDKKPjLzQ',
#   'ugFQzYeqIl',
#   'UFDtFe',
#   'egKvqhf',
#   'wZDlNa',
#   'WSyYVuSv',
#   'OfrdkZrY',
#   'dvkoqSt',
#   'BPzHlnNZD',
#   'bzbyS',
#   'XtHSBty',
#   'AHrKIcDAHj',
#   'WlMPQ',
#   'QZDRt',
#   'HvBGsYxsb',
#   'PZotc',
#   'yPitBZSAqU',
#   'qXZdH',
#   'xgvErKNQpX',
#   'bjYLDsGdaq',
#   'tvUdaSi',
#   'rzRnCKd',
#   'apdWjW',
#   'eqxKMBhER',
#   'JwYws',
#   'kGvyndn',
#   'XGUqHp',
#   'ERbgT',
#   'VwqFFkc',
#   'onRVzugydh',
#   'CnfxU',
#   'obuOdh',
#   'VrGwpTRAXm',
#   'AyQAhGvFIh',
#   'KYlWFQMLmB',
#   'mMWLJTQ',
#   'VIJRxCZsl',
#   'LvWGjATNiL',
#   'wRlWNNaxA',
#   'ZuHGLGipqh',
#   'FsHjYN',
#   'XEknB',
#   'VJLnaRt',
#   'jJJDbODyvp',
#   'PVthc',
#   'fCuFDZC',
#   'ruJIbWB',
#   'pImhIuzHQf',
#   'Figpikq',
#   'QibpRzAY',
#   'iTbEU',
#   'eYdin',
#   'dfJqCmKnI',
#   'kPbvPT',
#   'jWbIsP',
#   'SGEco',
#   'YrxeNRzo',
#   'BrOQU',
#   'dHoll',
#   'jjmfNNFP',
#   'vmVFCZp',
#   'pUdJzl',
#   'ACalf',
#   'MCkTjN',
#   'UjwcJA',
#   'ehzmRHFJoT',
#   'RsxmexLtM',
#   'TUekMPndM',
#   'ndCFM',
#   'wBiHn',
#   'qFLxqiTqAT',
#   'iLosFFEHft',
#   'bedJkavayc',
#   'DgWGGiE',
#   'gIWNYpg',
#   'RuBuJ',
#   'PkTYJam',
#   'svtRRaYxLX',
#   'FTXqWaGEs',
#   'kUpwPhjyys',
#   'TqggEIVOLv',
#   'NaMrdOJK',
#   'rNjokB',
#   'fubLUVD',
#   'gkzcb',
#   'iaeaEWqj',
#   'GoqHq',
#   'MzYfu',
#   'kQBrPAs',
#   'gDKsk',
#   'VFoDdbvpa',
#   'tTQJpFir',
#   'ajEfuSLI',
#   'KvJHmI',
#   'ubFlqN',
#   'nxuqgPBUu',
#   'VBhGjkg',
#   'PXEAh',
#   'VdOAjNXOJP',
#   'uUZgwAn',
#   'IAIiLS',
#   'bwftlwDfLo',
#   'njPbaZwd',
#   'Uwlbpe',
#   'yDJXFbv',
#   'LjFULE',
#   'QvAHYuav',
#   'UZQGMwU',
#   'ohAMFyk',
#   'mpzxgraSX',
#   'KzhGuScRn',
#   'pTIhwtirA',
#   'NzxxLwiNXv',
#   'GGrZuPtJz',
#   'MroaGC',
#   'IYKdA',
#   'iRMmt',
#   'WpZzyZa',
#   'YyrcLfUMre',
#   'BVFWzEuzQk',
#   'wkYbIZfa',
#   'wOWMd',
#   'WvpBJwA',
#   'JZBQaoI',
#   'MGgWTCY',
#   'XrpobvQgVR',
#   'ztasDN',
#   'jolzne',
#   'hUZntSn',
#   'pouNUy',
#   'GeABUeG',
#   'saPrJeOq',
#   'iEKAw',
#   'YHBszbWg',
#   'hAdVwRTa',
#   'aKwkbyiG',
#   'xYBLZl',
#   'xEQlxfM',
#   'ESFtx',
#   'xGRxVxGZPr',
#   'bkeqHJt',
#   'fbObzRQ',
#   'ThFLeE',
#   'qPgmhBFGi',
#   'yNFJeyaRd',
#   'JzycB',
#   'zSGEvJprF',
#   'xqvAsoqn',
#   'JlwEF',
#   'KegqUDtTV',
#   'MWGEBihwNI',
#   'HDRpQZqY',
#   'DRQNPtM',
#   'uLphxTWeP',
#   'qfGPFwHci',
#   'clxrmYOON',
#   'olIbNlAe',
#   'WKtQipCHPz',
#   'aHDtGc',
#   'rYBIbI',
#   'qeBGJVmeeO',
#   'PwYdV',
#   'pjYJS',
#   'iCglJrDz',
#   'zOGOXEJc',
#   'beAGB',
#   'lEKrhYBCG',
#   'DmYDfWvPhu',
#   'qVIENRXpJ',
#   'DtioFSy',
#   'zJDQE',
#   'HTmDw',
#   'iRVMUlEy',
#   'bCZrrGlB',
#   'UWezePo',
#   'QExyzXeA',
#   'KvWePCsr',
#   'hvxLPmLQcq',
#   'TJZLGitka',
#   'mltDznG',
#   'eAEKTXOvf',
#   'ZGMLSByRJ',
#   'SUXbyXVBho',
#   'EcWgeeyoDN',
#   'hsjOB',
#   'WHhqRtXPWJ',
#   'MRzkZHDVFJ',
#   'uCiRlgHzjr',
#   'uOJvOov',
#   'EdBxVDs',
#   'ZUXeKubz',
#   'CwNxzrMQZd',
#   'oiCNK',
#   'IOGJlT',
#   'UKTVr',
#   'kgWuTyXF',
#   'CJkKCCuWMO',
#   'aTZaZxCGL',
#   'DGdKAfMxo',
#   'ZdCWW',
#   'wMesxXw',
#   'FtBLTcFXx',
#   'WZrmn',
#   'UXsXHVlvF',
#   'FfYfeiOHr',
#   'UfJmJDvXEP',
#   'fzZQPlXi',
#   'oklKCU',
#   'cxafRlt',
#   'xwIlWXa',
#   'cjOathLy',
#   'fzAArhEx',
#   'aibbTtCVW',
#   'ywuol',
#   'GhKXpJqT',
#   'PSOsoa',
#   'uWJGkCc',
#   'QEkwxLBY',
#   'JVKnPDpP',
#   'Dmewf',
#   'wurZdUrOEn',
#   'hXfdY',
#   'TOszFDc',
#   'cDJYdtR',
#   'zemDblr',
#   'iuJPqRCdi',
#   'MkKZu',
#   'MJeTNPIJ',
#   'fbxgwruT',
#   'ZLPzeJQ',
#   'PuHYFsTH',
#   'GNPUXnCdI',
#   'JHtweAnrC',
#   'AwLhikvWQ',
#   'ShSDKdoY',
#   'PmQvlgC',
#   'lYoGkTRvzM',
#   'yeuzmKb',
#   'ReYoMrviTV',
#   'BXNKsNuzm',
#   'codXHhpdW',
#   'CTDDFJa',
#   'RzrsAIwT',
#   'KYQaENaH',
#   'JTsdLeciSX',
#   'cebnWOnHI',
#   'LmIrh',
#   'ipmpDvNhj',
#   'MuSzH',
#   'hYAkeEs',
#   'lItmDviLg',
#   'YBzPemZix',
#   'DvZkLBhi',
#   'cunvtL',
#   'IGIjrVWl',
#   'ONtlklRrr',
#   'oUtOnczMow',
#   'hFsovdI',
#   'PxLvoWHG',
#   'DfsLfK',
#   'jjNpjGDvBZ',
#   'MHprBgep',
#   'FElIJuCbR',
#   'HjwcPUD',
#   'VZrmixV',
#   'qNJNN',
#   'SEgnfmouN',
#   'MUeVFIz',
#   'dNnjcGi',
#   'BsxmzJo',
#   'XkoFU',
#   'RukVeTvXhI',
#   'iwTwwC',
#   'vaGcCd',
#   'PQxCRlKvSL',
#   'qqtaZub',
#   'wgIQTmlBgv',
#   'OGscId',
#   'tObCjnon',
#   'vWBTDBCORj',
#   'McyLDIJriT',
#   'qrrWCUKQ',
#   'vbXQfD',
#   'XprYunHR',
#   'HextXq',
#   'PuCIhshgyn',
#   'WxgFJMoUxR',
#   'MBkYyP',
#   'cTNkS',
#   'aOIosBFe',
#   'KaEog',
#   'PRNwDyCo',
#   'hwZsxlTrX',
#   'PJHLWdIJu',
#   'OxlELCFnw',
#   'LKofYgExM',
#   'TmVbIR',
#   'pgEaqX'],
#  ['vrtyTWXAQGxkALEaFuNFmeYVRLuSYkaOfRRsuVPiLyiycDTpRk',
#   'YuMTAiSoGCDJzGZRzzvhyBczllanvEyaSZGJpEUuCxcAUurwEX',
#   'gqqGDrHjAKvinPypLcnLZbiEAEVVmODrQqhzqhOpqgDmCvtlYz',
#   'nyYTIaAgpuaCXduzXSUkyYdHnRyKAxyaFGRctaJImYKPUwNVUs',
#   'ksmAjQwVCLwGIYfVkjvntWSEqfFGLlZlDkqTXgGlSbVsQKylwh',
#   'RGHLejvWmtgDlskckfqMTMcGqwjmvQMHjqWgJVrTAeBUAcpTaj',
#   'KmJwMYHudWdnVVtGIcrOodjhxtTYruxyykfDNCzxPMRjOqMkfp',
#   'DpXaJkAipjvsmTxeSAisqlcPHvHnddJzHOjcJxOaynnNzCfGsL',
#   'SRHJlFqkjPpmUQWDKiDjtSnahqBmfPpjgdvlXEttucLFrnshrp',
#   'FgrREFVxfEvipPsddwTsSmaNvYElwhcZwqrElUoYvNanWGyvhM',
#   'UqWCxUVUfaPVHorwLUcuacYXUvXVOmFWHtCKlDuoxxVxjtWPJs',
#   'IPwAdyYavPHXeAOjVwJBYnrtaDfuXLFXUDSpsTUIvywOzAukcn',
#   'XqvHHUhxhtzhboBdmPJjCNEUlkFnVpRnhiaZRXaYvBDZmisTWZ',
#   'oXnGYovyYqaCdGjAGeEYfBDuieKwMfjCcqKdUKIzgiacOkCrTm',
#   'zlESNILKhYgCLSeccsZaQSmEjIunATkKIGXKJkmQXnQjRSVaJs',
#   'lJvPhNeGdjnRdbgFVSrTQMsGjtjlhAtcYOXefkwCPEITVeNPHt',
#   'VBFdhxcyWhgpLcEUyCFWvclGuBjBzlqJktfAZZMqFiOAStpREH',
#   'VzEsjyqxqrzATFmKYstRbnyhGJGYbFsiTXSYEIoiAYSJTmdDAO',
#   'OhPEJaRQrOnALbsERNUlBYRQfRutfPQisRAFNlwFGXiiNIptxj',
#   'rnRTOMmTejOoWKODTTmbUyrCjUhzmVgZLSWbzbZSgOFkjlYCQM',
#   'FSPlEQYySrKqipBANSZmDztfSlGkdLKlGOMnRYYHMtkdQnFyHk',
#   'FVfAehNsZyPinUUPfUmKOXhZcjJJRblrJWJduuEEIhnZIpJdeJ',
#   'wcCQgQBcsHjovFkFXwIXNnEBImdVRqMWPWwDPCVToGZDODFtAt',
#   'SssMymEYcHFaynjiBvBjPaauGEWpEsRCcnAyciiqrjEOrjdYtd',
#   'GYssZgrIGkocgrbRPZFjcxwYCZKxNLGrrebiBryoXbBCeciVTC',
#   'SNYDwGlcfoilDJEMdCONDoiKAoGZRHAudcTWyMBmsPuxGuTQor',
#   'sjAIZskPGIuGlzOIgwxzuNTsWmMfUnkbtnExrpkSAEVGvGseep',
#   'fnSkjnylKgCanmrkiWMJRmOkITXJqMfVAPHuUtmCwLRqzCUImP',
#   'YoaGfBILoWkDKVOFqUdUvqrHyBHLluDkrGcQKTOFFUNxKYoArm'],
#  ['Y-*OiC=',
#   'H\t\ng&,hJ=',
#   'x"!?afPBg',
#   'c^Q\x0br!UOy+',
#   "{-'wB)\n5+",
#   'fR\\A4',
#   'y7M*CaH',
#   '\t4phhW~4',
#   '\x0blgz6',
#   '5qldn.X',
#   '\ri[)C',
#   "\\*'m@n",
#   'd!3qU\x0czNX|',
#   "4 i)q'r",
#   '$FS~S{',
#   '61\\LOAe"',
#   'QBQLc',
#   '<f}e*/V$Z',
#   ')I6)h',
#   '668#Y',
#   "'g>4jm",
#   '?jMP7EQ',
#   '(BoY%<&iP"',
#   '}Z$$?t',
#   'NR1hw[d&',
#   '[C~ji"B',
#   'wg?].Z0s',
#   '"y;zk9_S',
#   '@ t>j( eMM',
#   'D`>F(Uk}',
#   'C3L!yJNL',
#   '1p.qwU',
#   '/,q\rN*',
#   '23G>3Kw}N',
#   ' ?uA9-c:y',
#   '$$%MGFOJl',
#   '(%t{(',
#   ")'emG",
#   '8vZV\rA',
#   'Rn[4.',
#   ')A\n%A',
#   '}CW\\;0pZ',
#   '^P_Rk9M;c',
#   'onr!0',
#   '_MHcHRo9',
#   'Lze|X0Q',
#   '0u:0X]uR',
#   'Mr}-JS#p4+',
#   'vm,5jE@) N',
#   'W!2js',
#   'zdvYm',
#   '<oR*h',
#   '\x0b.w!(4-',
#   ')7p(pv8',
#   '$d9xVT`^?I',
#   '|x\x0b3X=',
#   'W2kQvS$',
#   '\x0bO>Z@YdL',
#   '\x0bc=DES',
#   '5.D<O',
#   '\x0cd^6P,2\x0c(O',
#   'C4\t(ISTpq<',
#   'Yc[r_',
#   "'fDeD{=DS|",
#   'x,.cr=b',
#   ' )\\3MOg',
#   'YaBPg5}#$h',
#   'M_P,YZX',
#   "&C'S6n&Ja[",
#   'Un.o`pw7X~',
#   'uIR_Ud',
#   '$MGV?',
#   'I>=l\r',
#   ';pi\x0c~-\x0cbD',
#   'ROqZYER',
#   "'6heG:6v",
#   'Wl^eGz',
#   '\r6}r-\t:',
#   'X&:}:\x0ba',
#   'Qd^\\P\x0cwwuE',
#   '\nJ|13',
#   "mYe,AE#'@9",
#   '*;eW-VS&',
#   'sOM:(j',
#   'x:?0d',
#   'iK^[UX~;G',
#   '^3edV',
#   'Vc:"\r\'',
#   ':85Mr',
#   'x|Ja5',
#   '?jTFO=\r',
#   'w=C"I@&',
#   'W\x0b/^-',
#   '~jfO]',
#   '\\ nW2',
#   '_#U;s.q',
#   'HLGLU"}B5A',
#   'BNYa/:HP',
#   'lmiu}E{',
#   'ted31Y>R',
#   '>kz`%o5)',
#   ']QO[ZJ<bO',
#   'Ui%77A',
#   '&ynpPK_&N_',
#   '+51L(gH]',
#   ':z)\nP',
#   '\x0bmy,#Cz',
#   '`;`/44->',
#   '^-L0%=',
#   'f}P[c\nG/y!',
#   'Fpb)1&',
#   '"\rL1}',
#   'TQx!T=d!F',
#   '-D]:\x0b2|_L',
#   'A~/ uS',
#   'wt^L*Zh',
#   'z?q&HVz',
#   '\t=iy$C_\\4',
#   '$:#WqK',
#   'l\x0cZJt\r',
#   '/WOg`_)',
#   'e5MlUr',
#   '%\rkUwCY',
#   '12@ yq"n U',
#   'fo9SyG.a!',
#   '( KIT;',
#   '7=?u$v',
#   'v;*\n\tFh,',
#   'vuIO\t.',
#   'hO\x0c<V',
#   '4sLaH(s):B',
#   '`U$Ao\x0b\r',
#   'Ql`0R\nT',
#   "U>I':>CUYU",
#   '0Y-%){&s',
#   'f=>,t`3\x0bg2',
#   'OCz~A0+',
#   'l ;Sy',
#   'yI(6?',
#   'BKTD\\g&V',
#   '8~n=o|yF\t',
#   'XQ+,`h>',
#   '\x0ce50{',
#   '8|Ot\x0cvK',
#   '!x|yPj',
#   'Vc""jm',
#   '1*ML~@LY',
#   'bki^3B ',
#   '>V{#Lc-8(',
#   '@$zYL\\Z#C',
#   '[8wib:a',
#   'typyu',
#   '-I;Az',
#   'q`|%E#K{',
#   ',p1W3Y\x0b%',
#   '\rdcw|',
#   'U+PX>?+M\t',
#   'Q5WuP',
#   'Y&\rt)%-',
#   'DhN30{-',
#   '@nj37yslNo',
#   "2'*$|GRVa",
#   'W"Jq@vl',
#   '?uQ\x0c]T\n\x0cz',
#   '1NzbYxRm<',
#   'sVhr\n',
#   '\\=[5]f7E\x0c',
#   "'[;~8e",
#   'L;9;Ye0',
#   "|'hl3Q",
#   "l0='.gTw",
#   '<MLUS?',
#   '6P0\\Z~a&<~',
#   'Y@;Io#/ gH',
#   "F ]D'1IP{",
#   ']RR)$2',
#   'g-!_?2#;w',
#   'f?Z]&0{',
#   '@}4hT',
#   'P[7kU4)-\\U',
#   '4dNx_0',
#   'ZQX{P',
#   '4o:_Q~bI>',
#   '\x0bSmV2]UU',
#   'HxS;RvhvB',
#   ' `<88S(RS7',
#   'l1JDYa?\t%R',
#   ')d!,k,\x0b*.',
#   'X$\\N\n',
#   'hY#I^',
#   'pa\\D!&5/Se',
#   'mjlTvm"7',
#   'gI%rk',
#   '#cua?:S]\n',
#   '2c[HV/ `"w',
#   '1y2%lce-',
#   '!m{@sI',
#   '&ehIId44',
#   ' !|qg4\x0ba?',
#   '[s\r\\|n\x0c1?4',
#   "+\n/>'.~W",
#   '=JemM)c',
#   'LHuz}v',
#   '\\Ka+>',
#   '!dw1o',
#   'WKL4nO`\\4',
#   '.Vz<-2X\t',
#   'T#a3!;b',
#   'fyb\x0b:WvSX@',
#   'q-5lr',
#   'uUM>CqK$R',
#   'gMI740~\x0b\r?',
#   '|ZH*W)\x0bWu\n',
#   'jDJd\x0bm<',
#   '"H~b={',
#   '+~ZHD|6P',
#   '~-<z09%',
#   'E2/YwB.^>',
#   'BQ^KM',
#   'C_Ck*)',
#   'owpk\\4_cGJ',
#   '9n%t-+\tgvj',
#   '/;sb\r',
#   'Dq\\FYbHv<k',
#   "gkB;c`T>'=",
#   'fK27wj{W',
#   'J<T.:UQ',
#   'M5BR^e',
#   '1\rld!B',
#   '!\x0bc\n_Z5',
#   '+bk7@Pe',
#   'Y#y<EcCwL`',
#   'r=G]?',
#   ':l}D\\F*\tU',
#   '.ApguI2+}',
#   'EHXSm1',
#   'W\t}aD|',
#   '4zc%P51',
#   'RNYUYi',
#   'PD}q+py#=',
#   'CI\x0c3W',
#   ' @bBc\\F',
#   '\nQBw\n,',
#   'sKY/G',
#   ']_#\tLEU',
#   'u3B+p#h+\\',
#   '$\t>/-',
#   '=\\T%Ez-+G6',
#   ',|z1;8H',
#   '@ q@,zL',
#   'ZBoWNg.N',
#   '?JaJ:,+52',
#   'X_jHs6*\x0b=',
#   '/IXMoxN9,{',
#   '.Pt8rR',
#   '&oI#\n',
#   'k/x\\K',
#   '\rC2HPJ\tCBU',
#   '/ihWg]4D',
#   "&T^[*\n'V",
#   '*!!^|*5i2w',
#   'd3MFM$>vKd',
#   'U~rIxyBr',
#   'l\x0b.6Wa~e',
#   '{~kN;',
#   'T":QFeW\x0b',
#   '\t+H{^',
#   '-+LR$T',
#   'S|-$_LK4',
#   'iP7wI',
#   ':^TE0tSx90',
#   ':oS#0',
#   'n6rDS~AV',
#   'e:/\nrv|\t6&',
#   '\r~&kyi ex',
#   '4b%=z<',
#   "I&2'W9Ew?",
#   ':y"Iu',
#   'w{EYH',
#   'oG]gy(x',
#   'x@*o(C6<',
#   'o{aUc$]Z',
#   '^\x0c{u 0',
#   '2oQ!h+Hb',
#   'pryI$!&',
#   "6RlELnT&'g",
#   '.C:<"',
#   "A'jsfX5ET-",
#   'L_KE\n',
#   'tFh@r`ux',
#   '}@",e XR',
#   '7z`B`8U',
#   '\\M[[eDV""',
#   '\nw6dwWH',
#   '\nf$o9nBX&^',
#   'H?JG3a',
#   '7MxI5`wL',
#   'F6Uh$nK8Hu',
#   'l^{jOc',
#   '4m:\rg9%r'],
#  ['pwmkyAklSi',
#   'iSUAEXTe',
#   'KEDKKPjLzQ',
#   'ugFQzYeqIl',
#   'UFDtFe',
#   'egKvqhf',
#   'wZDlNa',
#   'WSyYVuSv',
#   'OfrdkZrY',
#   'dvkoqSt',
#   'BPzHlnNZD',
#   'bzbyS',
#   'XtHSBty',
#   'AHrKIcDAHj',
#   'WlMPQ',
#   'QZDRt',
#   'HvBGsYxsb',
#   'PZotc',
#   'yPitBZSAqU',
#   'qXZdH',
#   'xgvErKNQpX',
#   'bjYLDsGdaq',
#   'tvUdaSi',
#   'rzRnCKd',
#   'apdWjW',
#   'eqxKMBhER',
#   'JwYws',
#   'kGvyndn',
#   'XGUqHp',
#   'ERbgT',
#   'VwqFFkc',
#   'onRVzugydh',
#   'CnfxU',
#   'obuOdh',
#   'VrGwpTRAXm',
#   'AyQAhGvFIh',
#   'KYlWFQMLmB',
#   'mMWLJTQ',
#   'VIJRxCZsl',
#   'LvWGjATNiL',
#   'wRlWNNaxA',
#   'ZuHGLGipqh',
#   'FsHjYN',
#   'XEknB',
#   'VJLnaRt',
#   'jJJDbODyvp',
#   'PVthc',
#   'fCuFDZC',
#   'ruJIbWB',
#   'pImhIuzHQf',
#   'Figpikq',
#   'QibpRzAY',
#   'iTbEU',
#   'eYdin',
#   'dfJqCmKnI',
#   'kPbvPT',
#   'jWbIsP',
#   'SGEco',
#   'YrxeNRzo',
#   'BrOQU',
#   'dHoll',
#   'jjmfNNFP',
#   'vmVFCZp',
#   'pUdJzl',
#   'ACalf',
#   'MCkTjN',
#   'UjwcJA',
#   'ehzmRHFJoT',
#   'RsxmexLtM',
#   'TUekMPndM',
#   'ndCFM',
#   'wBiHn',
#   'qFLxqiTqAT',
#   'iLosFFEHft',
#   'bedJkavayc',
#   'DgWGGiE',
#   'gIWNYpg',
#   'RuBuJ',
#   'PkTYJam',
#   'svtRRaYxLX',
#   'FTXqWaGEs',
#   'kUpwPhjyys',
#   'TqggEIVOLv',
#   'NaMrdOJK',
#   'rNjokB',
#   'fubLUVD',
#   'gkzcb',
#   'iaeaEWqj',
#   'GoqHq',
#   'MzYfu',
#   'kQBrPAs',
#   'gDKsk',
#   'VFoDdbvpa',
#   'tTQJpFir',
#   'ajEfuSLI',
#   'KvJHmI',
#   'ubFlqN',
#   'nxuqgPBUu',
#   'VBhGjkg',
#   'PXEAh',
#   'VdOAjNXOJP',
#   'uUZgwAn',
#   'IAIiLS',
#   'bwftlwDfLo',
#   'njPbaZwd',
#   'Uwlbpe',
#   'yDJXFbv',
#   'LjFULE',
#   'QvAHYuav',
#   'UZQGMwU',
#   'ohAMFyk',
#   'mpzxgraSX',
#   'KzhGuScRn',
#   'pTIhwtirA',
#   'NzxxLwiNXv',
#   'GGrZuPtJz',
#   'MroaGC',
#   'IYKdA',
#   'iRMmt',
#   'WpZzyZa',
#   'YyrcLfUMre',
#   'BVFWzEuzQk',
#   'wkYbIZfa',
#   'wOWMd',
#   'WvpBJwA',
#   'JZBQaoI',
#   'MGgWTCY',
#   'XrpobvQgVR',
#   'ztasDN',
#   'jolzne',
#   'hUZntSn',
#   'pouNUy',
#   'GeABUeG',
#   'saPrJeOq',
#   'iEKAw',
#   'YHBszbWg',
#   'hAdVwRTa',
#   'aKwkbyiG',
#   'xYBLZl',
#   'xEQlxfM',
#   'ESFtx',
#   'xGRxVxGZPr',
#   'bkeqHJt',
#   'fbObzRQ',
#   'ThFLeE',
#   'qPgmhBFGi',
#   'yNFJeyaRd',
#   'JzycB',
#   'zSGEvJprF',
#   'xqvAsoqn',
#   'JlwEF',
#   'KegqUDtTV',
#   'MWGEBihwNI',
#   'HDRpQZqY',
#   'DRQNPtM',
#   'uLphxTWeP',
#   'qfGPFwHci',
#   'clxrmYOON',
#   'olIbNlAe',
#   'WKtQipCHPz',
#   'aHDtGc',
#   'rYBIbI',
#   'qeBGJVmeeO',
#   'PwYdV',
#   'pjYJS',
#   'iCglJrDz',
#   'zOGOXEJc',
#   'beAGB',
#   'lEKrhYBCG',
#   'DmYDfWvPhu',
#   'qVIENRXpJ',
#   'DtioFSy',
#   'zJDQE',
#   'HTmDw',
#   'iRVMUlEy',
#   'bCZrrGlB',
#   'UWezePo',
#   'QExyzXeA',
#   'KvWePCsr',
#   'hvxLPmLQcq',
#   'TJZLGitka',
#   'mltDznG',
#   'eAEKTXOvf',
#   'ZGMLSByRJ',
#   'SUXbyXVBho',
#   'EcWgeeyoDN',
#   'hsjOB',
#   'WHhqRtXPWJ',
#   'MRzkZHDVFJ',
#   'uCiRlgHzjr',
#   'uOJvOov',
#   'EdBxVDs',
#   'ZUXeKubz',
#   'CwNxzrMQZd',
#   'oiCNK',
#   'IOGJlT',
#   'UKTVr',
#   'kgWuTyXF',
#   'CJkKCCuWMO',
#   'aTZaZxCGL',
#   'DGdKAfMxo',
#   'ZdCWW',
#   'wMesxXw',
#   'FtBLTcFXx',
#   'WZrmn',
#   'UXsXHVlvF',
#   'FfYfeiOHr',
#   'UfJmJDvXEP',
#   'fzZQPlXi',
#   'oklKCU',
#   'cxafRlt',
#   'xwIlWXa',
#   'cjOathLy',
#   'fzAArhEx',
#   'aibbTtCVW',
#   'ywuol',
#   'GhKXpJqT',
#   'PSOsoa',
#   'uWJGkCc',
#   'QEkwxLBY',
#   'JVKnPDpP',
#   'Dmewf',
#   'wurZdUrOEn',
#   'hXfdY',
#   'TOszFDc',
#   'cDJYdtR',
#   'zemDblr',
#   'iuJPqRCdi',
#   'MkKZu',
#   'MJeTNPIJ',
#   'fbxgwruT',
#   'ZLPzeJQ',
#   'PuHYFsTH',
#   'GNPUXnCdI',
#   'JHtweAnrC',
#   'AwLhikvWQ',
#   'ShSDKdoY',
#   'PmQvlgC',
#   'lYoGkTRvzM',
#   'yeuzmKb',
#   'ReYoMrviTV',
#   'BXNKsNuzm',
#   'codXHhpdW',
#   'CTDDFJa',
#   'RzrsAIwT',
#   'KYQaENaH',
#   'JTsdLeciSX',
#   'cebnWOnHI',
#   'LmIrh',
#   'ipmpDvNhj',
#   'MuSzH',
#   'hYAkeEs',
#   'lItmDviLg',
#   'YBzPemZix',
#   'DvZkLBhi',
#   'cunvtL',
#   'IGIjrVWl',
#   'ONtlklRrr',
#   'oUtOnczMow',
#   'hFsovdI',
#   'PxLvoWHG',
#   'DfsLfK',
#   'jjNpjGDvBZ',
#   'MHprBgep',
#   'FElIJuCbR',
#   'HjwcPUD',
#   'VZrmixV',
#   'qNJNN',
#   'SEgnfmouN',
#   'MUeVFIz',
#   'dNnjcGi',
#   'BsxmzJo',
#   'XkoFU',
#   'RukVeTvXhI',
#   'iwTwwC',
#   'vaGcCd',
#   'PQxCRlKvSL',
#   'qqtaZub',
#   'wgIQTmlBgv',
#   'OGscId',
#   'tObCjnon',
#   'vWBTDBCORj',
#   'McyLDIJriT',
#   'qrrWCUKQ',
#   'vbXQfD',
#   'XprYunHR',
#   'HextXq',
#   'PuCIhshgyn',
#   'WxgFJMoUxR',
#   'MBkYyP',
#   'cTNkS',
#   'aOIosBFe',
#   'KaEog',
#   'PRNwDyCo',
#   'hwZsxlTrX',
#   'PJHLWdIJu',
#   'OxlELCFnw',
#   'LKofYgExM',
#   'TmVbIR',
#   'pgEaqX'],
#  ['pwmkyAklSi',
#   'iSUAEXTe',
#   'KEDKKPjLzQ',
#   'ugFQzYeqIl',
#   'UFDtFe',
#   'egKvqhf',
#   'wZDlNa',
#   'WSyYVuSv',
#   'OfrdkZrY',
#   'dvkoqSt',
#   'BPzHlnNZD',
#   'bzbyS',
#   'XtHSBty',
#   'AHrKIcDAHj',
#   'WlMPQ',
#   'QZDRt',
#   'HvBGsYxsb',
#   'PZotc',
#   'yPitBZSAqU',
#   'qXZdH',
#   'xgvErKNQpX',
#   'bjYLDsGdaq',
#   'tvUdaSi',
#   'rzRnCKd',
#   'apdWjW',
#   'eqxKMBhER',
#   'JwYws',
#   'kGvyndn',
#   'XGUqHp',
#   'ERbgT',
#   'VwqFFkc',
#   'onRVzugydh',
#   'CnfxU',
#   'obuOdh',
#   'VrGwpTRAXm',
#   'AyQAhGvFIh',
#   'KYlWFQMLmB',
#   'mMWLJTQ',
#   'VIJRxCZsl',
#   'LvWGjATNiL',
#   'wRlWNNaxA',
#   'ZuHGLGipqh',
#   'FsHjYN',
#   'XEknB',
#   'VJLnaRt',
#   'jJJDbODyvp',
#   'PVthc',
#   'fCuFDZC',
#   'ruJIbWB',
#   'pImhIuzHQf',
#   'Figpikq',
#   'QibpRzAY',
#   'iTbEU',
#   'eYdin',
#   'dfJqCmKnI',
#   'kPbvPT',
#   'jWbIsP',
#   'SGEco',
#   'YrxeNRzo',
#   'BrOQU',
#   'dHoll',
#   'jjmfNNFP',
#   'vmVFCZp',
#   'pUdJzl',
#   'ACalf',
#   'MCkTjN',
#   'UjwcJA',
#   'ehzmRHFJoT',
#   'RsxmexLtM',
#   'TUekMPndM',
#   'ndCFM',
#   'wBiHn',
#   'qFLxqiTqAT',
#   'iLosFFEHft',
#   'bedJkavayc',
#   'DgWGGiE',
#   'gIWNYpg',
#   'RuBuJ',
#   'PkTYJam',
#   'svtRRaYxLX',
#   'FTXqWaGEs',
#   'kUpwPhjyys',
#   'TqggEIVOLv',
#   'NaMrdOJK',
#   'rNjokB',
#   'fubLUVD',
#   'gkzcb',
#   'iaeaEWqj',
#   'GoqHq',
#   'MzYfu',
#   'kQBrPAs',
#   'gDKsk',
#   'VFoDdbvpa',
#   'tTQJpFir',
#   'ajEfuSLI',
#   'KvJHmI',
#   'ubFlqN',
#   'nxuqgPBUu',
#   'VBhGjkg',
#   'PXEAh',
#   'VdOAjNXOJP',
#   'uUZgwAn',
#   'IAIiLS',
#   'bwftlwDfLo',
#   'njPbaZwd',
#   'Uwlbpe',
#   'yDJXFbv',
#   'LjFULE',
#   'QvAHYuav',
#   'UZQGMwU',
#   'ohAMFyk',
#   'mpzxgraSX',
#   'KzhGuScRn',
#   'pTIhwtirA',
#   'NzxxLwiNXv',
#   'GGrZuPtJz',
#   'MroaGC',
#   'IYKdA',
#   'iRMmt',
#   'WpZzyZa',
#   'YyrcLfUMre',
#   'BVFWzEuzQk',
#   'wkYbIZfa',
#   'wOWMd',
#   'WvpBJwA',
#   'JZBQaoI',
#   'MGgWTCY',
#   'XrpobvQgVR',
#   'ztasDN',
#   'jolzne',
#   'hUZntSn',
#   'pouNUy',
#   'GeABUeG',
#   'saPrJeOq',
#   'iEKAw',
#   'YHBszbWg',
#   'hAdVwRTa',
#   'aKwkbyiG',
#   'xYBLZl',
#   'xEQlxfM',
#   'ESFtx',
#   'xGRxVxGZPr',
#   'bkeqHJt',
#   'fbObzRQ',
#   'ThFLeE',
#   'qPgmhBFGi',
#   'yNFJeyaRd',
#   'JzycB',
#   'zSGEvJprF',
#   'xqvAsoqn',
#   'JlwEF',
#   'KegqUDtTV',
#   'MWGEBihwNI',
#   'HDRpQZqY',
#   'DRQNPtM',
#   'uLphxTWeP',
#   'qfGPFwHci',
#   'clxrmYOON',
#   'olIbNlAe',
#   'WKtQipCHPz',
#   'aHDtGc',
#   'rYBIbI',
#   'qeBGJVmeeO',
#   'PwYdV',
#   'pjYJS',
#   'iCglJrDz',
#   'zOGOXEJc',
#   'beAGB',
#   'lEKrhYBCG',
#   'DmYDfWvPhu',
#   'qVIENRXpJ',
#   'DtioFSy',
#   'zJDQE',
#   'HTmDw',
#   'iRVMUlEy',
#   'bCZrrGlB',
#   'UWezePo',
#   'QExyzXeA',
#   'KvWePCsr',
#   'hvxLPmLQcq',
#   'TJZLGitka',
#   'mltDznG',
#   'eAEKTXOvf',
#   'ZGMLSByRJ',
#   'SUXbyXVBho',
#   'EcWgeeyoDN',
#   'hsjOB',
#   'WHhqRtXPWJ',
#   'MRzkZHDVFJ',
#   'uCiRlgHzjr',
#   'uOJvOov',
#   'EdBxVDs',
#   'ZUXeKubz',
#   'CwNxzrMQZd',
#   'oiCNK',
#   'IOGJlT',
#   'UKTVr',
#   'kgWuTyXF',
#   'CJkKCCuWMO',
#   'aTZaZxCGL',
#   'DGdKAfMxo',
#   'ZdCWW',
#   'wMesxXw',
#   'FtBLTcFXx',
#   'WZrmn',
#   'UXsXHVlvF',
#   'FfYfeiOHr',
#   'UfJmJDvXEP',
#   'fzZQPlXi',
#   'oklKCU',
#   'cxafRlt',
#   'xwIlWXa',
#   'cjOathLy',
#   'fzAArhEx',
#   'aibbTtCVW',
#   'ywuol',
#   'GhKXpJqT',
#   'PSOsoa',
#   'uWJGkCc',
#   'QEkwxLBY',
#   'JVKnPDpP',
#   'Dmewf',
#   'wurZdUrOEn',
#   'hXfdY',
#   'TOszFDc',
#   'cDJYdtR',
#   'zemDblr',
#   'iuJPqRCdi',
#   'MkKZu',
#   'MJeTNPIJ',
#   'fbxgwruT',
#   'ZLPzeJQ',
#   'PuHYFsTH',
#   'GNPUXnCdI',
#   'JHtweAnrC',
#   'AwLhikvWQ',
#   'ShSDKdoY',
#   'PmQvlgC',
#   'lYoGkTRvzM',
#   'yeuzmKb',
#   'ReYoMrviTV',
#   'BXNKsNuzm',
#   'codXHhpdW',
#   'CTDDFJa',
#   'RzrsAIwT',
#   'KYQaENaH',
#   'JTsdLeciSX',
#   'cebnWOnHI',
#   'LmIrh',
#   'ipmpDvNhj',
#   'MuSzH',
#   'hYAkeEs',
#   'lItmDviLg',
#   'YBzPemZix',
#   'DvZkLBhi',
#   'cunvtL',
#   'IGIjrVWl',
#   'ONtlklRrr',
#   'oUtOnczMow',
#   'hFsovdI',
#   'PxLvoWHG',
#   'DfsLfK',
#   'jjNpjGDvBZ',
#   'MHprBgep',
#   'FElIJuCbR',
#   'HjwcPUD',
#   'VZrmixV',
#   'qNJNN',
#   'SEgnfmouN',
#   'MUeVFIz',
#   'dNnjcGi',
#   'BsxmzJo',
#   'XkoFU',
#   'RukVeTvXhI',
#   'iwTwwC',
#   'vaGcCd',
#   'PQxCRlKvSL',
#   'qqtaZub',
#   'wgIQTmlBgv',
#   'OGscId',
#   'tObCjnon',
#   'vWBTDBCORj',
#   'McyLDIJriT',
#   'qrrWCUKQ',
#   'vbXQfD',
#   'XprYunHR',
#   'HextXq',
#   'PuCIhshgyn',
#   'WxgFJMoUxR',
#   'MBkYyP',
#   'cTNkS',
#   'aOIosBFe',
#   'KaEog',
#   'PRNwDyCo',
#   'hwZsxlTrX',
#   'PJHLWdIJu',
#   'OxlELCFnw',
#   'LKofYgExM',
#   'TmVbIR',
#   'pgEaqX'],
#  ['pwmkyAklSi',
#   'iSUAEXTe',
#   'KEDKKPjLzQ',
#   'ugFQzYeqIl',
#   'UFDtFe',
#   'egKvqhf',
#   'wZDlNa',
#   'WSyYVuSv',
#   'OfrdkZrY',
#   'dvkoqSt',
#   'BPzHlnNZD',
#   'bzbyS',
#   'XtHSBty',
#   'AHrKIcDAHj',
#   'WlMPQ',
#   'QZDRt',
#   'HvBGsYxsb',
#   'PZotc',
#   'yPitBZSAqU',
#   'qXZdH',
#   'xgvErKNQpX',
#   'bjYLDsGdaq',
#   'tvUdaSi',
#   'rzRnCKd',
#   'apdWjW',
#   'eqxKMBhER',
#   'JwYws',
#   'kGvyndn',
#   'XGUqHp',
#   'ERbgT',
#   'VwqFFkc',
#   'onRVzugydh',
#   'CnfxU',
#   'obuOdh',
#   'VrGwpTRAXm',
#   'AyQAhGvFIh',
#   'KYlWFQMLmB',
#   'mMWLJTQ',
#   'VIJRxCZsl',
#   'LvWGjATNiL',
#   'wRlWNNaxA',
#   'ZuHGLGipqh',
#   'FsHjYN',
#   'XEknB',
#   'VJLnaRt',
#   'jJJDbODyvp',
#   'PVthc',
#   'fCuFDZC',
#   'ruJIbWB',
#   'pImhIuzHQf',
#   'Figpikq',
#   'QibpRzAY',
#   'iTbEU',
#   'eYdin',
#   'dfJqCmKnI',
#   'kPbvPT',
#   'jWbIsP',
#   'SGEco',
#   'YrxeNRzo',
#   'BrOQU',
#   'dHoll',
#   'jjmfNNFP',
#   'vmVFCZp',
#   'pUdJzl',
#   'ACalf',
#   'MCkTjN',
#   'UjwcJA',
#   'ehzmRHFJoT',
#   'RsxmexLtM',
#   'TUekMPndM',
#   'ndCFM',
#   'wBiHn',
#   'qFLxqiTqAT',
#   'iLosFFEHft',
#   'bedJkavayc',
#   'DgWGGiE',
#   'gIWNYpg',
#   'RuBuJ',
#   'PkTYJam',
#   'svtRRaYxLX',
#   'FTXqWaGEs',
#   'kUpwPhjyys',
#   'TqggEIVOLv',
#   'NaMrdOJK',
#   'rNjokB',
#   'fubLUVD',
#   'gkzcb',
#   'iaeaEWqj',
#   'GoqHq',
#   'MzYfu',
#   'kQBrPAs',
#   'gDKsk',
#   'VFoDdbvpa',
#   'tTQJpFir',
#   'ajEfuSLI',
#   'KvJHmI',
#   'ubFlqN',
#   'nxuqgPBUu',
#   'VBhGjkg',
#   'PXEAh',
#   'VdOAjNXOJP',
#   'uUZgwAn',
#   'IAIiLS',
#   'bwftlwDfLo',
#   'njPbaZwd',
#   'Uwlbpe',
#   'yDJXFbv',
#   'LjFULE',
#   'QvAHYuav',
#   'UZQGMwU',
#   'ohAMFyk',
#   'mpzxgraSX',
#   'KzhGuScRn',
#   'pTIhwtirA',
#   'NzxxLwiNXv',
#   'GGrZuPtJz',
#   'MroaGC',
#   'IYKdA',
#   'iRMmt',
#   'WpZzyZa',
#   'YyrcLfUMre',
#   'BVFWzEuzQk',
#   'wkYbIZfa',
#   'wOWMd',
#   'WvpBJwA',
#   'JZBQaoI',
#   'MGgWTCY',
#   'XrpobvQgVR',
#   'ztasDN',
#   'jolzne',
#   'hUZntSn',
#   'pouNUy',
#   'GeABUeG',
#   'saPrJeOq',
#   'iEKAw',
#   'YHBszbWg',
#   'hAdVwRTa',
#   'aKwkbyiG',
#   'xYBLZl',
#   'xEQlxfM',
#   'ESFtx',
#   'xGRxVxGZPr',
#   'bkeqHJt',
#   'fbObzRQ',
#   'ThFLeE',
#   'qPgmhBFGi',
#   'yNFJeyaRd',
#   'JzycB',
#   'zSGEvJprF',
#   'xqvAsoqn',
#   'JlwEF',
#   'KegqUDtTV',
#   'MWGEBihwNI',
#   'HDRpQZqY',
#   'DRQNPtM',
#   'uLphxTWeP',
#   'qfGPFwHci',
#   'clxrmYOON',
#   'olIbNlAe',
#   'WKtQipCHPz',
#   'aHDtGc',
#   'rYBIbI',
#   'qeBGJVmeeO',
#   'PwYdV',
#   'pjYJS',
#   'iCglJrDz',
#   'zOGOXEJc',
#   'beAGB',
#   'lEKrhYBCG',
#   'DmYDfWvPhu',
#   'qVIENRXpJ',
#   'DtioFSy',
#   'zJDQE',
#   'HTmDw',
#   'iRVMUlEy',
#   'bCZrrGlB',
#   'UWezePo',
#   'QExyzXeA',
#   'KvWePCsr',
#   'hvxLPmLQcq',
#   'TJZLGitka',
#   'mltDznG',
#   'eAEKTXOvf',
#   'ZGMLSByRJ',
#   'SUXbyXVBho',
#   'EcWgeeyoDN',
#   'hsjOB',
#   'WHhqRtXPWJ',
#   'MRzkZHDVFJ',
#   'uCiRlgHzjr',
#   'uOJvOov',
#   'EdBxVDs',
#   'ZUXeKubz',
#   'CwNxzrMQZd',
#   'oiCNK',
#   'IOGJlT',
#   'UKTVr',
#   'kgWuTyXF',
#   'CJkKCCuWMO',
#   'aTZaZxCGL',
#   'DGdKAfMxo',
#   'ZdCWW',
#   'wMesxXw',
#   'FtBLTcFXx',
#   'WZrmn',
#   'UXsXHVlvF',
#   'FfYfeiOHr',
#   'UfJmJDvXEP',
#   'fzZQPlXi',
#   'oklKCU',
#   'cxafRlt',
#   'xwIlWXa',
#   'cjOathLy',
#   'fzAArhEx',
#   'aibbTtCVW',
#   'ywuol',
#   'GhKXpJqT',
#   'PSOsoa',
#   'uWJGkCc',
#   'QEkwxLBY',
#   'JVKnPDpP',
#   'Dmewf',
#   'wurZdUrOEn',
#   'hXfdY',
#   'TOszFDc',
#   'cDJYdtR',
#   'zemDblr',
#   'iuJPqRCdi',
#   'MkKZu',
#   'MJeTNPIJ',
#   'fbxgwruT',
#   'ZLPzeJQ',
#   'PuHYFsTH',
#   'GNPUXnCdI',
#   'JHtweAnrC',
#   'AwLhikvWQ',
#   'ShSDKdoY',
#   'PmQvlgC',
#   'lYoGkTRvzM',
#   'yeuzmKb',
#   'ReYoMrviTV',
#   'BXNKsNuzm',
#   'codXHhpdW',
#   'CTDDFJa',
#   'RzrsAIwT',
#   'KYQaENaH',
#   'JTsdLeciSX',
#   'cebnWOnHI',
#   'LmIrh',
#   'ipmpDvNhj',
#   'MuSzH',
#   'hYAkeEs',
#   'lItmDviLg',
#   'YBzPemZix',
#   'DvZkLBhi',
#   'cunvtL',
#   'IGIjrVWl',
#   'ONtlklRrr',
#   'oUtOnczMow',
#   'hFsovdI',
#   'PxLvoWHG',
#   'DfsLfK',
#   'jjNpjGDvBZ',
#   'MHprBgep',
#   'FElIJuCbR',
#   'HjwcPUD',
#   'VZrmixV',
#   'qNJNN',
#   'SEgnfmouN',
#   'MUeVFIz',
#   'dNnjcGi',
#   'BsxmzJo',
#   'XkoFU',
#   'RukVeTvXhI',
#   'iwTwwC',
#   'vaGcCd',
#   'PQxCRlKvSL',
#   'qqtaZub',
#   'wgIQTmlBgv',
#   'OGscId',
#   'tObCjnon',
#   'vWBTDBCORj',
#   'McyLDIJriT',
#   'qrrWCUKQ',
#   'vbXQfD',
#   'XprYunHR',
#   'HextXq',
#   'PuCIhshgyn',
#   'WxgFJMoUxR',
#   'MBkYyP',
#   'cTNkS',
#   'aOIosBFe',
#   'KaEog',
#   'PRNwDyCo',
#   'hwZsxlTrX',
#   'PJHLWdIJu',
#   'OxlELCFnw',
#   'LKofYgExM',
#   'TmVbIR',
#   'pgEaqX'],
#  ['pwmkyAklSi',
#   'iSUAEXTe',
#   'KEDKKPjLzQ',
#   'ugFQzYeqIl',
#   'UFDtFe',
#   'egKvqhf',
#   'wZDlNa',
#   'WSyYVuSv',
#   'OfrdkZrY',
#   'dvkoqSt',
#   'BPzHlnNZD',
#   'bzbyS',
#   'XtHSBty',
#   'AHrKIcDAHj',
#   'WlMPQ',
#   'QZDRt',
#   'HvBGsYxsb',
#   'PZotc',
#   'yPitBZSAqU',
#   'qXZdH',
#   'xgvErKNQpX',
#   'bjYLDsGdaq',
#   'tvUdaSi',
#   'rzRnCKd',
#   'apdWjW',
#   'eqxKMBhER',
#   'JwYws',
#   'kGvyndn',
#   'XGUqHp',
#   'ERbgT',
#   'VwqFFkc',
#   'onRVzugydh',
#   'CnfxU',
#   'obuOdh',
#   'VrGwpTRAXm',
#   'AyQAhGvFIh',
#   'KYlWFQMLmB',
#   'mMWLJTQ',
#   'VIJRxCZsl',
#   'LvWGjATNiL',
#   'wRlWNNaxA',
#   'ZuHGLGipqh',
#   'FsHjYN',
#   'XEknB',
#   'VJLnaRt',
#   'jJJDbODyvp',
#   'PVthc',
#   'fCuFDZC',
#   'ruJIbWB',
#   'pImhIuzHQf',
#   'Figpikq',
#   'QibpRzAY',
#   'iTbEU',
#   'eYdin',
#   'dfJqCmKnI',
#   'kPbvPT',
#   'jWbIsP',
#   'SGEco',
#   'YrxeNRzo',
#   'BrOQU',
#   'dHoll',
#   'jjmfNNFP',
#   'vmVFCZp',
#   'pUdJzl',
#   'ACalf',
#   'MCkTjN',
#   'UjwcJA',
#   'ehzmRHFJoT',
#   'RsxmexLtM',
#   'TUekMPndM',
#   'ndCFM',
#   'wBiHn',
#   'qFLxqiTqAT',
#   'iLosFFEHft',
#   'bedJkavayc',
#   'DgWGGiE',
#   'gIWNYpg',
#   'RuBuJ',
#   'PkTYJam',
#   'svtRRaYxLX',
#   'FTXqWaGEs',
#   'kUpwPhjyys',
#   'TqggEIVOLv',
#   'NaMrdOJK',
#   'rNjokB',
#   'fubLUVD',
#   'gkzcb',
#   'iaeaEWqj',
#   'GoqHq',
#   'MzYfu',
#   'kQBrPAs',
#   'gDKsk',
#   'VFoDdbvpa',
#   'tTQJpFir',
#   'ajEfuSLI',
#   'KvJHmI',
#   'ubFlqN',
#   'nxuqgPBUu',
#   'VBhGjkg',
#   'PXEAh',
#   'VdOAjNXOJP',
#   'uUZgwAn',
#   'IAIiLS',
#   'bwftlwDfLo',
#   'njPbaZwd',
#   'Uwlbpe',
#   'yDJXFbv',
#   'LjFULE',
#   'QvAHYuav',
#   'UZQGMwU',
#   'ohAMFyk',
#   'mpzxgraSX',
#   'KzhGuScRn',
#   'pTIhwtirA',
#   'NzxxLwiNXv',
#   'GGrZuPtJz',
#   'MroaGC',
#   'IYKdA',
#   'iRMmt',
#   'WpZzyZa',
#   'YyrcLfUMre',
#   'BVFWzEuzQk',
#   'wkYbIZfa',
#   'wOWMd',
#   'WvpBJwA',
#   'JZBQaoI',
#   'MGgWTCY',
#   'XrpobvQgVR',
#   'ztasDN',
#   'jolzne',
#   'hUZntSn',
#   'pouNUy',
#   'GeABUeG',
#   'saPrJeOq',
#   'iEKAw',
#   'YHBszbWg',
#   'hAdVwRTa',
#   'aKwkbyiG',
#   'xYBLZl',
#   'xEQlxfM',
#   'ESFtx',
#   'xGRxVxGZPr',
#   'bkeqHJt',
#   'fbObzRQ',
#   'ThFLeE',
#   'qPgmhBFGi',
#   'yNFJeyaRd',
#   'JzycB',
#   'zSGEvJprF',
#   'xqvAsoqn',
#   'JlwEF',
#   'KegqUDtTV',
#   'MWGEBihwNI',
#   'HDRpQZqY',
#   'DRQNPtM',
#   'uLphxTWeP',
#   'qfGPFwHci',
#   'clxrmYOON',
#   'olIbNlAe',
#   'WKtQipCHPz',
#   'aHDtGc',
#   'rYBIbI',
#   'qeBGJVmeeO',
#   'PwYdV',
#   'pjYJS',
#   'iCglJrDz',
#   'zOGOXEJc',
#   'beAGB',
#   'lEKrhYBCG',
#   'DmYDfWvPhu',
#   'qVIENRXpJ',
#   'DtioFSy',
#   'zJDQE',
#   'HTmDw',
#   'iRVMUlEy',
#   'bCZrrGlB',
#   'UWezePo',
#   'QExyzXeA',
#   'KvWePCsr',
#   'hvxLPmLQcq',
#   'TJZLGitka',
#   'mltDznG',
#   'eAEKTXOvf',
#   'ZGMLSByRJ',
#   'SUXbyXVBho',
#   'EcWgeeyoDN',
#   'hsjOB',
#   'WHhqRtXPWJ',
#   'MRzkZHDVFJ',
#   'uCiRlgHzjr',
#   'uOJvOov',
#   'EdBxVDs',
#   'ZUXeKubz',
#   'CwNxzrMQZd',
#   'oiCNK',
#   'IOGJlT',
#   'UKTVr',
#   'kgWuTyXF',
#   'CJkKCCuWMO',
#   'aTZaZxCGL',
#   'DGdKAfMxo',
#   'ZdCWW',
#   'wMesxXw',
#   'FtBLTcFXx',
#   'WZrmn',
#   'UXsXHVlvF',
#   'FfYfeiOHr',
#   'UfJmJDvXEP',
#   'fzZQPlXi',
#   'oklKCU',
#   'cxafRlt',
#   'xwIlWXa',
#   'cjOathLy',
#   'fzAArhEx',
#   'aibbTtCVW',
#   'ywuol',
#   'GhKXpJqT',
#   'PSOsoa',
#   'uWJGkCc',
#   'QEkwxLBY',
#   'JVKnPDpP',
#   'Dmewf',
#   'wurZdUrOEn',
#   'hXfdY',
#   'TOszFDc',
#   'cDJYdtR',
#   'zemDblr',
#   'iuJPqRCdi',
#   'MkKZu',
#   'MJeTNPIJ',
#   'fbxgwruT',
#   'ZLPzeJQ',
#   'PuHYFsTH',
#   'GNPUXnCdI',
#   'JHtweAnrC',
#   'AwLhikvWQ',
#   'ShSDKdoY',
#   'PmQvlgC',
#   'lYoGkTRvzM',
#   'yeuzmKb',
#   'ReYoMrviTV',
#   'BXNKsNuzm',
#   'codXHhpdW',
#   'CTDDFJa',
#   'RzrsAIwT',
#   'KYQaENaH',
#   'JTsdLeciSX',
#   'cebnWOnHI',
#   'LmIrh',
#   'ipmpDvNhj',
#   'MuSzH',
#   'hYAkeEs',
#   'lItmDviLg',
#   'YBzPemZix',
#   'DvZkLBhi',
#   'cunvtL',
#   'IGIjrVWl',
#   'ONtlklRrr',
#   'oUtOnczMow',
#   'hFsovdI',
#   'PxLvoWHG',
#   'DfsLfK',
#   'jjNpjGDvBZ',
#   'MHprBgep',
#   'FElIJuCbR',
#   'HjwcPUD',
#   'VZrmixV',
#   'qNJNN',
#   'SEgnfmouN',
#   'MUeVFIz',
#   'dNnjcGi',
#   'BsxmzJo',
#   'XkoFU',
#   'RukVeTvXhI',
#   'iwTwwC',
#   'vaGcCd',
#   'PQxCRlKvSL',
#   'qqtaZub',
#   'wgIQTmlBgv',
#   'OGscId',
#   'tObCjnon',
#   'vWBTDBCORj',
#   'McyLDIJriT',
#   'qrrWCUKQ',
#   'vbXQfD',
#   'XprYunHR',
#   'HextXq',
#   'PuCIhshgyn',
#   'WxgFJMoUxR',
#   'MBkYyP',
#   'cTNkS',
#   'aOIosBFe',
#   'KaEog',
#   'PRNwDyCo',
#   'hwZsxlTrX',
#   'PJHLWdIJu',
#   'OxlELCFnw',
#   'LKofYgExM',
#   'TmVbIR',
#   'pgEaqX']]

# %% [markdown]
# #### Insert Time Taken

# %%
def InsertTime2(classname, datalist):
    # Remove Duplicates
    seen = {}
    uniqueDatas = []
    for e in datalist:
        if e not in seen:
            seen[e] = True
            uniqueDatas.append(e)
    
    algorithm = classname()
    if str(classname) == str(BloomFilterSet):
        algorithm.initVariables(len(datalist), 0.01, hashFunctions)

    InsertStart = timeit.default_timer()
    res = []
    for word in uniqueDatas:
        # Remove Missing Values
        if word is not None:
            inserted = algorithm.insertElement(word)
            res.append(inserted)
    InsertEnd = timeit.default_timer()
    InsertTime = InsertEnd - InsertStart
    print("Insert time taken is :", InsertTime)
    return algorithm, res

# %%
SEQSyn, BSTSyn, RBTSyn, BTSyn = [], [], [], []
InsertRes1, InsertRes2, InsertRes3, InsertRes4 = [], [], [], []
for i in range(len(SyntheticDataList)):
    print("For", SyntheticDataNames[i], "Case: ")
    print("Sequential Search: ")
    SEQ, res1 = InsertTime2(SequentialSearchSet, SyntheticDataList[i])
    SEQSyn.append(SEQ)
    InsertRes1.append(res1)
#     print("Binary Search Tree: ")
#     BST, res2 = InsertTime2(BinarySearchTreeSet, SyntheticDataList[i])
#     BSTSyn.append(BST)
#     InsertRes2.append(res2)
#     print("Balanced Search Tree: ")
#     RBT, res3 = InsertTime2(BalancedSearchTreeSet, SyntheticDataList[i])
#     RBTSyn.append(RBT)
#     InsertRes3.append(res3)
    print("Bloom Filter: ")
    BT, res4 = InsertTime2(BloomFilterSet, SyntheticDataList[i])
    BTSyn.append(BT)
    InsertRes4.append(res4)
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# Out:
# For Normal Case:
# Sequential Search:
# Insert time taken is : 0.026619700001901947
# Bloom Filter:
# Insert time taken is : 1.3880563999991864
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# For Long String Case:
# Sequential Search:
# Insert time taken is : 0.023791799998434726
# Bloom Filter:
# Insert time taken is : 18.018197299999883
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# For Special String Case:
# Sequential Search:
# Insert time taken is : 0.02436659999511903
# Bloom Filter:
# Insert time taken is : 1.2901741999958176
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# For Ascending Order Case:
# Sequential Search:
# Insert time taken is : 0.028609200002392754
# Bloom Filter:
# Insert time taken is : 1.277701099999831
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# For Descending Order Case:
# Sequential Search:
# Insert time taken is : 0.02921990000322694
# Bloom Filter:
# Insert time taken is : 1.3793139000044903
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# For String with missing values Case:
# Sequential Search:
# Insert time taken is : 0.012728299996524584
# Bloom Filter:
# Insert time taken is : 0.719817699995474
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# For String with duplicate values Case:
# Sequential Search:
# Insert time taken is : 0.011816299993370194
# Bloom Filter:
# Insert time taken is : 0.7024897000010242
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
# print(InsertRes1, InsertRes2, InsertRes3, InsertRes4)

# %%
# BST, ts = InsertTime2(BinarySearchTreeSet, SyntheticDataList[2])
# ts

# %% [markdown]
# ### Search Time Taken

# %%
def SearchTime2(obj, searchdata):
    res = []
    SearchStart = timeit.default_timer()
    for ws in searchdata:
        if ws is not None:
            searched = obj.searchElement(ws)
            res.append(searched)
    SearchEnd = timeit.default_timer()
    SearchTime = SearchEnd - SearchStart
    print("Search time taken is :", SearchTime)
    return res

# %%
SearchRes1, SearchRes2, SearchRes3, SearchRes4 = [], [], [], []
for i in range (len(synSearchList)):
    print("For", SyntheticDataNames[i], "Case: ")
    print("Sequential Search: ")
    SEQ, sres1 = SearchTime2(SEQSyn[i], synSearchList[i])
    SearchRes1.append(sres1)
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
    print("Binary Search Tree: ")
    BST, sres2 = SearchTime2(BSTSyn[i], synSearchList[i])
    SearchRes2.append(sres2)
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
    print("Balanced Search Tree: ")
    RBT, sres3 = SearchTime2(RBTSyn[i], synSearchList[i])
    SearchRes3.append(sres3)
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
    print("Bloom Filter: ")
    BT, sres4 = SearchTime2(BTSyn[i], synSearchList[i])
    SearchRes4.append(sres4)
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
    print("                                                 ")
# Out:
# For Normal Case:
# Sequential Search:
# Search time taken is : 0.011950699999943026
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Binary Search Tree:
# Search time taken is : 0.0011890999994648155
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Balanced Search Tree:
# Search time taken is : 0.0007524999991801451
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Bloom Filter:
# Search time taken is : 0.004684200000156125
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# For Long String Case:
# Sequential Search:
# Search time taken is : 0.01957239999956073
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Binary Search Tree:
# Search time taken is : 0.0010870000005525071
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Balanced Search Tree:
# Search time taken is : 0.0007821999997759121
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Bloom Filter:
# Search time taken is : 0.03139980000014475
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# For Special String Case:
# Sequential Search:
# Search time taken is : 0.011610600000494742
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Binary Search Tree:
# Search time taken is : 0.0010661000005711685
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Balanced Search Tree:
# Search time taken is : 0.0008282999997391016
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Bloom Filter:
# Search time taken is : 0.003964000000451051
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# For Ascending Order Case:
# Sequential Search:
# Search time taken is : 0.011570900000151596
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Binary Search Tree:
# Search time taken is : 0.047698500000478816
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Balanced Search Tree:
# Search time taken is : 0.000705000000380096
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Bloom Filter:
# Search time taken is : 0.00409250000029715
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# For Descending Order Case:
# Sequential Search:
# Search time taken is : 0.01168260000031296
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Binary Search Tree:
# Search time taken is : 0.03880699999990611
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Balanced Search Tree:
# Search time taken is : 0.0006995999992795987
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Bloom Filter:
# Search time taken is : 0.003970199999457691
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# For String with missing values Case:
# Sequential Search:
# Search time taken is : 0.012896899999759626
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Binary Search Tree:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7496/2883475570.py in <module>
#       5     print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
#       6     print("Binary Search Tree: ")
# ----> 7     BST = SearchTime2(BSTSyn[i], synSearchList[i])
#       8     print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
#       9     print("Balanced Search Tree: ")
#
# IndexError: list index out of range

# %% [markdown]
# # --------

# %%
rbt = BalancedSearchTreeSet()
rbt.insertElement('b')
rbt.insertElement('a')
rbt.insertElement('c')

print(rbt.searchElement('b'))
print(rbt.searchElement('a'))
print(rbt.searchElement('c'))
# Out:
# True
# True
# True

# %% [markdown]
# Sequential Search

# %%
# for key in files.keys():
#     seqInsertStart = timeit.default_timer()
#     for word in files[key]:
#         SEQs.insertElement(word)
#     seqInsertEnd = timeit.default_timer()
#     seqInsertTime = seqInsertEnd - seqInsertStart
#     print("Insert time taken for ", key, "is : ", seqInsertTime)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27260\2375292265.py in <module>
#       2     seqInsertStart = timeit.default_timer()
#       3     for word in files[key]:
# ----> 4         SEQs.insertElement(word)
#       5     seqInsertEnd = timeit.default_timer()
#       6     seqInsertTime = seqInsertEnd - seqInsertStart
#
# AttributeError: 'list' object has no attribute 'insertElement'

# %% [markdown]
# Sequential Search

# %%
SeqSearchStart = timeit.default_timer()
for ws in wordsforsearch:
    SEQs.searchElement(ws)
SeqSearchEnd = timeit.default_timer()
SeqSearchTime = SeqSearchEnd - SeqSearchStart
print("Search time taken for 'test-search.txt' is : ", SeqSearchTime)

# %% [markdown]
# Binary Search Tree

# %%
for key in files.keys():
    binaryInsertStart = timeit.default_timer()
    for word in files[key]:
        BSTs.insertElement(word)
    binaryInsertEnd = timeit.default_timer()
    
    binaryInsertTime = binaryInsertEnd - binaryInsertStart
    print("Insert time taken for ", key, "is : ", binaryInsertTime)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27260\3371357167.py in <module>
#       2     binaryInsertStart = timeit.default_timer()
#       3     for word in files[key]:
# ----> 4         BSTs.insertElement(word)
#       5     binaryInsertEnd = timeit.default_timer()
#       6     binaryInsertTime = binaryInsertEnd - binaryInsertStart
#
# AttributeError: 'list' object has no attribute 'insertElement'

# %% [markdown]
# Binary Search Tree

# %%
BinarySearchStart = timeit.default_timer()
for ws in wordsforsearch:
    BSTs.searchElement(ws)
BinarySearchEnd = timeit.default_timer()
BinarySearchTime = BinarySearchEnd - BinarySearchStart
print("Search time taken for 'test-search.txt' is : ", BinarySearchTime)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27260\1165406966.py in <module>
#       1 BinarySearchStart = timeit.default_timer()
#       2 for ws in wordsforsearch:
# ----> 3     BSTs.searchElement(ws)
#       4 BinarySearchEnd = timeit.default_timer()
#       5 BinarySearchTime = BinarySearchEnd - BinarySearchStart
#
# AttributeError: 'list' object has no attribute 'searchElement'

# %% [markdown]
# Balanced Search Tree

# %%
for key in files.keys():
    RedBlackInsertStart = timeit.default_timer()
    for word in files[key]:
        RBT.insertElement(word)
    RedBlackInsertEnd = timeit.default_timer()
    RedBlackInsertTime = RedBlackInsertEnd - RedBlackInsertStart
    print("Insert time taken for ", key, "is : ", RedBlackInsertTime)
# Out:
# Insert time taken for  'test1-mobydick.txt' is :  2.1321972999994614
# Insert time taken for  'test2-warpeace.txt' is :  6.030556100000467
# Insert time taken for  'test-search.txt' is :  60.04795980000017

# %% [markdown]
# Balanced Search Tree

# %%
RedBlackSearchStart = timeit.default_timer()
for ws in wordsforsearch:
    RBT.searchElement(ws)
RedBlackSearchEnd = timeit.default_timer()
RedBlackSearchTime = RedBlackSearchEnd - RedBlackSearchStart
print("Search time taken for 'test-search.txt' is : ", RedBlackSearchTime)
# Out:
# Search time taken for 'test-search.txt' is :  0.0031930999994074227

# %% [markdown]
# Bloom Filter

# %%
for key in files.keys():
    BFInsertStart = timeit.default_timer()
    for word in files[key]:
        BF.insertElement(word)
    BFInsertEnd = timeit.default_timer()
    BFInsertTime = BFInsertEnd - BFInsertStart
    print("Insert time taken for ", key, "is : ", BFInsertTime)
# Out:
# Insert time taken for  'test1-mobydick.txt' is :  2.006846799999039
# Insert time taken for  'test2-warpeace.txt' is :  5.462229099999604
# Insert time taken for  'test3-dickens.txt' is :  49.96937220000109

# %% [markdown]
# Bloom Filter

# %%
BFSearchStart = timeit.default_timer()
for word in wordsforsearch:
    BF.searchElement(word)
BFSearchEnd = timeit.default_timer()
BFSearchTime = BFSearchEnd - BFSearchStart
print("Search time taken for 'test-search.txt' is : ", BFSearchTime)
# Out:
# Search time taken for 'test-search.txt' is :  0.005908900000576978

# %%
a = './data/testfiles/test1-mobydick.txt'
b = './data/testfiles/test2-warpeace.txt'
c = './data/testfiles/test3-dickens.txt'
insertFiles = [a,b,c]

for file in insertFiles:
    seqInsertStart = timeit.default_timer()
    seqS.insertElement(file)
    seqInsertEnd = timeit.default_timer()
    seqInsertTime = seqInsertEnd - seqInsertStart
    print(seqInsertTime)

# %%
a = './data/testfiles/test1-mobydick.txt'
b = './data/testfiles/test2-warpeace.txt'
c = './data/testfiles/test3-dickens.txt'
d = "./data/testfiles/test-search.txt"
insertFiles = [a,b,c]
for file in insertFiles:
    seqS.insertElement(file)
    SeqSearchStart = timeit.default_timer()
    seqS.searchElement(d)
    SeqSearchEnd = timeit.default_timer()
    SeqSearchTime = SeqSearchEnd - SeqSearchStart
    print(SeqSearchTime)
# Out:
# False ,['zero'] is not found
# 94.96285220000027
# False ,['zero'] is not found
# 106.49899989999994
# False ,['zero'] is not found
# 183.5646872999996

# %%
a = './data/testfiles/test1-mobydick.txt'
b = './data/testfiles/test2-warpeace.txt'
c = './data/testfiles/test3-dickens.txt'
insertFiles = [a,b,c]

for file in insertFiles:
    BSTInsertStart = timeit.default_timer()
    rbt.insertElement(file)
    BSTInsertEnd = timeit.default_timer()
    BSTInsertTime = BSTInsertEnd - BSTInsertStart
    print(BSTInsertTime)
# Out:
# 1.3200000012147939e-05
# 1.6899999991437653e-05
# 4.79999994240643e-06

# %%
def insert_file():
    a = './data/testfiles/test1-mobydick.txt'
    b = './data/testfiles/test2-warpeace.txt'
    c = './data/testfiles/test3-dickens.txt'
    insertFiles = [a,b,c]
    for file in insertFiles:
        BSTInsertStart = timeit.default_timer()
        bst.insertElement(file)
        BSTInsertEnd = timeit.default_timer()
        BSTInsertTime = BSTInsertEnd - BSTInsertStart
        print(BSTInsertTime)

def insert_real_data_test(words, bst):
    BSTInsertStart = timeit.default_timer() 
    for word in words:
        bst.insertElement(word)
    BSTInsertEnd = timeit.default_timer()
    BSTInsertTime = BSTInsertEnd - BSTInsertStart
    print("Insert time: ", BSTInsertTime)

def search_words_in_set(words, bst):
    BSTSearchStart = timeit.default_timer() 
    for word in words:
        bst.searchElement(word)
    BSTSearchEnd = timeit.default_timer()
    BSTSearchTime = BSTSearchEnd - BSTSearchStart
    print("Search time (word already in set): ", BSTSearchTime)


def search_words(words, bst):
    BSTSearchStart = timeit.default_timer() 
    for word in words:
        bst.searchElement(word)
    BSTSearchEnd = timeit.default_timer()
    BSTSearchTime = BSTSearchEnd - BSTSearchStart
    print("Search time (test-search words): ", BSTSearchTime)


bst1 = BinarySearchTreeSet()
bst2 = BinarySearchTreeSet()
bst3 = BinarySearchTreeSet()

insert_real_data_test(words, bst1)
insert_real_data_test(words2, bst2)
insert_real_data_test(words3, bst3)

search_words_in_set(words, bst1)
search_words_in_set(words2, bst2)
search_words_in_set(words3, bst3)

search_words(words, bst1)
search_words(words2, bst2)
search_words(words3, bst3)

# %%
a = './data/testfiles/test1-mobydick.txt'
b = './data/testfiles/test2-warpeace.txt'
c = './data/testfiles/test3-dickens.txt'
d = "./data/testfiles/test-search.txt"
insertFiles = [a,b,c]

for file in insertFiles:
    rbt.insertElement(file)
    BSTSearchStart = timeit.default_timer()
    rbt.searchElement(d)
    BSTSearchEnd = timeit.default_timer()
    BSTSearchTime = BSTSearchEnd - BSTSearchStart
    print(BSTSearchTime)
# Out:
# 2.4000000848900527e-06
# 8.000001798791345e-07
# 7.000003279244993e-07

# %%
# 1st version

class TestDataGenerator():

    def __init__(self):
            self.syntheticData = []
            
            pass           
            
    # sythetic data -- integers:
    def generateNum(self, size):
        for _ in range(size):
            item = random.randrange(0,1000000)
            self.syntheticData.append(item)
        print(self.syntheticData) # delete when it's finished
        return self.syntheticData   
    
    # sythetic data -- 4-letter string (randomly without real meanings):
    def generateString(self,size):
        letters = string.ascii_lowercase
        for letter in letters:
            for _ in range(size):
                letter1 = ''.join(random.choice(letters))
                letter2 = ''.join(random.choice(letters))
                letter3 = ''.join(random.choice(letters))
                stringGenerated = letter + letter1 + letter2 + letter3
                self.syntheticData.append(stringGenerated)
        print(self.syntheticData) # delete when it's finished
        return self.syntheticData

toGenerate = TestDataGenerator()
toSearch = TestDataGenerator()

toGenerate.generateString(1)
toSearch.generateNum(10)
# Out:
# ['aiet', 'bbrr', 'csgv', 'dmux', 'ezat', 'fxew', 'gfhm', 'hyjd', 'iaby', 'jwzk', 'kshf', 'lwrx', 'mdrk', 'nbfd', 'ogxs', 'pgyh', 'qyvb', 'rxeo', 'sjff', 'tosj', 'ukjl', 'vhgj', 'wlgn', 'xtyg', 'yvhy', 'zchc']
# [634667, 496119, 767303, 410927, 353639, 23654, 399978, 520985, 373862, 726654]
# [634667, 496119, 767303, 410927, 353639, 23654, 399978, 520985, 373862, 726654]
