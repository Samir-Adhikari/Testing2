# %% [markdown]
# # Set Membership Coursework

# %%
import random
import string
import timeit
from bitarray import bitarray

# %% [markdown]
# ## 1. Implementeation

# %% [markdown]
# ### Sequential Search

# %%
class SequentialSearchSet():
    
    def __init__(self):
        self.items = []           
        
    def insertElement(self, element):
        self.items.append(element)
        return True   

    def searchElement(self, element):
        found = False     
        for item1 in self.items:
            if item1 == element:
                found = True
            else:
                found = False
        return found

# %% [markdown]
# Time Complexity:
# - Insert an element is O(n^2)
# - Search an element is O(n)
#
# Space Complexity:
# - O(n)

# %% [markdown]
# ### Binary Search Tree

# %%
class Node:
    
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

    def get(self, element):
        if self.value == element:
            return True
        elif element < self.value and self.left:
            return self.left.get(element)
        elif element > self.value and self.right:
            return self.right.get(element)
        return False

    def put(self, element):
        if self.value == None:
            self.value = element
            return True
        elif element == self.value:
            self.value = element
            return True
        elif element < self.value:
            if self.left is None:
                self.left = Node(element)
                return True
            else: 
                return self.left.put(element)
        elif element > self.value:
            if self.right is None:
                self.right = Node(element)
                return True
            else: 
                return self.right.put(element)
        return False

class BinarySearchTreeSet:
    
    def __init__(self):
        self.bst = Node(None)

    def insertElement(self, element):
        inserted = False
        inserted = self.bst.put(element) 
        return inserted

    def searchElement(self, element):     
        found = False 
        found = self.bst.get(element)
        return found

# %% [markdown]
# Time Complexity:
#
# Insert:
# - Average: O(log n)
# - Worst: O(n)
#
# Search:
# - Average: O(log n)
# - Worst: O(n)
#
# Space Complexity:
# - O(n)

# %% [markdown]
# ### Balanced Search Tree

# %%
class BalancedSearchTreeSet:
    R = True
    B = False
    # R refers to Red; B refers to Black
    
    class Nodes:
        def __init__(self, val, colour):
            self.val = val
            self.colour = colour
            self.left = None
            self.right = None
            
    def __init__(self):
        self.root = None
        
    def searchElement(self, element):
        found = False
        found = self.search(self.root, element)
        return found
    
    def search(self, node, val):
        if node is None:
            return False
        else:
            if node.val == val:
                return True
            elif node.val > val:
                return self.search(node.left, val)
            else:
                return self.search(node.right, val)
    
    def insertElement(self, element):
        inserted = False
        if self.root is None:
            self.root = self.Nodes(element, self.B)
            inserted = True
        else:
            self.root, inserted = self.insert(self.root, element)
            self.root.colour = self.B
        return inserted

    def insert(self, node, val):
        if node is None:
            return self.Nodes(val, self.R), True
        if val < node.val:
            node.left, inserted = self.insert(node.left, val)
        elif val > node.val:
            node.right, inserted = self.insert(node.right, val)
        else:
            # value already exists, do nothing
            return node, False

        # perform rotations and colour flips
        if self.isR(node.right) and not self.isR(node.left):
            node = self.leftRotate(node)
        if self.isR(node.left) and self.isR(node.left.left):
            node = self.rightRotate(node)
        if self.isR(node.left) and self.isR(node.right):
            self.flipColour(node)

        return node, inserted

    def isR(self, node):
        if node is None:
            return False
        return node.colour == self.R
    
    def leftRotate(self, node):
        x = node.right
        node.right = x.left
        x.left = node
        x.colour = node.colour
        node.colour = self.R
        return x
    
    def rightRotate(self, node):
        x = node.left
        node.left = x.right
        x.right = node
        x.colour = node.colour
        node.colour = self.R
        return x
    
    def flipColour(self, node):
        node.colour = not node.colour
        node.left.colour = self.B
        node.right.colour = self.B

# %% [markdown]
# Time Complexity:
#
# - Insert an element is O(log n)
# - Search an element is O(log n)
#
# Space Complexity:
#
# - O(n)

# %% [markdown]
# ### 2-3 Search Tree

# %%
class Node2:
    def __init__(self, values, parent = None):
        self.values = [values]
        self.parent = parent
        self.child = []
    
    def is_leaf(self):
        return len(self.child) == 0
    
    def __lt__(self, other):
        return self.values[0] < other.values[0]
    
    def add(self, new_node):
        for child in new_node.child:
            child.parent = self
        self.values.extend(new_node.values)
        self.values.sort()
        self.child.extend(new_node.child)
        if len(self.child)>1:
            self.child.sort()
        if len(self.values)>2:
            self.split()
    
    def _insert(self, new_node):
        if self.is_leaf() == True:
            if new_node.values[0] not in self.values:
                self.add(new_node)
                return True
            return False
        elif new_node.values[0] > self.values[-1]:
            return self.child[-1]._insert(new_node)
        else:
            for i in range(0, len(self.values)):
                if new_node.values[0] < self.values[i]:
                    return self.child[i]._insert(new_node)
                    
    
    def split(self):
        left_child = Node2(self.values[0], self)
        right_child = Node2(self.values[2], self)
        if len(self.child) != 0:
            self.child[0].parent = left_child
            self.child[1].parent = left_child
            self.child[2].parent = right_child
            self.child[3].parent = right_child
            left_child.child = [self.child[0], self.child[1]]
            right_child.child = [self.child[2], self.child[3]]
        
        #promote middle node
        self.child = [left_child]
        self.child.append(right_child)
        self.values = [self.values[1]]

        if self.parent is not None:
            if self in self.parent.child:
                self.parent.child.remove(self)
            self.parent.add(self)
        else:
            left_child.parent = self
            right_child.parent = self

    def _find(self, element):
        if element in self.values:
            return True
        elif self.is_leaf() == True:
            return False
        elif element > self.values[-1]:
            return self.child[-1]._find(element)
        else:
            for i in range (0, len(self.values)):
                if element < self.values[i]:
                    return self.child[i]._find(element)
        
class TwoThreeBSTSet:
    def __init__(self):
        self.root = None
    
    def insertElement(self, element):
        inserted = False
        new_node = Node2(element)
        if self.root is None:
            self.root = new_node
        else:
            inserted = self.root._insert(new_node)
            if not inserted:
                return False
            #re-establishes the root to the top of the tree
            while self.root.parent is not None:
                self.root = self.root.parent
        return True 
    
    def searchElement(self, element):
        found = False
        found =self.root._find(element)
        return found

# %% [markdown]
# Time Complexity:
# - Insert an element is O(log n)
# - Search an element is O(log n)
#
# Space Complexity:
# - O(n)

# %% [markdown]
# ### Bloom Filter

# %%
class BloomFilterSet:
    
    def __init__(self):
        self.HashFunctions = None
        self.hashNum = 0
        self.size = 0
        self.bitArray = None
    
    def initVariables(self, ItemNum, FPProb, HashFunctions):
        # ItemNum : int, Number of items expected to be stored in bloom filter
        # FPProb : float, False Positive probability in decimal
        # HashFunctions: list, number of hash functions to use
        self.HashFunctions = HashFunctions
        self.hashNum = len(HashFunctions)
        # Total size of bit array
        self.size = self.getSize(ItemNum, FPProb)
        # Bit array of given size, and initialize all bits as 0 (False)
        self.bitArray = bitarray(self.size)
        self.bitArray.setall(0)

    def insertElement(self, element):
        inserted = False
        tempIndex = []
        for function in self.HashFunctions:
            index = function(element) % self.size
            self.bitArray[index] = True
            tempIndex.append(self.bitArray[index])
        if False not in tempIndex:
            inserted = True
        return inserted

    def searchElement(self, element):
        found = False
        count = 0
        for function in self.HashFunctions:
            index = function(element) % self.size
            if not self.bitArray[index] == False:
                count += 1
            else:
                return found
        if count == len(self.HashFunctions):
            found = True
        return found

    def getSize(self, n, p):
        # m = -(n * lg(p)) / (lg(2)^2)
        # n : number of items expected to be stored in filter
        # p : False Positive probability in decimal
        m = -(n * self.myLog(p)) / (self.myLog(2) ** 2)
        return int(m)
    
    def myLog(self, n):
        if n <= 0:
            raise ValueError("logarithm is undefined for non-positive values")
        if n == 1:
            return 0
        if n < 1:
            # log(xn) = -log(1/n) for n < 1
            return -self.myLog(1 / n)
        # Use the taylor series approximation for log(n) where |n-1| < 1
        taylor = (n - 1) / float(n + 1)
        term = taylor
        total = taylor
        num = 1
        while abs(term) > 1e-15:
            num += 2
            term *= taylor * taylor / float(num * (num - 1))
            total += term
        return 2 * total

# %%
def builtinHash(string):
    return hash(string)

def bernsteinHash(string):
    hashValue = 5381
    for char in string:
        hashValue = ((hashValue << 5) + hashValue) + ord(char)
    return hashValue

def fnvHash(string):
    hashValue = 2166136261
    for char in string:
        hashValue = (hashValue * 16777619) ^ ord(char)
    return hashValue

def jenkinsHash(string):
    hashValue = 0
    for char in string:
        hashValue += ord(char)
        hashValue += (hashValue << 10)
        hashValue ^= (hashValue >> 6)
    hashValue += (hashValue << 3)
    hashValue ^= (hashValue >> 11)
    hashValue += (hashValue << 15)
    return hashValue

def djb2Hash(string):
    hashValue = 5381
    for char in string:
        hashValue = ((hashValue << 5) + hashValue) + ord(char)
    return hashValue

def sdbmHash(string):
    hashValue = 0
    for char in string:
        hashValue = ord(char) + (hashValue << 6) + (hashValue << 16) - hashValue
    return hashValue

def fnv1aHash(string):
    hashValue = 2166136261
    for char in string:
        hashValue ^= ord(char)
        hashValue *= 16777619
    return hashValue

# %%
Alphabets = list(string.ascii_letters)
randomword = []
for a in range(10000):
    temp = ''.join(random.choice(Alphabets) for t in range(random.randint(100, 200)))
    randomword.append(temp)

functions = [builtinHash, bernsteinHash, fnvHash, jenkinsHash, 
             djb2Hash, sdbmHash, fnv1aHash]
bf = BloomFilterSet()
bf.initVariables(10000, 0.01, functions)
testnum = 0
for ws in randomword:
    if bf.searchElement(ws) == True:
        testnum += 1

print("The False-Positive-Rate: ", testnum / len(randomword))
# Out:
# The False-Positive-Rate:  0.0

# %% [markdown]
# Time Complexity:
# - Creating the Bloom filter is O(kn)
# - Insert and Search an element: O(k)
# - k is the number of hash functions and n is the number of elements
#
# Space Complexity:
# - O(kb), where k is the number of hash functions and b is the bits number

# %% [markdown]
# ## 2. Experimentally Evaluation

# %% [markdown]
# ### Using Real Data

# %%
def ReadFile(filepath):
    with open(filepath) as f:
        for line in f:
            words = line.strip().split()
    return words

# %%
words1 = ReadFile("./data/testfiles/test1-mobydick.txt")
words2 = ReadFile("./data/testfiles/test2-warpeace.txt")
words3 = ReadFile("./data/testfiles/test3-dickens.txt")

files = {"'test1-mobydick.txt'": words1, "'test2-warpeace.txt'": words2,
         "'test3-dickens.txt'": words3}
print(len(words1), len(words2), len(words3))
# Out:
# 209329 564236 5149661

# %%
wordsforsearch = []
with open("./data/testfiles/test-search.txt") as fsearch:
    for line in fsearch:
        wordsforsearch.append(line.strip())
        
len(wordsforsearch)
# Out:
# 544

# %%
hashFunctions = [builtinHash, bernsteinHash, fnvHash, jenkinsHash, 
                 djb2Hash, sdbmHash, fnv1aHash]

# %% [markdown]
# #### The total amount of time of all insert operations

# %%
def InsertTime(classname, datadict):
    res = []
    classlist = []
    
    for key in datadict.keys():
        tempdata = datadict[key]
        algorithm = classname()
        if str(classname) == str(BloomFilterSet):
            algorithm.initVariables(len(tempdata), 0.01, hashFunctions)

        seen = {}
        InsertStart = timeit.default_timer()
        for word in tempdata:
            if word is not None and word not in seen:
                seen[word] = True
                inserted = algorithm.insertElement(word)
                res.append(inserted)
        InsertEnd = timeit.default_timer()
        InsertTime = InsertEnd - InsertStart
        print("Insert time taken for", key, "is :", InsertTime)
        classlist.append(algorithm)
    return classlist, res

# %%
# Sequential Search
SEQs, res = InsertTime(SequentialSearchSet, files)
res
# Out:
# Insert time taken for 'test1-mobydick.txt' is : 0.03130710000550607
# Insert time taken for 'test2-warpeace.txt' is : 0.07976359999884153
# Insert time taken for 'test3-dickens.txt' is : 0.6486728999952902
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  ...]

# %%
# Binary Search Tree
BSTs, res = InsertTime(BinarySearchTreeSet, files)
res
# Out:
# Insert time taken for 'test1-mobydick.txt' is : 0.17177070000616368
# Insert time taken for 'test2-warpeace.txt' is : 0.7194921000045724
# Insert time taken for 'test3-dickens.txt' is : 1.3332328999968013
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  ...]

# %%
# Balanced Search Tree
RBTs, res = InsertTime(BalancedSearchTreeSet, files)
res
# Out:
# Insert time taken for 'test1-mobydick.txt' is : 0.42829019999771845
# Insert time taken for 'test2-warpeace.txt' is : 0.3952906000049552
# Insert time taken for 'test3-dickens.txt' is : 3.344172199998866
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  ...]

# %%
# Balanced Search Tree -- 2-3 Search Tree
TTSTs, res = InsertTime(TwoThreeBSTSet, files)
res
# Out:
# Insert time taken for 'test1-mobydick.txt' is : 0.8376441000000341
# Insert time taken for 'test2-warpeace.txt' is : 0.32367539999540895
# Insert time taken for 'test3-dickens.txt' is : 4.147186800000782
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  ...]

# %%
# Bloom Filter
BFs, res = InsertTime(BloomFilterSet, files)
res
# Out:
# Insert time taken for 'test1-mobydick.txt' is : 0.297156200002064
# Insert time taken for 'test2-warpeace.txt' is : 0.32849069999792846
# Insert time taken for 'test3-dickens.txt' is : 1.8756322999979602
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  ...]

# %% [markdown]
# #### The total amount of time of search operations

# %%
def SearchTime(objects, searchdata):
    res = []
    for obj in objects:
        tempres = []
        SearchStart = timeit.default_timer()
        for ws in searchdata:
            if ws is not None:
                searched = obj.searchElement(ws)
                tempres.append(searched)
        SearchEnd = timeit.default_timer()
        SearchTime = SearchEnd - SearchStart
        print("Search time taken for 'test-search.txt' in file", 
              objects.index(obj)+1, "is :", SearchTime)
        res.append(tempres)
    return res

# %%
# Sequential Search Tree
SearchTime(SEQs, wordsforsearch)
# Out:
# Search time taken for 'test-search.txt' in file 1 is : 0.133109999995213
# Search time taken for 'test-search.txt' in file 2 is : 0.09881110000424087
# Search time taken for 'test-search.txt' in file 3 is : 0.3563752000045497
# [[False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False]]

# %%
# Binary Search Tree
SearchTime(BSTs, wordsforsearch)
# Out:
# Search time taken for 'test-search.txt' in file 1 is : 0.0028355999966152012
# Search time taken for 'test-search.txt' in file 2 is : 0.002892299999075476
# Search time taken for 'test-search.txt' in file 3 is : 0.002479700000549201
# [[False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False]]

# %%
# Balanced Search Tree
SearchTime(RBTs, wordsforsearch)
# Out:
# Search time taken for 'test-search.txt' in file 1 is : 0.0051075999945169315
# Search time taken for 'test-search.txt' in file 2 is : 0.0020838999989791773
# Search time taken for 'test-search.txt' in file 3 is : 0.002711000000999775
# [[False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False]]

# %%
# Balanced Search Tree -- 2-3 Search Tree
SearchTime(TTSTs, wordsforsearch)
# Out:
# Search time taken for 'test-search.txt' in file 1 is : 0.0046432000017375685
# Search time taken for 'test-search.txt' in file 2 is : 0.004830300000321586
# Search time taken for 'test-search.txt' in file 3 is : 0.005131000005349051
# [[False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False]]

# %%
# Bloom Filter
SearchTime(BFs, wordsforsearch)
# Out:
# Search time taken for 'test-search.txt' in file 1 is : 0.004998399999749381
# Search time taken for 'test-search.txt' in file 2 is : 0.005291099994792603
# Search time taken for 'test-search.txt' in file 3 is : 0.009204599999065977
# [[False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False]]

# %% [markdown]
# ### Using Synthetic Data

# %% [markdown]
# ### different conditions:
# - Duplicate cases
# - Longer String length
# - Adding numbers and symbols in each string
# - String list in ascending/descending order
# - Missing values
# - ......

# %%
class TestDataGenerator():

    def __init__(self):
        self.syntheticData = []
        self.strLen = 0
        self.percentage = 0.0

    def setParams(self, strLen, percentage):
        self.strLen = strLen
        self.percentage = percentage
    
    def generateData(self, size):
        data, data1, data2 = [], [], []
        seen1, seen2, seen3 = {}, {}, {}
        alphabets = list(string.ascii_letters)
        charlist = string.printable

        # Normal Case
        while len(data) < size:
            temp = ''.join(random.choice(alphabets) for _ in range(random.randint(4, 10)))
            if temp not in seen1:
                seen1[temp] = True
                data.append(temp)

        # Long String
        while len(data1) < size:
            temp1 = ''.join(random.choice(alphabets) for _ in range(self.strLen))
            if temp1 not in seen2:
                seen2[temp1] = True
                data1.append(temp1)

        # Special String
        while len(data2) < size:
            temp2 = ''.join(random.sample(charlist, random.randint(4, 10)))
            if temp2 not in seen3:
                seen3[temp2] = True
                data2.append(temp2)

        # Ascending Order
        data3 = self.mergeSort(data.copy())

        # String with missing values and duplicate values
        num6 = round(size * 0.2)
        temp6 = data[ : num6]
        data5 = [None if i >= num6 and random.random() < self.percentage else data[i] for i in range(size)]
        data6 = [random.choice(temp6) if i >= num6 and random.random() < self.percentage else data[i] for i in range(size)]

        # Descending Order
        data4 = data3[::-1]

        self.syntheticData.append(data)
        self.syntheticData.append(data1)
        self.syntheticData.append(data2)
        self.syntheticData.append(data3)
        self.syntheticData.append(data4)
        self.syntheticData.append(data5)
        self.syntheticData.append(data6)
        return self.syntheticData

    def mergeSort(self, arr):
        n = len(arr)
        size = 1
        while size < n:
            for i in range(0, n, 2*size):
                left = arr[i : i+size]
                right = arr[i+size : i+2*size]
                merged = []
                l = r = 0
                while l < len(left) and r < len(right):
                    if left[l] < right[r]:
                        merged.append(left[l])
                        l += 1
                    else:
                        merged.append(right[r])
                        r += 1
                merged += left[l:]
                merged += right[r:]
                arr[i : i+len(merged)] = merged
            size *= 2
        return arr

# %%
dataGenerate = TestDataGenerator()
dataGenerate.setParams(100, 0.6)
SyntheticDataList = dataGenerate.generateData(100000)
SyntheticDataList
# Out:
# [['kinO',
#   'TskkQPfDhX',
#   'YycUuT',
#   'lVUrMsB',
#   'Cwrt',
#   'YbDWZ',
#   'TRhd',
#   'zlVdrdNlD',
#   'WxDZzEi',
#   'YwipaO',
#   'QZqciAnQRU',
#   'lkFrqGJTR',
#   'OTDUWgtzD',
#   'zimdI',
#   'ktjEABA',
#   'UuFZgsg',
#   'fwSnGz',
#   'ZClLSYDK',
#   'BaznBv',
#   'gPZdM',
#   'imLlZiyVd',
#   'mwjPbDuSf',
#   'krjZqxoUXt',
#   'RxagPMV',
#   'CHOKzLIO',
#   'KbSxBrAAFk',
#   'rTvCHp',
#   'NcFWip',
#   'GdYw',
#   'kOCBngwPq',
#   'XYNwHBfNF',
#   'pUGUmhq',
#   'EhsM',
#   'xmjebi',
#   'zxJdqwxSK',
#   'Qulomuuer',
#   'gbbiFtCio',
#   'DUrR',
#   'TARZeBQLR',
#   'feqRKA',
#   'KtxsAQi',
#   'ZNspKn',
#   'opDbnz',
#   'LrfD',
#   'iubqtVz',
#   'LUqkjo',
#   'vseDdjqC',
#   'Gscx',
#   'RkUxdzcpI',
#   'KVCOpQLwY',
#   'vidvp',
#   'ICpS',
#   'ufrZoPnGvJ',
#   'zGttj',
#   'hAjrIo',
#   'MkltV',
#   'trbuDH',
#   'xheNbuN',
#   'oRbnhGUQPH',
#   'GCue',
#   'KSDSPT',
#   'iUJnEY',
#   'gDQq',
#   'EhJC',
#   'QYAjNCxCC',
#   'IXZKmBkEF',
#   'wekkYhy',
#   'kPzxBX',
#   'WDwAm',
#   'ljvnvUwQx',
#   'kZNgt',
#   'PsOh',
#   'CrwdwZiba',
#   'jzgOuCUKM',
#   'sGkx',
#   'qHhkar',
#   'GnWfiiKGND',
#   'komzMxvtgL',
#   'jdlgDlgAqi',
#   'UQRZLGED',
#   'GSRcAb',
#   'SwtxuJUBSu',
#   'nIgcD',
#   'BrPK',
#   'RapMYdSwE',
#   'DStU',
#   'kVJz',
#   'vhoyFfc',
#   'TZTARIlZV',
#   'OBpgh',
#   'ogfYJ',
#   'NMBcLZZTNB',
#   'YSXjWATxn',
#   'BctXcCKgB',
#   'JwxdMdX',
#   'RnPKwBqckd',
#   'ILEnXBVCgQ',
#   'HLkmcMd',
#   'IoVdcUVPG',
#   'MGgZcn',
#   'GoZcBg',
#   'aLWoxr',
#   'ufTPOX',
#   'zKpihN',
#   'ZtfJoW',
#   'wOtZUTS',
#   'pElCcQdoxy',
#   'rTjh',
#   'dxBbrrj',
#   'LInThGtUg',
#   'bhLkWYIv',
#   'LsPEtRhEJ',
#   'XqXnaT',
#   'bkgy',
#   'kHcRsYKqse',
#   'TtxyFsH',
#   'XtNWkVmbzM',
#   'xdmZfcgQcw',
#   'QFMNPlBOSn',
#   'yutJwvQM',
#   'rzmbroRk',
#   'TTEAoAXEVU',
#   'jNCh',
#   'IscdMZcU',
#   'pIgHlzQob',
#   'YFagpBHcwS',
#   'jhiXLeJ',
#   'gNgffFgY',
#   'tnEUq',
#   'loVgIHY',
#   'hwDo',
#   'IpBfzkPXs',
#   'BSHc',
#   'mFAXwany',
#   'sUiDd',
#   'SoiNs',
#   'AsvqxBH',
#   'kZqxs',
#   'xslpU',
#   'HzGDe',
#   'JtFTUUiBuJ',
#   'NFIkRuyv',
#   'SBkRI',
#   'NUzyXgdb',
#   'IOaL',
#   'BYzO',
#   'jntD',
#   'YtxibFWmX',
#   'zqiqEBFmBz',
#   'RQeeQHjTJ',
#   'OHtGD',
#   'PylmTaE',
#   'vMzhHaLAyi',
#   'KHkp',
#   'sFLnZ',
#   'bpHTDwrb',
#   'vtaxF',
#   'Qqwhzxc',
#   'hrFvBwl',
#   'epTyHzTol',
#   'wTFlo',
#   'NZIlMMqn',
#   'HMCVPdJ',
#   'AaZq',
#   'TLLH',
#   'zRRamxEP',
#   'zUZTAVP',
#   'wPrP',
#   'sbLLAkt',
#   'ABVk',
#   'RtVinm',
#   'DxdKIVYKn',
#   'tQQZi',
#   'hNUaPfjzcu',
#   'azhnyNEUdf',
#   'HuuzjaiQv',
#   'dbrNWFAjP',
#   'ZQJHSXNm',
#   'VEXE',
#   'NkJv',
#   'ITsIOko',
#   'elCHjxA',
#   'jBwgjDn',
#   'BFjIB',
#   'AJxss',
#   'cdnVbODSOH',
#   'nYWOr',
#   'RcTxj',
#   'oMzJEHL',
#   'xuVm',
#   'FPxJxhYQiV',
#   'CFUQJmsbNh',
#   'LsoQyBw',
#   'xtmkjUnGpg',
#   'PbOxLAFqCJ',
#   'KoKx',
#   'ETrMq',
#   'yoTdGvheD',
#   'dNErnoTC',
#   'FXFjFHO',
#   'OiqH',
#   'miPzacI',
#   'paAKINnin',
#   'GrykLiS',
#   'mTjyCbl',
#   'KeMHSdq',
#   'swykqZdf',
#   'XbuHu',
#   'DAFR',
#   'EADSq',
#   'IjhGG',
#   'qZCUIbXLU',
#   'QOTTDCU',
#   'wYbJ',
#   'mmnnQ',
#   'LujF',
#   'ILpoxZ',
#   'saFGA',
#   'uVeOtAb',
#   'OeWDFN',
#   'UnWPjXg',
#   'EtaQRL',
#   'JmJTJlyKr',
#   'UkMCCYAzmT',
#   'khVGd',
#   'XQfS',
#   'XZlkC',
#   'WgCp',
#   'uTrCEShEa',
#   'DfUePyLua',
#   'LGLVe',
#   'ZIJmoPGQUT',
#   'unlUxAdU',
#   'bchVry',
#   'Ofap',
#   'nHgy',
#   'cVRVE',
#   'HqPSJoOq',
#   'cvdxIUt',
#   'CQbmJoZgZ',
#   'PmFclpg',
#   'konxHakP',
#   'EEuXaiyqXF',
#   'VNoc',
#   'AfCGaUzqmO',
#   'dXfyc',
#   'VawMNiMJud',
#   'CpsrV',
#   'ynGBUcNljt',
#   'NUjsUHsof',
#   'nhLZwha',
#   'IcNyBtNFjE',
#   'tRcWc',
#   'efatuUkzn',
#   'sIJE',
#   'wOQUROA',
#   'NZiZ',
#   'EkeFPkL',
#   'tJtOxySwnN',
#   'OLvUG',
#   'vBBKhdNzfP',
#   'ujeHWm',
#   'gIvehA',
#   'LjUaqZNq',
#   'RYJrmCuh',
#   'VkwX',
#   'bFJvLyNQJ',
#   'AMFgsk',
#   'HYDa',
#   'UFzLxvraYt',
#   'GFTr',
#   'wNCycFkB',
#   'rKYMQPSx',
#   'QKFTHtR',
#   'YCVGaNoGUV',
#   'pyUq',
#   'gsXgCKY',
#   'XkpqQZZ',
#   'geqfacIR',
#   'OvuWcoK',
#   'TYrZprgi',
#   'GgmTeRv',
#   'aSZNjCMV',
#   'dmKiJ',
#   'WQNPVfpmD',
#   'pgXNuQnkH',
#   'KmiCDd',
#   'BOdedCMp',
#   'dFNih',
#   'zPPQzwKrd',
#   'JRFSil',
#   'lyJtDjdpIF',
#   'eeMJpoeC',
#   'ZZALEurmh',
#   'OoRszibt',
#   'wgcn',
#   'wYHs',
#   'kKQkVdtmQD',
#   'DDACDgmvE',
#   'lwgAdQ',
#   'bPnrld',
#   'qhDsOjSqW',
#   'TMkdiZ',
#   'rKFPt',
#   'bWknf',
#   'rMcUTgv',
#   'WFFBBmrsnT',
#   'zmqlocUJ',
#   'eHVbqmf',
#   'xqiszlddK',
#   'qFrKOVxDFN',
#   'UcJsHODz',
#   'iTMMTZ',
#   'PbJXhl',
#   'VkDfe',
#   'uEia',
#   'lHlibQW',
#   'WWymAiGYvR',
#   'ziixRdE',
#   'Wvmlcu',
#   'WSxf',
#   'AtBZINnTmG',
#   'aukYcq',
#   'NnVrBGH',
#   'PZWsc',
#   'iJji',
#   'WtxbztUG',
#   'ulKWpjIG',
#   'prIyrTxg',
#   'mJyj',
#   'BEbItLUMvK',
#   'huivMIEwas',
#   'GXnDkNk',
#   'LmCiziyf',
#   'iMUzpqW',
#   'wtjjWxPE',
#   'oOByH',
#   'TdPgq',
#   'BDSgBj',
#   'FwjAcEDFlJ',
#   'VjwoYY',
#   'OnWDTFbzBu',
#   'rmDq',
#   'HbhOGdX',
#   'VpcworapiI',
#   'FGwIjir',
#   'vOSxVFplnx',
#   'uNMOE',
#   'hWxmKXqV',
#   'pkGTwVQQ',
#   'XGroTO',
#   'HPAHj',
#   'eXiPD',
#   'tEmLxSCDZ',
#   'LupoVLQ',
#   'WMSOaVWzj',
#   'gJbtRevl',
#   'XbvVX',
#   'yflng',
#   'xPauvpom',
#   'WBvtpb',
#   'afWAVaSVsD',
#   'ruEqXrD',
#   'VUvmRYfV',
#   'rsNITQQ',
#   'PexQTX',
#   'CQisRvKipE',
#   'vBmw',
#   'rXDjuPiG',
#   'Haxjcyyb',
#   'kDKglUC',
#   'SMEwrYhfjR',
#   'tfzdeWkVGS',
#   'kaLs',
#   'EQBQD',
#   'sjXyErz',
#   'ItlZ',
#   'HDKoR',
#   'mWHJpRD',
#   'XBxhd',
#   'gDhZy',
#   'GVjSJPgbR',
#   'IqYwGXLEv',
#   'Tycl',
#   'xeArU',
#   'BhnIkzOC',
#   'VMRC',
#   'lYNHJLROLn',
#   'AxRpsb',
#   'fShoWpn',
#   'KKxyrua',
#   'TgJyMr',
#   'gXVCOOpKxj',
#   'czAHRfP',
#   'nuOw',
#   'PpooV',
#   'oCBhoxCfbc',
#   'oDFV',
#   'CbXHMc',
#   'CYLBays',
#   'jKpNiB',
#   'aQJvgrELpZ',
#   'pxkDlF',
#   'GfnJkIUwQP',
#   'DtVzsZA',
#   'WlTAryTgzA',
#   'PhYuyvv',
#   'imqXvz',
#   'MQnMBgu',
#   'WmWuyzcS',
#   'DfOwiTbqLY',
#   'oZRI',
#   'YiZXsvj',
#   'DwkqhL',
#   'mSIdTIqexp',
#   'myptlGjjQ',
#   'ztPkbaVbyl',
#   'SSVMeHKJ',
#   'lgJoTbWQ',
#   'WrtX',
#   'KmKoCviMeX',
#   'zTPiFGQNAN',
#   'KuFuOR',
#   'cisJ',
#   'nvzfYEW',
#   'cNHgY',
#   'xPQXqhhbnR',
#   'KZcnlcM',
#   'PBrFLJMKs',
#   'CDPTcqtb',
#   'POMMk',
#   'GzHIiDXFIz',
#   'gtpMAXU',
#   'gOHzkrlcRm',
#   'IvflwBPD',
#   'LinFk',
#   'flkP',
#   'OQJKmC',
#   'lHNCqiGk',
#   'gRWs',
#   'rbggaKLZXY',
#   'VvWnqX',
#   'RiBcnoC',
#   'azYiewsPX',
#   'NbthJS',
#   'Hyzk',
#   'LHuwj',
#   'biMOpljXRF',
#   'UnzOlWxGPr',
#   'MzaAA',
#   'pXKKBe',
#   'slFLHBuem',
#   'wyxqprbg',
#   'mzFl',
#   'AcaWhQ',
#   'lTgqbQmXtQ',
#   'QwlQ',
#   'BhzG',
#   'xbIrZQ',
#   'FdyKHG',
#   'zbIlmuIhhe',
#   'EerOChWbM',
#   'Rvpw',
#   'vZZnKt',
#   'RNnIe',
#   'FpnNyyJmCN',
#   'pbKrwhtf',
#   'TFiU',
#   'ZzWGjAkkaV',
#   'eiQXoNRV',
#   'WcwGVDNM',
#   'buboqS',
#   'QarUOhCAD',
#   'EzesBhDpT',
#   'uiHxbO',
#   'ylILqYkSql',
#   'DETGiCgt',
#   'MbdS',
#   'bPiz',
#   'tqihwFJT',
#   'CNCe',
#   'VQrxvDYFmj',
#   'ufbWVTuwtE',
#   'FMXB',
#   'wxPwxd',
#   'lCIsjdOo',
#   'XtGoRh',
#   'siJBBbrzL',
#   'NAnVNIYIH',
#   'wfGX',
#   'DmEeNNTh',
#   'DGIUwToRPj',
#   'xBbcHTYQr',
#   'qtAljUJ',
#   'sRCvZ',
#   'mAEqSOmfz',
#   'fOdscDdN',
#   'nAXXx',
#   'CPRjjk',
#   'DlFgOA',
#   'LjAAUZgJH',
#   'zVDnfHglib',
#   'JHmO',
#   'EbVI',
#   'AirLnf',
#   'gkTqfsRVT',
#   'brsqZpIDf',
#   'czhHJQ',
#   'RnUKL',
#   'RNkkUWd',
#   'vaFkY',
#   'HJIF',
#   'XHhBDSwXpY',
#   'wQIomJT',
#   'ghvHahAWTv',
#   'yIuvFmZG',
#   'HnlXA',
#   'Nefb',
#   'FHuzwJig',
#   'stzm',
#   'cmjnItE',
#   'uLWrYXIXh',
#   'bdMaayT',
#   'OQNgSwY',
#   'CxRC',
#   'kbNzGOAHRb',
#   'angi',
#   'ZKWj',
#   'ojBkTmcm',
#   'RteNX',
#   'xKsBYy',
#   'ZmTHSmOMRW',
#   'vNkURpwH',
#   'GOtlOnCl',
#   'TGckFli',
#   'mgtSkvqWNg',
#   'cVUGeMGOkf',
#   'phmX',
#   'rqwvYI',
#   'qGdETgeJ',
#   'KenciwUf',
#   'eEiJPygd',
#   'CDLVGjku',
#   'wPqzEwwuA',
#   'fMgzKrL',
#   'QPJbTFkAo',
#   'iEQM',
#   'dwOK',
#   'oGIXWLUX',
#   'bcKfYnEY',
#   'XkFS',
#   'SVMblCI',
#   'hJNpC',
#   'DacZ',
#   'JHsDD',
#   'FcAKeBpZ',
#   'NimitNofA',
#   'OSNPl',
#   'ZtKv',
#   'aDmQzKs',
#   'JmIcZF',
#   'oGguJuM',
#   'GnQMe',
#   'LXnswvWTru',
#   'dyPa',
#   'uoquWVFYE',
#   'OaQBewHHH',
#   'RLjBBMgmPT',
#   'QedCmU',
#   'PcRIbTMrnk',
#   'XwSfJ',
#   'fmkIQApr',
#   'EgZVQejI',
#   'wrDUhQh',
#   'wJurq',
#   'BMJG',
#   'HuQJq',
#   'IbBy',
#   'GTpHT',
#   'wQXn',
#   'cKmWwW',
#   'STbG',
#   'TlohMV',
#   'pUVexIS',
#   'nBQeruvQe',
#   'oTrFUj',
#   'QSEldGtHVa',
#   'dzwe',
#   'KRiwDiOLoj',
#   'ZFjlZq',
#   'cMMhcI',
#   'NlYQOADr',
#   'LkSCyVri',
#   'lYZUle',
#   'iCnbCb',
#   'ANCy',
#   'pPkVhYx',
#   'mFLmXFECs',
#   'sogSFLdLwn',
#   'ZSnRjuMElx',
#   'TjVHVPSv',
#   'NRXxk',
#   'rTKCv',
#   'VEeRzZ',
#   'wvHswmECY',
#   'pHbgelj',
#   'pDahf',
#   'GICnqgmYIc',
#   'udDtIt',
#   'DvastOVYQ',
#   'aVRJ',
#   'MwCAmnSVd',
#   'OQCIF',
#   'wVwv',
#   'exYDfTaq',
#   'MurZtCys',
#   'fUUpzLHQ',
#   'FqeGjMdo',
#   'oWjLiTG',
#   'KSht',
#   'LGnG',
#   'FkzZRu',
#   'SESPHmtO',
#   'fndQJ',
#   'ATbo',
#   'idNPLfba',
#   'BoVwPlU',
#   'Vmdrt',
#   'HceTCZvW',
#   'aNnEkEZU',
#   'qCYxwGWnI',
#   'ZmRlPGf',
#   'JzdpuQDlPk',
#   'MbQrkl',
#   'DwAjwCm',
#   'RCsR',
#   'HOQm',
#   'fphLI',
#   'kqoLZXmF',
#   'VsEIfuT',
#   'srrRlY',
#   'MPXOkKtGgx',
#   'ZFip',
#   'lSyYFPz',
#   'MVDkVEz',
#   'GUjkHhy',
#   'RFci',
#   'RMiv',
#   'RqfE',
#   'SRjTQmLO',
#   'XiCQHWK',
#   'tKnWsw',
#   'UXaxBvILY',
#   'FdWPqusoO',
#   'zARYex',
#   'lJbnzbEryi',
#   'IZCQYXi',
#   'NXwlj',
#   'kIzLFeJYp',
#   'JsBjkCeQ',
#   'NNqNEtC',
#   'HDUPtifwFC',
#   'DTZdiJx',
#   'Rlzw',
#   'iMZCHNtQT',
#   'AWYiqvV',
#   'FUprY',
#   'GOGQ',
#   'wrxfHNJx',
#   'heVtPzl',
#   'RoufnRmjz',
#   'nAYxrWhWT',
#   'dwTB',
#   'tSOKIZkLF',
#   'EPsYuVjdO',
#   'XFOjNpmpr',
#   'QVVnEx',
#   'PUWubLvO',
#   'hASSQtDMu',
#   'WVTUzBjW',
#   'qkeOXPjM',
#   'ArvyqHYnUi',
#   'lCJATDrS',
#   'wKTsEbpON',
#   'kuMLOUvOfw',
#   'hYjSlyk',
#   'IMWYAnyOqJ',
#   'VLUK',
#   'gVAHn',
#   'cABuueXDpl',
#   'fzgG',
#   'YrWMo',
#   'uRibSXRldT',
#   'OexrswkHfB',
#   'pSBgz',
#   'xcmHz',
#   'FvPElwd',
#   'iERsQnvjnY',
#   'cZNaW',
#   'rvsRyP',
#   'DpENWIp',
#   'AbTZGny',
#   'gnfSKnb',
#   'gGWOMskB',
#   'JtEk',
#   'fyaDjoiI',
#   'CESXboMig',
#   'JLHJYbaZPf',
#   'jyYBdkypN',
#   'suImsZGKlt',
#   'YdDfmMgLUB',
#   'uoyfcTcIDg',
#   'CiostQUp',
#   'huOO',
#   'otyDeBM',
#   'EzvD',
#   'mOgpq',
#   'wNQxEetkwP',
#   'xlWMqtNi',
#   'Jkswn',
#   'SuSkgy',
#   'JLbpCy',
#   'znJii',
#   'hTIYAQOnKZ',
#   'oxhoKKJHXa',
#   'cGRLXpujM',
#   'EQRXTHWU',
#   'usclTFhbSM',
#   'JNuX',
#   'cDEoomseja',
#   'enxHYGC',
#   'OZTqfYRTjU',
#   'GXBGgWvvdf',
#   'LrSsmYJTS',
#   'NeMix',
#   'BtlmtHFC',
#   'IRCCqXaBN',
#   'ieTXZlkE',
#   'wKRKjJdEt',
#   'KsGgBXWFu',
#   'jaKfCysh',
#   'upMI',
#   'iBtYkBdfi',
#   'GzUu',
#   'MAcRLYe',
#   'QJyAXlpcX',
#   'bGNrPiKD',
#   'BCSZAp',
#   'RxAqwgwW',
#   'idJTqK',
#   'VWHHNao',
#   'kDxz',
#   'VvbSJyPWzE',
#   'VFArj',
#   'pRyhUBgwX',
#   'pBGESGO',
#   'jfYet',
#   'teOqiUpWbb',
#   'NQMDUO',
#   'exMlxh',
#   'sXVBuaU',
#   'FUULcb',
#   'zAwCxdCuu',
#   'VcUZIBBcht',
#   'EVJZl',
#   'ccEiV',
#   'TbXL',
#   'mmpcKPZ',
#   'xAcj',
#   'XJBINry',
#   'nMqNxrMmE',
#   'YiAAbQFgId',
#   'hapMH',
#   'ZyjrXyPH',
#   'emHyh',
#   'KScQtJahnW',
#   'TRZsFbEt',
#   'ZMyVCyuq',
#   'RtXCNKyfyL',
#   'DvqikjXNm',
#   'DXsZjOYElo',
#   'kzMOH',
#   'keqt',
#   'EkliZN',
#   'vZmf',
#   'anQazo',
#   'haBJZSDx',
#   'JgMtFjd',
#   'fySfXtD',
#   'slAADrZaMk',
#   'QlYQTXWVH',
#   'OXcZ',
#   'hUSeDBp',
#   'tSiF',
#   'PrkVWznK',
#   'Gpzn',
#   'FgpaNsNl',
#   'SeKnmLvsvX',
#   'sUyLWM',
#   'tAml',
#   'BBnncUGg',
#   'NxqHJfdfI',
#   'vYTyLrhfR',
#   'jUijDf',
#   'GnABkP',
#   'qthrJ',
#   'zKbuWPBl',
#   'dNPMGPF',
#   'SxswS',
#   'hBguYuZ',
#   'lfFClFqa',
#   'tWXqpF',
#   'QqsIprOZo',
#   'RJmm',
#   'XPgxiKATk',
#   'ETgQPChGqk',
#   'gnXOK',
#   'VUthnYR',
#   'izyE',
#   'fGHjinWR',
#   'RIEfBLMWfe',
#   'vcmuNMaDz',
#   'GnVXawk',
#   'HzfKPDULOe',
#   'SNKWYKc',
#   'viBzl',
#   'uqPccDfkxF',
#   'kbrChs',
#   'IQPtzzFpLB',
#   'Gdjvpebg',
#   'PIXM',
#   'PwMZSh',
#   'aWoutIPoHD',
#   'UcnuI',
#   'NLinCxdT',
#   'YISTDJ',
#   'vwcjtG',
#   'XvvCseJd',
#   'GFkkM',
#   'SVHUKzRaJ',
#   'aVrydQndBj',
#   'ChUCzAJ',
#   'iBPqVEF',
#   'SyxOffldo',
#   'YkCwfYnE',
#   'Lkuio',
#   'EyRH',
#   'gVPzcWOir',
#   'yrmzkrb',
#   'IqNedLqj',
#   'JNeJ',
#   'cSuObQR',
#   'ZOHQn',
#   'ikublBnnfp',
#   'jEAPngRIU',
#   'PBBD',
#   'uZmiieoxOU',
#   'FyZUZYQ',
#   'KRoigjQ',
#   'Tpjyzmu',
#   'RQVHdPFOg',
#   'Ckxk',
#   'LGvDkGCv',
#   'nkyUWXgb',
#   'vcgzR',
#   'VCiY',
#   'bacLJaEP',
#   'wPGNRF',
#   'XESTU',
#   'PWXMHM',
#   'cgNhD',
#   'NfUj',
#   'bpNYCJu',
#   'rijNI',
#   'xwZIk',
#   'JQUVDVy',
#   'roiHTr',
#   'jvIV',
#   'OOKs',
#   'HIQNP',
#   'LCDdgjTo',
#   'WSPmZd',
#   'CtXMhkM',
#   'JlwN',
#   'RQjRRS',
#   'rOTdcmgk',
#   'liiAE',
#   'MBCIk',
#   'AyPUxevmP',
#   'ZiAsEzFYD',
#   'IsGrAUzHNC',
#   'nFdHi',
#   'avqhwq',
#   'fhyuHMAEgN',
#   'ptcXF',
#   'huaJDYakO',
#   'OsGlhtZnoV',
#   'mHBWk',
#   'XuxxmLVYhg',
#   'OjJQwURK',
#   'UyohiN',
#   'woMBf',
#   'pLPSSJj',
#   'apMRDkO',
#   'frlAip',
#   'eozbMSOHHT',
#   'mouDszD',
#   'cEtDU',
#   'ogeWwntTse',
#   'hqkoJuzJ',
#   'yRQDcAAn',
#   'qxuu',
#   'QtJqQ',
#   'ASVU',
#   'qyEevi',
#   'gQdQY',
#   'WqweoPDNQn',
#   'hUMLte',
#   'aRuUk',
#   'WtdFFCdND',
#   'QtRaq',
#   'zSua',
#   'BdgEWePON',
#   'rotp',
#   'izGZBrdqMI',
#   'dzYCkltHl',
#   'JvatMnFS',
#   'lkgnZtyV',
#   'kTHXt',
#   'pVsw',
#   'OuoqFq',
#   'qMUh',
#   'HTXHjqF',
#   'ivFK',
#   'LHPyiGGTrb',
#   'UwJWeb',
#   'vsXiNkMkM',
#   'cJUZi',
#   'LLAKsHvUn',
#   'ySTQc',
#   'WOBeNWcl',
#   'hVzdpW',
#   'joHGbsk',
#   'LcFSaXCUPi',
#   'jMMTkvrYDG',
#   'tozJK',
#   'CMDdWUW',
#   'PXRfaiZP',
#   'nteATlFmYZ',
#   'FopAWUjHS',
#   'nCCuKnmx',
#   'YEvAX',
#   'rPImk',
#   'OGeywOlC',
#   'iPsYYOkwuF',
#   'BMcfY',
#   'cCFNUVTsr',
#   'kCMKnWZ',
#   'PVnvMzn',
#   'VApip',
#   'ZFMaXENKkH',
#   'QpPZSb',
#   'ijeotW',
#   'DSZzXtEmI',
#   'bFabavXGAu',
#   'FmTCIyYEt',
#   'lcTVPuQLlI',
#   'fdPaWPJQ',
#   'Ndxx',
#   'zlVOvjnXV',
#   'mrqDiJjHsc',
#   'xXouvFtL',
#   'kDWQhqydrc',
#   'clxZUTs',
#   'cEmJlG',
#   'DPqVjGpAIS',
#   'wVfQaNKzvc',
#   'eYTc',
#   'fjXdM',
#   'BLSxXXt',
#   'QygTCPEsKp',
#   'UtPlGVGZ',
#   'vUYka',
#   'UJEs',
#   'tNdnJbEgN',
#   'hJlByNRZa',
#   'Mcooj',
#   'uufgC',
#   'IOMtcpXnY',
#   'HEoEWO',
#   'hImsKES',
#   'lneXEaP',
#   'SxABqZRc',
#   'oTVkuSBV',
#   'mquXvrY',
#   'sVlQzsJyhI',
#   'abWwiqqX',
#   'dsDSsFt',
#   'mPIZvI',
#   'RJVk',
#   ...],
#  ['LoWSedhugSCabgChHhhvdBXaaZiREggACNltWUvnryVgkfNitcCxgzQVXcEpWUfOMwaQHHdCUSrwAFhIBAiFvIAtbkTJEJtuPxGw',
#   'JwZeSyMHSFfLPYydZhaFOTgRIcoNsiuTKWTjZDMBuCztwVInTjfwgDnMQbpIeSZaueSUPIZTIRvsBCQSuluVYEbhCwmKBxDXhNNi',
#   'rgwNsIAkFVTEMWjzZHRcbUalsjKozdZfYWsnlNyfpLBTHhuJvIrzgxvrzwvnPILsKqiBdjssRzTWwqmgWaokMFUepEVFCeUKInvx',
#   'OXcZ',
#   'hUSeDBp',
#   'tSiF',
#   'PrkVWznK',
#   'Gpzn',
#   'FgpaNsNl',
#   'SeKnmLvsvX',
#   'sUyLWM',
#   'tAml',
#   'BBnncUGg',
#   'NxqHJfdfI',
#   'vYTyLrhfR',
#   'jUijDf',
#   'GnABkP',
#   'qthrJ',
#   'zKbuWPBl',
#   'dNPMGPF',
#   'SxswS',
#   'hBguYuZ',
#   'lfFClFqa',
#   'tWXqpF',
#   'QqsIprOZo',
#   'RJmm',
#   'XPgxiKATk',
#   'ETgQPChGqk',
#   'gnXOK',
#   'VUthnYR',
#   'izyE',
#   'fGHjinWR',
#   'RIEfBLMWfe',
#   'vcmuNMaDz',
#   'GnVXawk',
#   'HzfKPDULOe',
#   'SNKWYKc',
#   'viBzl',
#   'uqPccDfkxF',
#   'kbrChs',
#   'IQPtzzFpLB',
#   'Gdjvpebg',
#   'PIXM',
#   'PwMZSh',
#   'aWoutIPoHD',
#   'UcnuI',
#   'NLinCxdT',
#   'YISTDJ',
#   'vwcjtG',
#   'XvvCseJd',
#   'GFkkM',
#   'SVHUKzRaJ',
#   'aVrydQndBj',
#   'ChUCzAJ',
#   'iBPqVEF',
#   'SyxOffldo',
#   'YkCwfYnE',
#   'Lkuio',
#   'EyRH',
#   'gVPzcWOir',
#   'yrmzkrb',
#   'IqNedLqj',
#   'JNeJ',
#   'cSuObQR',
#   'ZOHQn',
#   'ikublBnnfp',
#   'jEAPngRIU',
#   'PBBD',
#   'uZmiieoxOU',
#   'FyZUZYQ',
#   'KRoigjQ',
#   'Tpjyzmu',
#   'RQVHdPFOg',
#   'Ckxk',
#   'LGvDkGCv',
#   'nkyUWXgb',
#   'vcgzR',
#   'VCiY',
#   'bacLJaEP',
#   'wPGNRF',
#   'XESTU',
#   'PWXMHM',
#   'cgNhD',
#   'NfUj',
#   'bpNYCJu',
#   'rijNI',
#   'xwZIk',
#   'JQUVDVy',
#   'roiHTr',
#   'jvIV',
#   'OOKs',
#   'HIQNP',
#   'LCDdgjTo',
#   'WSPmZd',
#   'CtXMhkM',
#   'JlwN',
#   'RQjRRS',
#   'rOTdcmgk',
#   'liiAE',
#   'MBCIk',
#   'AyPUxevmP',
#   'ZiAsEzFYD',
#   'IsGrAUzHNC',
#   'nFdHi',
#   'avqhwq',
#   'fhyuHMAEgN',
#   'ptcXF',
#   'huaJDYakO',
#   'OsGlhtZnoV',
#   'mHBWk',
#   'XuxxmLVYhg',
#   'OjJQwURK',
#   'UyohiN',
#   'woMBf',
#   'pLPSSJj',
#   'apMRDkO',
#   'frlAip',
#   'eozbMSOHHT',
#   'mouDszD',
#   'cEtDU',
#   'ogeWwntTse',
#   'hqkoJuzJ',
#   'yRQDcAAn',
#   'qxuu',
#   'QtJqQ',
#   'ASVU',
#   'qyEevi',
#   'gQdQY',
#   'WqweoPDNQn',
#   'hUMLte',
#   'aRuUk',
#   'WtdFFCdND',
#   'QtRaq',
#   'zSua',
#   'BdgEWePON',
#   'rotp',
#   'izGZBrdqMI',
#   'dzYCkltHl',
#   'JvatMnFS',
#   'lkgnZtyV',
#   'kTHXt',
#   'pVsw',
#   'OuoqFq',
#   'qMUh',
#   'HTXHjqF',
#   'ivFK',
#   'LHPyiGGTrb',
#   'UwJWeb',
#   'vsXiNkMkM',
#   'cJUZi',
#   'LLAKsHvUn',
#   'ySTQc',
#   'WOBeNWcl',
#   'hVzdpW',
#   'joHGbsk',
#   'LcFSaXCUPi',
#   'jMMTkvrYDG',
#   'tozJK',
#   'CMDdWUW',
#   'PXRfaiZP',
#   'nteATlFmYZ',
#   'FopAWUjHS',
#   'nCCuKnmx',
#   'YEvAX',
#   'rPImk',
#   'OGeywOlC',
#   'iPsYYOkwuF',
#   'BMcfY',
#   'cCFNUVTsr',
#   'kCMKnWZ',
#   'PVnvMzn',
#   'VApip',
#   'ZFMaXENKkH',
#   'QpPZSb',
#   'ijeotW',
#   'DSZzXtEmI',
#   'bFabavXGAu',
#   'FmTCIyYEt',
#   'lcTVPuQLlI',
#   'fdPaWPJQ',
#   'Ndxx',
#   'zlVOvjnXV',
#   'mrqDiJjHsc',
#   'xXouvFtL',
#   'kDWQhqydrc',
#   'clxZUTs',
#   'cEmJlG',
#   'DPqVjGpAIS',
#   'wVfQaNKzvc',
#   'eYTc',
#   'fjXdM',
#   'BLSxXXt',
#   'QygTCPEsKp',
#   'UtPlGVGZ',
#   'vUYka',
#   'UJEs',
#   'tNdnJbEgN',
#   'hJlByNRZa',
#   'Mcooj',
#   'uufgC',
#   'IOMtcpXnY',
#   'HEoEWO',
#   'hImsKES',
#   'lneXEaP',
#   'SxABqZRc',
#   'oTVkuSBV',
#   'mquXvrY',
#   'sVlQzsJyhI',
#   'abWwiqqX',
#   'dsDSsFt',
#   'mPIZvI',
#   'RJVk',
#   ...],
#  ['kinO',
#   'TskkQPfDhX',
#   'YycUuT',
#   'lVUrMsB',
#   'Cwrt',
#   'YbDWZ',
#   'TRhd',
#   'zlVdrdNlD',
#   'WxDZzEi',
#   'YwipaO',
#   'QZqciAnQRU',
#   'lkFrqGJTR',
#   'OTDUWgtzD',
#   'zimdI',
#   'ktjEABA',
#   'UuFZgsg',
#   'fwSnGz',
#   'ZClLSYDK',
#   'BaznBv',
#   'gPZdM',
#   'imLlZiyVd',
#   'mwjPbDuSf',
#   'krjZqxoUXt',
#   'RxagPMV',
#   'CHOKzLIO',
#   'KbSxBrAAFk',
#   'rTvCHp',
#   'NcFWip',
#   'GdYw',
#   'kOCBngwPq',
#   'XYNwHBfNF',
#   'pUGUmhq',
#   'EhsM',
#   'xmjebi',
#   'zxJdqwxSK',
#   'Qulomuuer',
#   'gbbiFtCio',
#   'DUrR',
#   'TARZeBQLR',
#   'feqRKA',
#   'KtxsAQi',
#   'ZNspKn',
#   'opDbnz',
#   'LrfD',
#   'iubqtVz',
#   'LUqkjo',
#   'vseDdjqC',
#   'Gscx',
#   'RkUxdzcpI',
#   'KVCOpQLwY',
#   'vidvp',
#   'ICpS',
#   'ufrZoPnGvJ',
#   'zGttj',
#   'hAjrIo',
#   'MkltV',
#   'trbuDH',
#   'xheNbuN',
#   'oRbnhGUQPH',
#   'GCue',
#   'KSDSPT',
#   'iUJnEY',
#   'gDQq',
#   'EhJC',
#   'QYAjNCxCC',
#   'IXZKmBkEF',
#   'wekkYhy',
#   'kPzxBX',
#   'WDwAm',
#   'ljvnvUwQx',
#   'kZNgt',
#   'PsOh',
#   'CrwdwZiba',
#   'jzgOuCUKM',
#   'sGkx',
#   'qHhkar',
#   'GnWfiiKGND',
#   'komzMxvtgL',
#   'jdlgDlgAqi',
#   'UQRZLGED',
#   'GSRcAb',
#   'SwtxuJUBSu',
#   'nIgcD',
#   'BrPK',
#   'RapMYdSwE',
#   'DStU',
#   'kVJz',
#   'vhoyFfc',
#   'TZTARIlZV',
#   'OBpgh',
#   'ogfYJ',
#   'NMBcLZZTNB',
#   'YSXjWATxn',
#   'BctXcCKgB',
#   'JwxdMdX',
#   'RnPKwBqckd',
#   'ILEnXBVCgQ',
#   'HLkmcMd',
#   'IoVdcUVPG',
#   'MGgZcn',
#   'GoZcBg',
#   'aLWoxr',
#   'ufTPOX',
#   'zKpihN',
#   'ZtfJoW',
#   'wOtZUTS',
#   'pElCcQdoxy',
#   'rTjh',
#   'dxBbrrj',
#   'LInThGtUg',
#   'bhLkWYIv',
#   'LsPEtRhEJ',
#   'XqXnaT',
#   'bkgy',
#   'kHcRsYKqse',
#   'TtxyFsH',
#   'XtNWkVmbzM',
#   'xdmZfcgQcw',
#   'QFMNPlBOSn',
#   'yutJwvQM',
#   'rzmbroRk',
#   'TTEAoAXEVU',
#   'jNCh',
#   'IscdMZcU',
#   'pIgHlzQob',
#   'YFagpBHcwS',
#   'jhiXLeJ',
#   'gNgffFgY',
#   'tnEUq',
#   'loVgIHY',
#   'hwDo',
#   'IpBfzkPXs',
#   'BSHc',
#   'mFAXwany',
#   'sUiDd',
#   'SoiNs',
#   'AsvqxBH',
#   'kZqxs',
#   'xslpU',
#   'HzGDe',
#   'JtFTUUiBuJ',
#   'NFIkRuyv',
#   'SBkRI',
#   'NUzyXgdb',
#   'IOaL',
#   'BYzO',
#   'jntD',
#   'YtxibFWmX',
#   'zqiqEBFmBz',
#   'RQeeQHjTJ',
#   'OHtGD',
#   'PylmTaE',
#   'vMzhHaLAyi',
#   'KHkp',
#   'sFLnZ',
#   'bpHTDwrb',
#   'vtaxF',
#   'Qqwhzxc',
#   'hrFvBwl',
#   'epTyHzTol',
#   'wTFlo',
#   'NZIlMMqn',
#   'HMCVPdJ',
#   'AaZq',
#   'TLLH',
#   'zRRamxEP',
#   'zUZTAVP',
#   'wPrP',
#   'sbLLAkt',
#   'ABVk',
#   'RtVinm',
#   'DxdKIVYKn',
#   'tQQZi',
#   'hNUaPfjzcu',
#   'azhnyNEUdf',
#   'HuuzjaiQv',
#   'dbrNWFAjP',
#   'ZQJHSXNm',
#   'VEXE',
#   'NkJv',
#   'ITsIOko',
#   'elCHjxA',
#   'jBwgjDn',
#   'BFjIB',
#   'AJxss',
#   'cdnVbODSOH',
#   'nYWOr',
#   'RcTxj',
#   'oMzJEHL',
#   'xuVm',
#   'FPxJxhYQiV',
#   'CFUQJmsbNh',
#   'LsoQyBw',
#   'xtmkjUnGpg',
#   'PbOxLAFqCJ',
#   'KoKx',
#   'ETrMq',
#   'yoTdGvheD',
#   'dNErnoTC',
#   'FXFjFHO',
#   'OiqH',
#   'miPzacI',
#   'paAKINnin',
#   'GrykLiS',
#   'mTjyCbl',
#   'KeMHSdq',
#   'swykqZdf',
#   'XbuHu',
#   'DAFR',
#   'EADSq',
#   'IjhGG',
#   'qZCUIbXLU',
#   'QOTTDCU',
#   'wYbJ',
#   'mmnnQ',
#   'LujF',
#   'ILpoxZ',
#   'saFGA',
#   'uVeOtAb',
#   'OeWDFN',
#   'UnWPjXg',
#   'EtaQRL',
#   'JmJTJlyKr',
#   'UkMCCYAzmT',
#   'khVGd',
#   'XQfS',
#   'XZlkC',
#   'WgCp',
#   'uTrCEShEa',
#   'DfUePyLua',
#   'LGLVe',
#   'ZIJmoPGQUT',
#   'unlUxAdU',
#   'bchVry',
#   'Ofap',
#   'nHgy',
#   'cVRVE',
#   'HqPSJoOq',
#   'cvdxIUt',
#   'CQbmJoZgZ',
#   'PmFclpg',
#   'konxHakP',
#   'EEuXaiyqXF',
#   'VNoc',
#   'AfCGaUzqmO',
#   'dXfyc',
#   'VawMNiMJud',
#   'CpsrV',
#   'ynGBUcNljt',
#   'NUjsUHsof',
#   'nhLZwha',
#   'IcNyBtNFjE',
#   'tRcWc',
#   'efatuUkzn',
#   'sIJE',
#   'wOQUROA',
#   'NZiZ',
#   'EkeFPkL',
#   'tJtOxySwnN',
#   'OLvUG',
#   'vBBKhdNzfP',
#   'ujeHWm',
#   'gIvehA',
#   'LjUaqZNq',
#   'RYJrmCuh',
#   'VkwX',
#   'bFJvLyNQJ',
#   'AMFgsk',
#   'HYDa',
#   'UFzLxvraYt',
#   'GFTr',
#   'wNCycFkB',
#   'rKYMQPSx',
#   'QKFTHtR',
#   'YCVGaNoGUV',
#   'pyUq',
#   'gsXgCKY',
#   'XkpqQZZ',
#   'geqfacIR',
#   'OvuWcoK',
#   'TYrZprgi',
#   'GgmTeRv',
#   'aSZNjCMV',
#   'dmKiJ',
#   'WQNPVfpmD',
#   'pgXNuQnkH',
#   'KmiCDd',
#   'BOdedCMp',
#   'dFNih',
#   'zPPQzwKrd',
#   'JRFSil',
#   'lyJtDjdpIF',
#   'eeMJpoeC',
#   'ZZALEurmh',
#   'OoRszibt',
#   'wgcn',
#   'wYHs',
#   'kKQkVdtmQD',
#   'DDACDgmvE',
#   'lwgAdQ',
#   'bPnrld',
#   'qhDsOjSqW',
#   'TMkdiZ',
#   'rKFPt',
#   'bWknf',
#   'rMcUTgv',
#   'WFFBBmrsnT',
#   'zmqlocUJ',
#   'eHVbqmf',
#   'xqiszlddK',
#   'qFrKOVxDFN',
#   'UcJsHODz',
#   'iTMMTZ',
#   'PbJXhl',
#   'VkDfe',
#   'uEia',
#   'lHlibQW',
#   'WWymAiGYvR',
#   'ziixRdE',
#   'Wvmlcu',
#   'WSxf',
#   'AtBZINnTmG',
#   'aukYcq',
#   'NnVrBGH',
#   'PZWsc',
#   'iJji',
#   'WtxbztUG',
#   'ulKWpjIG',
#   'prIyrTxg',
#   'mJyj',
#   'BEbItLUMvK',
#   'huivMIEwas',
#   'GXnDkNk',
#   'LmCiziyf',
#   'iMUzpqW',
#   'wtjjWxPE',
#   'oOByH',
#   'TdPgq',
#   'BDSgBj',
#   'FwjAcEDFlJ',
#   'VjwoYY',
#   'OnWDTFbzBu',
#   'rmDq',
#   'HbhOGdX',
#   'VpcworapiI',
#   'FGwIjir',
#   'vOSxVFplnx',
#   'uNMOE',
#   'hWxmKXqV',
#   'pkGTwVQQ',
#   'XGroTO',
#   'HPAHj',
#   'eXiPD',
#   'tEmLxSCDZ',
#   'LupoVLQ',
#   'WMSOaVWzj',
#   'gJbtRevl',
#   'XbvVX',
#   'yflng',
#   'xPauvpom',
#   'WBvtpb',
#   'afWAVaSVsD',
#   'ruEqXrD',
#   'VUvmRYfV',
#   'rsNITQQ',
#   'PexQTX',
#   'CQisRvKipE',
#   'vBmw',
#   'rXDjuPiG',
#   'Haxjcyyb',
#   'kDKglUC',
#   'SMEwrYhfjR',
#   'tfzdeWkVGS',
#   'kaLs',
#   'EQBQD',
#   'sjXyErz',
#   'ItlZ',
#   'HDKoR',
#   'mWHJpRD',
#   'XBxhd',
#   'gDhZy',
#   'GVjSJPgbR',
#   'IqYwGXLEv',
#   'Tycl',
#   'xeArU',
#   'BhnIkzOC',
#   'VMRC',
#   'lYNHJLROLn',
#   'AxRpsb',
#   'fShoWpn',
#   'KKxyrua',
#   'TgJyMr',
#   'gXVCOOpKxj',
#   'czAHRfP',
#   'nuOw',
#   'PpooV',
#   'oCBhoxCfbc',
#   'oDFV',
#   'CbXHMc',
#   'CYLBays',
#   'jKpNiB',
#   'aQJvgrELpZ',
#   'pxkDlF',
#   'GfnJkIUwQP',
#   'DtVzsZA',
#   'WlTAryTgzA',
#   'PhYuyvv',
#   'imqXvz',
#   'MQnMBgu',
#   'WmWuyzcS',
#   'DfOwiTbqLY',
#   'oZRI',
#   'YiZXsvj',
#   'DwkqhL',
#   'mSIdTIqexp',
#   'myptlGjjQ',
#   'ztPkbaVbyl',
#   'SSVMeHKJ',
#   'lgJoTbWQ',
#   'WrtX',
#   'KmKoCviMeX',
#   'zTPiFGQNAN',
#   'KuFuOR',
#   'cisJ',
#   'nvzfYEW',
#   'cNHgY',
#   'xPQXqhhbnR',
#   'KZcnlcM',
#   'PBrFLJMKs',
#   'CDPTcqtb',
#   'POMMk',
#   'GzHIiDXFIz',
#   'gtpMAXU',
#   'gOHzkrlcRm',
#   'IvflwBPD',
#   'LinFk',
#   'flkP',
#   'OQJKmC',
#   'lHNCqiGk',
#   'gRWs',
#   'rbggaKLZXY',
#   'VvWnqX',
#   'RiBcnoC',
#   'azYiewsPX',
#   'NbthJS',
#   'Hyzk',
#   'LHuwj',
#   'biMOpljXRF',
#   'UnzOlWxGPr',
#   'MzaAA',
#   'pXKKBe',
#   'slFLHBuem',
#   'wyxqprbg',
#   'mzFl',
#   'AcaWhQ',
#   'lTgqbQmXtQ',
#   'QwlQ',
#   'BhzG',
#   'xbIrZQ',
#   'FdyKHG',
#   'zbIlmuIhhe',
#   'EerOChWbM',
#   'Rvpw',
#   'vZZnKt',
#   'RNnIe',
#   'FpnNyyJmCN',
#   'pbKrwhtf',
#   'TFiU',
#   'ZzWGjAkkaV',
#   'eiQXoNRV',
#   'WcwGVDNM',
#   'buboqS',
#   'QarUOhCAD',
#   'EzesBhDpT',
#   'uiHxbO',
#   'ylILqYkSql',
#   'DETGiCgt',
#   'MbdS',
#   'bPiz',
#   'tqihwFJT',
#   'CNCe',
#   'VQrxvDYFmj',
#   'ufbWVTuwtE',
#   'FMXB',
#   'wxPwxd',
#   'lCIsjdOo',
#   'XtGoRh',
#   'siJBBbrzL',
#   'NAnVNIYIH',
#   'wfGX',
#   'DmEeNNTh',
#   'DGIUwToRPj',
#   'xBbcHTYQr',
#   'qtAljUJ',
#   'sRCvZ',
#   'mAEqSOmfz',
#   'fOdscDdN',
#   'nAXXx',
#   'CPRjjk',
#   'DlFgOA',
#   'LjAAUZgJH',
#   'zVDnfHglib',
#   'JHmO',
#   'EbVI',
#   'AirLnf',
#   'gkTqfsRVT',
#   'brsqZpIDf',
#   'czhHJQ',
#   'RnUKL',
#   'RNkkUWd',
#   'vaFkY',
#   'HJIF',
#   'XHhBDSwXpY',
#   'wQIomJT',
#   'ghvHahAWTv',
#   'yIuvFmZG',
#   'HnlXA',
#   'Nefb',
#   'FHuzwJig',
#   'stzm',
#   'cmjnItE',
#   'uLWrYXIXh',
#   'bdMaayT',
#   'OQNgSwY',
#   'CxRC',
#   'kbNzGOAHRb',
#   'angi',
#   'ZKWj',
#   'ojBkTmcm',
#   'RteNX',
#   'xKsBYy',
#   'ZmTHSmOMRW',
#   'vNkURpwH',
#   'GOtlOnCl',
#   'TGckFli',
#   'mgtSkvqWNg',
#   'cVUGeMGOkf',
#   'phmX',
#   'rqwvYI',
#   'qGdETgeJ',
#   'KenciwUf',
#   'eEiJPygd',
#   'CDLVGjku',
#   'wPqzEwwuA',
#   'fMgzKrL',
#   'QPJbTFkAo',
#   'iEQM',
#   'dwOK',
#   'oGIXWLUX',
#   'bcKfYnEY',
#   'XkFS',
#   'SVMblCI',
#   'hJNpC',
#   'DacZ',
#   'JHsDD',
#   'FcAKeBpZ',
#   'NimitNofA',
#   'OSNPl',
#   'ZtKv',
#   'aDmQzKs',
#   'JmIcZF',
#   'oGguJuM',
#   'GnQMe',
#   'LXnswvWTru',
#   'dyPa',
#   'uoquWVFYE',
#   'OaQBewHHH',
#   'RLjBBMgmPT',
#   'QedCmU',
#   'PcRIbTMrnk',
#   'XwSfJ',
#   'fmkIQApr',
#   'EgZVQejI',
#   'wrDUhQh',
#   'wJurq',
#   'BMJG',
#   'HuQJq',
#   'IbBy',
#   'GTpHT',
#   'wQXn',
#   'cKmWwW',
#   'STbG',
#   'TlohMV',
#   'pUVexIS',
#   'nBQeruvQe',
#   'oTrFUj',
#   'QSEldGtHVa',
#   'dzwe',
#   'KRiwDiOLoj',
#   'ZFjlZq',
#   'cMMhcI',
#   'NlYQOADr',
#   'LkSCyVri',
#   'lYZUle',
#   'iCnbCb',
#   'ANCy',
#   'pPkVhYx',
#   'mFLmXFECs',
#   'sogSFLdLwn',
#   'ZSnRjuMElx',
#   'TjVHVPSv',
#   'NRXxk',
#   'rTKCv',
#   'VEeRzZ',
#   'wvHswmECY',
#   'pHbgelj',
#   'pDahf',
#   'GICnqgmYIc',
#   'udDtIt',
#   'DvastOVYQ',
#   'aVRJ',
#   'MwCAmnSVd',
#   'OQCIF',
#   'wVwv',
#   'exYDfTaq',
#   'MurZtCys',
#   'fUUpzLHQ',
#   'FqeGjMdo',
#   'oWjLiTG',
#   'KSht',
#   'LGnG',
#   'FkzZRu',
#   'SESPHmtO',
#   'fndQJ',
#   'ATbo',
#   'idNPLfba',
#   'BoVwPlU',
#   'Vmdrt',
#   'HceTCZvW',
#   'aNnEkEZU',
#   'qCYxwGWnI',
#   'ZmRlPGf',
#   'JzdpuQDlPk',
#   'MbQrkl',
#   'DwAjwCm',
#   'RCsR',
#   'HOQm',
#   'fphLI',
#   'kqoLZXmF',
#   'VsEIfuT',
#   'srrRlY',
#   'MPXOkKtGgx',
#   'ZFip',
#   'lSyYFPz',
#   'MVDkVEz',
#   'GUjkHhy',
#   'RFci',
#   'RMiv',
#   'RqfE',
#   'SRjTQmLO',
#   'XiCQHWK',
#   'tKnWsw',
#   'UXaxBvILY',
#   'FdWPqusoO',
#   'zARYex',
#   'lJbnzbEryi',
#   'IZCQYXi',
#   'NXwlj',
#   'kIzLFeJYp',
#   'JsBjkCeQ',
#   'NNqNEtC',
#   'HDUPtifwFC',
#   'DTZdiJx',
#   'Rlzw',
#   'iMZCHNtQT',
#   'AWYiqvV',
#   'FUprY',
#   'GOGQ',
#   'wrxfHNJx',
#   'heVtPzl',
#   'RoufnRmjz',
#   'nAYxrWhWT',
#   'dwTB',
#   'tSOKIZkLF',
#   'EPsYuVjdO',
#   'XFOjNpmpr',
#   'QVVnEx',
#   'PUWubLvO',
#   'hASSQtDMu',
#   'WVTUzBjW',
#   'qkeOXPjM',
#   'ArvyqHYnUi',
#   'lCJATDrS',
#   'wKTsEbpON',
#   'kuMLOUvOfw',
#   'hYjSlyk',
#   'IMWYAnyOqJ',
#   'VLUK',
#   'gVAHn',
#   'cABuueXDpl',
#   'fzgG',
#   'YrWMo',
#   'uRibSXRldT',
#   'OexrswkHfB',
#   'pSBgz',
#   'xcmHz',
#   'FvPElwd',
#   'iERsQnvjnY',
#   'cZNaW',
#   'rvsRyP',
#   'DpENWIp',
#   'AbTZGny',
#   'gnfSKnb',
#   'gGWOMskB',
#   'JtEk',
#   'fyaDjoiI',
#   'CESXboMig',
#   'JLHJYbaZPf',
#   'jyYBdkypN',
#   'suImsZGKlt',
#   'YdDfmMgLUB',
#   'uoyfcTcIDg',
#   'CiostQUp',
#   'huOO',
#   'otyDeBM',
#   'EzvD',
#   'mOgpq',
#   'wNQxEetkwP',
#   'xlWMqtNi',
#   'Jkswn',
#   'SuSkgy',
#   'JLbpCy',
#   'znJii',
#   'hTIYAQOnKZ',
#   'oxhoKKJHXa',
#   'cGRLXpujM',
#   'EQRXTHWU',
#   'usclTFhbSM',
#   'JNuX',
#   'cDEoomseja',
#   'enxHYGC',
#   'OZTqfYRTjU',
#   'GXBGgWvvdf',
#   'LrSsmYJTS',
#   'NeMix',
#   'BtlmtHFC',
#   'IRCCqXaBN',
#   'ieTXZlkE',
#   'wKRKjJdEt',
#   'KsGgBXWFu',
#   'jaKfCysh',
#   'upMI',
#   'iBtYkBdfi',
#   'GzUu',
#   'MAcRLYe',
#   'QJyAXlpcX',
#   'bGNrPiKD',
#   'BCSZAp',
#   'RxAqwgwW',
#   'idJTqK',
#   'VWHHNao',
#   'kDxz',
#   'VvbSJyPWzE',
#   'VFArj',
#   'pRyhUBgwX',
#   'pBGESGO',
#   'jfYet',
#   'teOqiUpWbb',
#   'NQMDUO',
#   'exMlxh',
#   'sXVBuaU',
#   'FUULcb',
#   'zAwCxdCuu',
#   'VcUZIBBcht',
#   'EVJZl',
#   'ccEiV',
#   'TbXL',
#   'mmpcKPZ',
#   'xAcj',
#   'XJBINry',
#   'nMqNxrMmE',
#   'YiAAbQFgId',
#   'hapMH',
#   'ZyjrXyPH',
#   'emHyh',
#   'KScQtJahnW',
#   'TRZsFbEt',
#   'ZMyVCyuq',
#   'RtXCNKyfyL',
#   'DvqikjXNm',
#   'DXsZjOYElo',
#   'kzMOH',
#   'keqt',
#   'EkliZN',
#   'vZmf',
#   'anQazo',
#   'haBJZSDx',
#   'JgMtFjd',
#   'fySfXtD',
#   'slAADrZaMk',
#   'QlYQTXWVH',
#   'OXcZ',
#   'hUSeDBp',
#   'tSiF',
#   'PrkVWznK',
#   'Gpzn',
#   'FgpaNsNl',
#   'SeKnmLvsvX',
#   'sUyLWM',
#   'tAml',
#   'BBnncUGg',
#   'NxqHJfdfI',
#   'vYTyLrhfR',
#   'jUijDf',
#   'GnABkP',
#   'qthrJ',
#   'zKbuWPBl',
#   'dNPMGPF',
#   'SxswS',
#   'hBguYuZ',
#   'lfFClFqa',
#   'tWXqpF',
#   'QqsIprOZo',
#   'RJmm',
#   'XPgxiKATk',
#   'ETgQPChGqk',
#   'gnXOK',
#   'VUthnYR',
#   'izyE',
#   'fGHjinWR',
#   'RIEfBLMWfe',
#   'vcmuNMaDz',
#   'GnVXawk',
#   'HzfKPDULOe',
#   'SNKWYKc',
#   'viBzl',
#   'uqPccDfkxF',
#   'kbrChs',
#   'IQPtzzFpLB',
#   'Gdjvpebg',
#   'PIXM',
#   'PwMZSh',
#   'aWoutIPoHD',
#   'UcnuI',
#   'NLinCxdT',
#   'YISTDJ',
#   'vwcjtG',
#   'XvvCseJd',
#   'GFkkM',
#   'SVHUKzRaJ',
#   'aVrydQndBj',
#   'ChUCzAJ',
#   'iBPqVEF',
#   'SyxOffldo',
#   'YkCwfYnE',
#   'Lkuio',
#   'EyRH',
#   'gVPzcWOir',
#   'yrmzkrb',
#   'IqNedLqj',
#   'JNeJ',
#   'cSuObQR',
#   'ZOHQn',
#   'ikublBnnfp',
#   'jEAPngRIU',
#   'PBBD',
#   'uZmiieoxOU',
#   'FyZUZYQ',
#   'KRoigjQ',
#   'Tpjyzmu',
#   'RQVHdPFOg',
#   'Ckxk',
#   'LGvDkGCv',
#   'nkyUWXgb',
#   'vcgzR',
#   'VCiY',
#   'bacLJaEP',
#   'wPGNRF',
#   'XESTU',
#   'PWXMHM',
#   'cgNhD',
#   'NfUj',
#   'bpNYCJu',
#   'rijNI',
#   'xwZIk',
#   'JQUVDVy',
#   'roiHTr',
#   'jvIV',
#   'OOKs',
#   'HIQNP',
#   'LCDdgjTo',
#   'WSPmZd',
#   'CtXMhkM',
#   'JlwN',
#   'RQjRRS',
#   'rOTdcmgk',
#   'liiAE',
#   'MBCIk',
#   'AyPUxevmP',
#   'ZiAsEzFYD',
#   'IsGrAUzHNC',
#   'nFdHi',
#   'avqhwq',
#   'fhyuHMAEgN',
#   'ptcXF',
#   'huaJDYakO',
#   'OsGlhtZnoV',
#   'mHBWk',
#   'XuxxmLVYhg',
#   'OjJQwURK',
#   'UyohiN',
#   'woMBf',
#   'pLPSSJj',
#   'apMRDkO',
#   'frlAip',
#   'eozbMSOHHT',
#   'mouDszD',
#   'cEtDU',
#   'ogeWwntTse',
#   'hqkoJuzJ',
#   'yRQDcAAn',
#   'qxuu',
#   'QtJqQ',
#   'ASVU',
#   'qyEevi',
#   'gQdQY',
#   'WqweoPDNQn',
#   'hUMLte',
#   'aRuUk',
#   'WtdFFCdND',
#   'QtRaq',
#   'zSua',
#   'BdgEWePON',
#   'rotp',
#   'izGZBrdqMI',
#   'dzYCkltHl',
#   'JvatMnFS',
#   'lkgnZtyV',
#   'kTHXt',
#   'pVsw',
#   'OuoqFq',
#   'qMUh',
#   'HTXHjqF',
#   'ivFK',
#   'LHPyiGGTrb',
#   'UwJWeb',
#   'vsXiNkMkM',
#   'cJUZi',
#   'LLAKsHvUn',
#   'ySTQc',
#   'WOBeNWcl',
#   'hVzdpW',
#   'joHGbsk',
#   'LcFSaXCUPi',
#   'jMMTkvrYDG',
#   'tozJK',
#   'CMDdWUW',
#   'PXRfaiZP',
#   'nteATlFmYZ',
#   'FopAWUjHS',
#   'nCCuKnmx',
#   'YEvAX',
#   'rPImk',
#   'OGeywOlC',
#   'iPsYYOkwuF',
#   'BMcfY',
#   'cCFNUVTsr',
#   'kCMKnWZ',
#   'PVnvMzn',
#   'VApip',
#   'ZFMaXENKkH',
#   'QpPZSb',
#   'ijeotW',
#   'DSZzXtEmI',
#   'bFabavXGAu',
#   'FmTCIyYEt',
#   'lcTVPuQLlI',
#   'fdPaWPJQ',
#   'Ndxx',
#   'zlVOvjnXV',
#   'mrqDiJjHsc',
#   'xXouvFtL',
#   'kDWQhqydrc',
#   'clxZUTs',
#   'cEmJlG',
#   'DPqVjGpAIS',
#   'wVfQaNKzvc',
#   'eYTc',
#   'fjXdM',
#   'BLSxXXt',
#   'QygTCPEsKp',
#   'UtPlGVGZ',
#   'vUYka',
#   'UJEs',
#   'tNdnJbEgN',
#   'hJlByNRZa',
#   'Mcooj',
#   'uufgC',
#   'IOMtcpXnY',
#   'HEoEWO',
#   'hImsKES',
#   'lneXEaP',
#   'SxABqZRc',
#   'oTVkuSBV',
#   'mquXvrY',
#   'sVlQzsJyhI',
#   'abWwiqqX',
#   'dsDSsFt',
#   'mPIZvI',
#   'RJVk',
#   ...]]

# %%
SyntheticDataNames = ["Normal", "Long String", "Special String", "Ascending Order", "Descending Order", 
                      "String with missing values", "String with duplicate values"]

# %%
synSearchList = []
for datalist in SyntheticDataList[0 : 3]:
    num = round(len(datalist) * 0.3)
    templist = []
    seen = {}
    # Choose from list
    while len(templist) < num:
        tempdata = random.choice(datalist)
        if tempdata not in seen:
            seen[tempdata] = True
            templist.append(tempdata)
    # Generate new values
    falsenum = round(len(datalist) * 0.2)
    for _ in range(falsenum):
        fdata = ''.join(random.choice(string.ascii_lowercase) for _ in range(random.randint(8, 12))) 
        templist.append(fdata)
    synSearchList.append(templist)

for _ in range(4):
    synSearchList.append(synSearchList[0].copy())
synSearchList
# Out:
# [['fdYgCb',
#   'EmiHuRcsuG',
#   'LFYdLzTjM',
#   'GByrtshVGt',
#   'OktODd',
#   'swGhCJtlU',
#   'MgwXF',
#   'iVzl',
#   'NqbhOBBuK',
#   'emCOXs',
#   'oDIROugT',
#   'BpGq',
#   'AtLotUE',
#   'jadzjETY',
#   'NZgX',
#   'DWNFCGemiE',
#   'qiCXFNnLmM',
#   'fVPKDfl',
#   'ordncstoOq',
#   'mDunpFYC',
#   'mqkauCLZYt',
#   'jKzPyWXu',
#   'EywsoUQS',
#   'xVwNeE',
#   'kyTYLmDL',
#   'XjLwlLV',
#   'osMV',
#   'Gixp',
#   'fWPxp',
#   'HXqzQkvafX',
#   'fjgsvAuSBe',
#   'sOVLWVs',
#   'RNpURbfQQ',
#   'WFQNBc',
#   'mtYCaV',
#   'vkKwsBbdz',
#   'nRkBpiSpDo',
#   'IDnQPrXdfK',
#   'qFxTUK',
#   'hwyvy',
#   'twFqeZMr',
#   'SvzOiTLPJb',
#   'bCeE',
#   'JxpBVBKlR',
#   'ipiOAr',
#   'sJnwJVv',
#   'shzptAsYg',
#   'HvUEfG',
#   'DxCE',
#   'bRYQBIn',
#   'onbKPE',
#   'pPHV',
#   'lbeCfzkn',
#   'WmfBdiG',
#   'iqfiIMK',
#   'TssaajdL',
#   'QJNtJT',
#   'keFFeMJIm',
#   'saihB',
#   'yYkYIuSw',
#   'NeJQaaLnJ',
#   'NqdZ',
#   'hGQECEo',
#   'ijKnqNfscL',
#   'BXFWOXmnzj',
#   'wnFGzVY',
#   'JLnICKhwV',
#   'fwbGKJ',
#   'Ekzy',
#   'ynlOqUj',
#   'aYbPYXki',
#   'kxGrfwof',
#   'DBtg',
#   'krKbwO',
#   'lpCuBVOF',
#   'mPQeQCV',
#   'SImv',
#   'vgxSQtm',
#   'BvSZoII',
#   'TFvA',
#   'jmlIpXwoxM',
#   'zzZISYcqNr',
#   'HjxfekLxoF',
#   'wNBQ',
#   'xjQOILsmI',
#   'KxPY',
#   'kKooMo',
#   'bQpOfx',
#   'yhYBIwELc',
#   'HRiRbBAjx',
#   'dybIM',
#   'UqOhz',
#   'ghztLK',
#   'guEQS',
#   'iERsQnvjnY',
#   'WCLCnZ',
#   'MVNfueMZ',
#   'pTeIEpqYK',
#   'wdjTK',
#   'uZSB',
#   'MkRbGkBU',
#   'fyMIdi',
#   'WlTAryTgzA',
#   'nzRYK',
#   'uqSkXOvxne',
#   'FcyyLCj',
#   'NvpJh',
#   'nEquzrp',
#   'wwdG',
#   'XvuY',
#   'ryAXg',
#   'Kaxwi',
#   'OFnXND',
#   'IkShzJ',
#   'GwAbg',
#   'HqFxmTTaAM',
#   'SgQiwwe',
#   'NXEuBGww',
#   'pPOhSkDrec',
#   'ysjyq',
#   'JdiIIOCrlK',
#   'trApdWQ',
#   'UjVzZ',
#   'XWpvr',
#   'wsyewpWN',
#   'aisdc',
#   'KNHWDLtoE',
#   'BuyI',
#   'OxVKupbAXV',
#   'cGhAhs',
#   'SNFO',
#   'XYYEk',
#   'oWktMDc',
#   'BLSxXXt',
#   'xWgYs',
#   'sUHXUvcnvo',
#   'lGKNptnHH',
#   'xIsCzuQN',
#   'PWnkUHHsI',
#   'IgoNQeXwO',
#   'eyKV',
#   'wburzVvN',
#   'SINLZB',
#   'AmJHAosj',
#   'WdZxLcpHm',
#   'QCWuAUubrc',
#   'VDwuIiWJPS',
#   'azGiHCgq',
#   'QJqvVE',
#   'jEzTnHnf',
#   'kPHuZawz',
#   'bRJKCxk',
#   'QBzOqc',
#   'JGnUJbe',
#   'lAiV',
#   'nSaRAumqg',
#   'rkXgpY',
#   'kdvbWXoqI',
#   'bFRwH',
#   'VdlYHt',
#   'RZcqJDLm',
#   'KgfJdAM',
#   'yoZPO',
#   'NHNQYb',
#   'KyLxBDSy',
#   'RHhByYBbP',
#   'MZCDSMax',
#   'CVdEaBHj',
#   'NeFuaE',
#   'LdJyhAcWVd',
#   'EpaEkmMy',
#   'oJGxdgWxB',
#   'jeJEUhh',
#   'ZTkKJ',
#   'DlOoJAOer',
#   'DUixBe',
#   'qRIGXD',
#   'kMWRn',
#   'WDcU',
#   'QziQdl',
#   'NswGaPi',
#   'AMiWyb',
#   'CZpWaBJu',
#   'UFGdrsMtkk',
#   'WylqkJw',
#   'LeKs',
#   'HkuSMZWwuG',
#   'VAvygq',
#   'sBjrmpq',
#   'HCvUoGe',
#   'iwUpGE',
#   'EdCMg',
#   'uRHvqpuiVd',
#   'EOODgzqaUJ',
#   'MWni',
#   'GlRrSk',
#   'VzxnA',
#   'tpNu',
#   'QuXbeukUy',
#   'DZwIx',
#   'WgVTyTez',
#   'RvPHMdeAA',
#   'EYdhoBHF',
#   'CirsM',
#   'pCFeCtzlto',
#   'wiGxh',
#   'kxTAm',
#   'siOAgeDn',
#   'wiJNfFZxCD',
#   'MabOZSmsJU',
#   'tUpULBsI',
#   'HYGDVlHIlS',
#   'sKIK',
#   'TlQx',
#   'kXqv',
#   'KhptXBSNU',
#   'tlgxeNSi',
#   'UCloNP',
#   'PzLqZeKtjg',
#   'fanutke',
#   'yyYLHxo',
#   'rpEjdgpxUa',
#   'ppiivYDnfo',
#   'XfAhIAy',
#   'cQQi',
#   'ObxKrmqYi',
#   'WnwLGNlI',
#   'QBFXxOqs',
#   'FlTwEQZm',
#   'ivVetBIe',
#   'RBWbeuYH',
#   'xclHmn',
#   'GAPKpZc',
#   'XTkdWj',
#   'Rfysq',
#   'YdgPqDg',
#   'qlNEVcCA',
#   'aJMrpJHbg',
#   'xDgsrcZ',
#   'muvcQx',
#   'wDSM',
#   'GDPN',
#   'EfwqX',
#   'kKcIzvKIR',
#   'UYkQ',
#   'loULGrIR',
#   'oALh',
#   'bVPXwaX',
#   'ANMkWaJQwP',
#   'dQnjM',
#   'rTcuQ',
#   'SoiNs',
#   'xshssWSqr',
#   'ESSAba',
#   'kYRxeCRDOr',
#   'qSCzfSb',
#   'aroIVQftHw',
#   'iZWmzDiprU',
#   'qJAUsZccq',
#   'rtCgaG',
#   'QGRzGNtc',
#   'RYlImrhrY',
#   'ZyMQLrIEma',
#   'UWDRpVv',
#   'eXYKYfE',
#   'YDGBVr',
#   'CXSiPdgf',
#   'SYyyDmLwbC',
#   'oVtAksIq',
#   'wTQBfs',
#   'DDir',
#   'tNdHHlr',
#   'wUGfTZ',
#   'chNET',
#   'lofs',
#   'pCDd',
#   'NUKxQ',
#   'QqKbHoErqj',
#   'MANsmMS',
#   'pDPvolEJ',
#   'YBOXfg',
#   'RfCXbre',
#   'XjnRKaAB',
#   'xIjaoOCg',
#   'DLnsraF',
#   'WwpwCcJTkl',
#   'HNGvDdxff',
#   'MqdKrkX',
#   'KibcgaYBaL',
#   'vMOosyYXWu',
#   'tNQaC',
#   'YqAURkW',
#   'FnAV',
#   'jYnwnDHvbt',
#   'eBuNvdnBzi',
#   'luKnrInU',
#   'QFzpcuCIE',
#   'TCprSwgzkH',
#   'xHuOTvGH',
#   'oNLlnK',
#   'pFOwyPfrr',
#   'agiK',
#   'cxOdBZh',
#   'wUfyltHv',
#   'DfpgaSlEs',
#   'XWbcQBG',
#   'nCbTAkr',
#   'bJEwYg',
#   'WvzI',
#   'Ibdm',
#   'fohMAuTKZP',
#   'GdrlQrPXz',
#   'hWktx',
#   'GxgczK',
#   'UxeHBLcOT',
#   'dlqgHsndT',
#   'PdawTXVFt',
#   'NbssBDZbz',
#   'NqSkiXMeK',
#   'HoWmoYbDN',
#   'vvqztzNu',
#   'ZoqPIP',
#   'MxhQGxh',
#   'nWBnBfBsWA',
#   'eSqgfzU',
#   'Nuyn',
#   'LefYWQ',
#   'hTDX',
#   'UuMlcSs',
#   'Nzch',
#   'kWgQxRQjXg',
#   'ThPqEFgHD',
#   'WMdBFfp',
#   'ynam',
#   'EUdI',
#   'oKeKH',
#   'ChHFbI',
#   'XTKq',
#   'JUYTlqgML',
#   'nMUVsO',
#   'IaijDd',
#   'ntMnPxcd',
#   'QMwWJ',
#   'mWQiaGL',
#   'xITVSZPrJI',
#   'yUQPuh',
#   'cwhzJ',
#   'MoKzFVS',
#   'rnvbWqLh',
#   'jhKpxyTBa',
#   'HsxToOFe',
#   'XPbwGPCbG',
#   'SFeKr',
#   'AQdljMT',
#   'Vwnukwd',
#   'vBxQPh',
#   'pwGmFV',
#   'OGnbJeuIWE',
#   'lXqzNix',
#   'OrhRb',
#   'ODcDdoYO',
#   'XprzEwmNR',
#   'aYsOWenFMH',
#   'zqmgGLdwO',
#   'xckzyPAU',
#   'OvrHndy',
#   'lvKIoW',
#   'CyGXZQu',
#   'bAbSURgiKS',
#   'iRLK',
#   'gtWdrYojB',
#   'oWFxOr',
#   'EUloisjEB',
#   'AZGBe',
#   'vgUejBpYW',
#   'oxyAnt',
#   'jxlI',
#   'AOWtG',
#   'snilv',
#   'mHDfik',
#   'SdFUvO',
#   'VLFBIQ',
#   'KVIwmVMbkI',
#   'jKTdKZwiP',
#   'ZcygPjs',
#   'pKCkSgufw',
#   'egomDOsMde',
#   'EXfA',
#   'NmcOPLR',
#   'IyCRwtnR',
#   'jgkWy',
#   'BNKe',
#   'WYeNW',
#   'KOHKRljjkd',
#   'TYOFSGsGr',
#   'tjDVQMQQr',
#   'djxHVhB',
#   'lXSfQA',
#   'lRjrkNs',
#   'UNvKe',
#   'KssDBFB',
#   'HbfrQgqW',
#   'KtIW',
#   'NySz',
#   'cmlkdbh',
#   'KNcsXLlz',
#   'bOxsGyt',
#   'JUVTGZIc',
#   'oAHSv',
#   'vejZI',
#   'cJGJo',
#   'qLfnRZE',
#   'NOMoUC',
#   'hCAqGBnhf',
#   'MyCHx',
#   'ArGP',
#   'DSkjXOupVT',
#   'SkOUyers',
#   'UvFvU',
#   'pPWgyBneM',
#   'DSGVFxBvoH',
#   'UmePhx',
#   'iPjerOyhCD',
#   'zbKXzt',
#   'ctdSn',
#   'ZWMdBzGw',
#   'MqbKLuv',
#   'wLiYyL',
#   'dlWVGzo',
#   'FkYpbDuxs',
#   'fjBRNtlI',
#   'RwfgJUakrL',
#   'ZpySwQS',
#   'CibgZuG',
#   'YYwfLluebt',
#   'zkGB',
#   'tFwYBDQrjU',
#   'gqyMjNDV',
#   'qRmOthKGGa',
#   'WVCkLC',
#   'RmdISLC',
#   'NnxxzX',
#   'QAnCar',
#   'qSjWtfjbu',
#   'qNCtGNVr',
#   'jhLLD',
#   'LTnQuUcBI',
#   'vAekxE',
#   'DFBB',
#   'aEaAUhEBJ',
#   'pIVyXnbc',
#   'Lzuqexndm',
#   'XTsg',
#   'kaeYX',
#   'yCcZsD',
#   'twoPT',
#   'BFAzsWXNW',
#   'frmhN',
#   'WFKzkQLsfy',
#   'mdaKY',
#   'mFZyHI',
#   'XuHjnbboNe',
#   'QbaNmjHY',
#   'TtFj',
#   'HYqJ',
#   'tjTqX',
#   'LiWVM',
#   'jcxhxS',
#   'kQUkpnlVn',
#   'GNcRMoS',
#   'TaZB',
#   'Ynjcmz',
#   'OpHVxDFt',
#   'eoDLwDJXZk',
#   'htZXWV',
#   'YJkr',
#   'ihOAem',
#   'dCPBt',
#   'ELLv',
#   'qANF',
#   'UUBej',
#   'kqdm',
#   'ASVX',
#   'afzEits',
#   'FbPdONLlDg',
#   'jOBfLQKK',
#   'NfUrO',
#   'atKwyPJy',
#   'OiAusT',
#   'NAQhHhBPO',
#   'XtJn',
#   'MfhHEIeeaN',
#   'ckPQ',
#   'jxPph',
#   'sovU',
#   'QeicIQPgH',
#   'OktvMtSHr',
#   'hxidyJhaW',
#   'Xizo',
#   'xrhsnnHbhZ',
#   'YcWrEUvz',
#   'ntPJwQ',
#   'kWQUZqbT',
#   'pikTsIww',
#   'ZMTV',
#   'TwvGdScHnP',
#   'FHkEfsZs',
#   'dAaXlmdqES',
#   'VeqJLXWrLh',
#   'IOoUEEX',
#   'njDhcXXWx',
#   'FgwUO',
#   'zXiB',
#   'qPOy',
#   'chjO',
#   'kbrChs',
#   'GTcfTQKvnV',
#   'IHEuRtL',
#   'jVEN',
#   'nMqsXo',
#   'fIYa',
#   'BpPbeGyf',
#   'SQOpqBMPHw',
#   'acQHzUmWrr',
#   'HVFnZj',
#   'kHvGpQJX',
#   'mOOwiDnMDT',
#   'sTMa',
#   'YNKXLPQDT',
#   'kBYnGB',
#   'uwdRcwfcHP',
#   'HCDTM',
#   'vjhE',
#   'iIEnkDphIO',
#   'wMpqVXq',
#   'QzGOX',
#   'sKQjwa',
#   'zgktGZs',
#   'gbLUZw',
#   'IktkpkIb',
#   'AGGrkD',
#   'SwSMGU',
#   'hMveylbqP',
#   'hKqDQ',
#   'scwjOBNipv',
#   'oTgKSC',
#   'fuJiwa',
#   'bVWQraar',
#   'aSpCqdGpHp',
#   'YFTZ',
#   'QHFsdeuygD',
#   'CELfxkBpxJ',
#   'siObkC',
#   'RQwpzoJ',
#   'HYNC',
#   'sUzeYWx',
#   'GddVWyFyWk',
#   'cLcuVgyrV',
#   'VOamLGtHSV',
#   'jIUgkWtniZ',
#   'tKWwy',
#   'kpvNnqOvmV',
#   'uEvrvV',
#   'UGSdFiQxLO',
#   'VRDuuk',
#   'ZPJTN',
#   'uWpHTF',
#   'CsdtylwPY',
#   'BGlUVl',
#   'WIyfwCMgZ',
#   'DOizWn',
#   'ULIDJSEuEQ',
#   'xqgfIt',
#   'TvZsNSAxt',
#   'gmdh',
#   'XaiEqlNAx',
#   'ijNNK',
#   'AUCX',
#   'lcrEBL',
#   'HHcu',
#   'GWlITairng',
#   'niiUJxv',
#   'ziqKdEWSq',
#   'pixECfasG',
#   'PAyC',
#   'vHNEPbqXmx',
#   'wpXV',
#   'DTlnBu',
#   'Iuvm',
#   'gGBnbrXev',
#   'CuFwcPexMN',
#   'WmAjNcGHlx',
#   'BRtGEI',
#   'HxolYq',
#   'BbaSuzdN',
#   'EHdoxAx',
#   'HSVn',
#   'ITZzuJLaJ',
#   'ZftYmnE',
#   'pKklXYTZE',
#   'IOerDZvNZk',
#   'NHQKXgANQ',
#   'PoVSohJJ',
#   'SLKn',
#   'gINOJDTwhn',
#   'YltLu',
#   'OemJKlSGH',
#   'lKXrxktX',
#   'mcTCDMH',
#   'SIeWQKE',
#   'Yebcci',
#   'QZqssyO',
#   'hgwBiVZts',
#   'dxcOBrenI',
#   'wlttVaZZXK',
#   'GuPggHE',
#   'FOLeiwMxdJ',
#   'bTkd',
#   'qeucmCo',
#   'KcPIMf',
#   'BTRznWfi',
#   'kengifzyW',
#   'yJZfuwyST',
#   'glCABJTvPx',
#   'JBSIrt',
#   'CSkity',
#   'aGyewn',
#   'OzWp',
#   'BGrI',
#   'AjsjLe',
#   'lDzIHh',
#   'qFFGVXSg',
#   'EGZt',
#   'lbxjcAa',
#   'SRQlzgsA',
#   'gExFilg',
#   'FdEzkVcnOw',
#   'SygFnW',
#   'VbdWqBNNYw',
#   'VYFKEns',
#   'tWbPnvQ',
#   'lGuCbJMF',
#   'SsMOIoSTIg',
#   'yEIYsiuYHD',
#   'vaFVus',
#   'NWqcyDw',
#   'NozIGFFNnw',
#   'vyCVkOf',
#   'coSURKzx',
#   'qqVCXErUm',
#   'wffvAsDCF',
#   'SqaY',
#   'uHZu',
#   'HzFv',
#   'iIImqdSsDR',
#   'cYssBJWVW',
#   'hsFGiL',
#   'awvmJOgGp',
#   'IGgugbk',
#   'HzFSyOFLU',
#   'aszlnitf',
#   'GjjEkOmNYf',
#   'vAhctL',
#   'sPPIlBrOyA',
#   'PwFGhKVTs',
#   'zDrjSWKXn',
#   'oEeqYAPFIU',
#   'OARYhujBOh',
#   'xguyIjL',
#   'wooby',
#   'Ufmd',
#   'lodwXNLGo',
#   'ionPIBd',
#   'aTjlN',
#   'rjMktMHr',
#   'KjCIO',
#   'sjdfxLIscZ',
#   'rkdOLbOm',
#   'kYuUHrzY',
#   'SgWx',
#   'VbgIh',
#   'nxIHdZl',
#   'aVyZviqVbY',
#   'AxFxfesq',
#   'oYVWaLS',
#   'jhIlWqDuGA',
#   'vRkpUeim',
#   'aCkIGQtKgs',
#   'RUgz',
#   'PzqVQdEOWo',
#   'qzmcCdXNm',
#   'bVlqtfr',
#   'Owdr',
#   'eWKklclL',
#   'SlalHnNjW',
#   'KoMvZ',
#   'ecCC',
#   'dyxChI',
#   'nLrgMtCLCG',
#   'ATtdHjcB',
#   'fosCjLkH',
#   'MadUVzqFEh',
#   'yKyKyXhDcu',
#   'lTihsSasd',
#   'vgsvtYs',
#   'qIKtwmZX',
#   'mRVbn',
#   'BVQoJyG',
#   'PZgpu',
#   'wpqZNw',
#   'rnOoxLVs',
#   'Andk',
#   'tlvOOZaKz',
#   'fThtvklGJm',
#   'DFfaeTr',
#   'tLRuNbMj',
#   'SgWy',
#   'SZtZFNApm',
#   'TDhU',
#   'SybKXQyfB',
#   'CKfWzHIGb',
#   'NHBSsiLT',
#   'eqowKYoMN',
#   'mPwoqeDYX',
#   'NvxE',
#   'mgdXK',
#   'tuVHoe',
#   'MShBbhqwc',
#   'JaEPnZbjf',
#   'WWBpBzKz',
#   'zIQcuRPUkt',
#   'dPoQnmfc',
#   'rwlPFCmYY',
#   'drOpSteStb',
#   'LdLao',
#   'cySMeS',
#   'IvJfzws',
#   'hvSfP',
#   'zrilo',
#   'dZRNatz',
#   'vBeoQIK',
#   'DrPeFzZ',
#   'EriRCWrQO',
#   'gugT',
#   'AJzElTXEi',
#   'URdZaGDt',
#   'MGHCAsKSx',
#   'MejDimxDny',
#   'iUQwTkN',
#   'TrTCDudmP',
#   'cTjUgFoj',
#   'ZuoAIwW',
#   'ndNYNADmad',
#   'vwnxEmzZip',
#   'cVJAi',
#   'zJoQRiClDW',
#   'mdRytTNt',
#   'wwRVgmXFl',
#   'RLXBCa',
#   'iDeQHuYu',
#   'leXM',
#   'buxF',
#   'KifEPYn',
#   'RwaFRegi',
#   'fUcZ',
#   'dfYcvmEC',
#   'TtyceYM',
#   'lbdYy',
#   'AdKLwE',
#   'KzwvLiGIJX',
#   'eaRk',
#   'YrWMo',
#   'gYKD',
#   'JIPunMfCk',
#   'QXVegQJGV',
#   'FwGnESUEav',
#   'IxCLl',
#   'arnXSUqKVp',
#   'mJLupVzs',
#   'BLmSWkP',
#   'ifiL',
#   'XrFSFIkl',
#   'pMvlWOaGB',
#   'HRCSTGVa',
#   'MwgjAw',
#   'JSRyHWkxB',
#   'IIHcsTf',
#   'wpRwGPXL',
#   'nrNWinh',
#   'YFKwQXid',
#   'wVjiS',
#   'nOla',
#   'KKxyrua',
#   'UJtzbAmqgx',
#   'VuhTcRJPN',
#   'ytTzS',
#   'YEgOQwbzoE',
#   'yZCaB',
#   'ItwW',
#   'VLPzYIg',
#   'eQrvWVfU',
#   'qTOZUE',
#   'YrzlmLcHVi',
#   'rfkggJ',
#   'UAfHXYYHY',
#   'XiqFoX',
#   'OKjgNI',
#   'mfJiW',
#   'EdCXBCX',
#   'jMGntjUTS',
#   'YfTXRxVMqT',
#   'TsSSZNrxjt',
#   'vHRHce',
#   'tRDjnB',
#   'yKymdcEHCd',
#   'JBxdYhJBGE',
#   'ISOhb',
#   'rQSrqcJMXi',
#   'SscVw',
#   'LALGhWzu',
#   'zQIP',
#   'ZToDkU',
#   'VmHojWkNlK',
#   'gEXrVJ',
#   'aogx',
#   'HmSaQ',
#   'zZwL',
#   'qZkGrezr',
#   'jlMyHXltC',
#   'ZVvpme',
#   'JwOBzwn',
#   'ETLtS',
#   'tQmfXA',
#   'hujg',
#   'gIAZD',
#   'zadgbZS',
#   'KzIaJJSFhZ',
#   'VKHCbBbfn',
#   'ruDkX',
#   'YgGpbCZTh',
#   'ASJP',
#   'YlMmKFjZmQ',
#   'gssIxTftQ',
#   'opSwhlO',
#   'TzuCewgkA',
#   'TxfWzsqGk',
#   'KHeWK',
#   'EDQJOw',
#   'FmOoCxYh',
#   'hTbOJgg',
#   'kxPd',
#   'eYHLQVRVc',
#   'nEZEeHp',
#   'Pdxs',
#   'qefCWvNz',
#   'hlfrHSv',
#   'GOKjhBjX',
#   'ybdtXPQ',
#   'EdIxWsjb',
#   'VZdW',
#   'wqlpEFVo',
#   'CENIpQf',
#   'KNOaU',
#   'WjJUwciqwv',
#   'ETiUxvxizE',
#   'nRitaq',
#   'lbsp',
#   'rtpfh',
#   'zTxQFTp',
#   'OBJWm',
#   'cVfWRxXoS',
#   'rIlJsG',
#   'roctb',
#   'Csabpdpny',
#   'SayBxn',
#   'VdiL',
#   'yPqRsv',
#   'UrDb',
#   'lNrWzvuXV',
#   'mHHh',
#   'DuYlRpjJsb',
#   'idXMliJ',
#   'brBu',
#   'gFpsNVy',
#   'NMJWGky',
#   'NMkxTlNv',
#   'eDpXWhJcyS',
#   'WySXXHMhMj',
#   'PAnXc',
#   'qTSYwRVV',
#   'mEaVEiHhz',
#   'pPIJpMETO',
#   'QCXlVstVR',
#   'CHkUwFecfV',
#   'zisYhLLJc',
#   'INCpBYh',
#   'sNtp',
#   'BoGrTGjoL',
#   'AbZQqQyBlh',
#   'bJsPa',
#   'OfNZ',
#   'xhIeNXiZIu',
#   'BfaYif',
#   'ycJj',
#   'aFeIu',
#   'XIYAQggeq',
#   'isuBCGY',
#   'kDHsccNjIS',
#   'zTpZ',
#   'DJcH',
#   'XeKDuM',
#   'Fggq',
#   'feKJ',
#   'LtoVD',
#   'OdcOuUV',
#   'skImbUQ',
#   'PVpQkQme',
#   'ENvIIBEvoH',
#   'otVDMQECc',
#   'usIO',
#   'toOItRagEi',
#   'nuJLkxk',
#   'lxfgvXt',
#   'uoLLhWnm',
#   'VhikmjiZa',
#   'KiLIkDvl',
#   'MVEeI',
#   'aLaJEnp',
#   'bzHQDWQOON',
#   'wvAngRY',
#   'WsFGPg',
#   'XZsEODzbEe',
#   'mUvKLtC',
#   'NTNZrll',
#   'AHTkaM',
#   'CLmaUPkV',
#   'XVFO',
#   'MzGgnn',
#   'Olbnypg',
#   'CDOsjIQtlP',
#   'HpQezZTkg',
#   'rtDoJa',
#   'AMJhhqDd',
#   'YRXMLt',
#   'yQEs',
#   'WNfNaLFsN',
#   'WmhuzB',
#   'tEgAXCr',
#   'lKIKYQGjEq',
#   'UVZRUjaplJ',
#   'KHORoZaHWZ',
#   'TODvYmDh',
#   'JYucqr',
#   'pikExXo',
#   'ayySmxT',
#   'NsWRzUQzzi',
#   'uumZYSem',
#   'WRlWCBIR',
#   'jRosplBC',
#   'MwledqFZO',
#   'drsSV',
#   'HaQu',
#   'uQqU',
#   'bWpDoiTea',
#   'DrAle',
#   'XCxUqUtt',
#   'PRJYv',
#   'HHETNYN',
#   'xzGmbbYuUb',
#   'UfFvuCK',
#   'RBtJPwyBS',
#   'LmihO',
#   'loDehrv',
#   'fhQrYfXrSj',
#   'zuAZWmYy',
#   'tUGfKgFL',
#   'skGX',
#   'voBoApp',
#   'MCxybkouI',
#   'rLgddFL',
#   'nQjG',
#   'dluLsbHlot',
#   'VDbYpDny',
#   'mVaQhKF',
#   'bZxm',
#   'EQezFibmtmUSbegMzhZwQAkxzCqREFPIQtpTElMUKABopyTjqQtIBvCuLyjZcKLChsFnDdLhTFiibkihqljKcDPrQmuysCOdOKvC',
# ...
#   'ifiL',
#   'XrFSFIkl',
#   'pMvlWOaGB',
#   'HRCSTGVa',
#   'MwgjAw',
#   'JSRyHWkxB',
#   'IIHcsTf',
#   'wpRwGPXL',
#   'nrNWinh',
#   'YFKwQXid',
#   'wVjiS',
#   'nOla',
#   'KKxyrua',
#   'UJtzbAmqgx',
#   'VuhTcRJPN',
#   'ytTzS',
#   'YEgOQwbzoE',
#   'yZCaB',
#   'ItwW',
#   'VLPzYIg',
#   'eQrvWVfU',
#   'qTOZUE',
#   'YrzlmLcHVi',
#   'rfkggJ',
#   'UAfHXYYHY',
#   'XiqFoX',
#   'OKjgNI',
#   'mfJiW',
#   'EdCXBCX',
#   'jMGntjUTS',
#   'YfTXRxVMqT',
#   'TsSSZNrxjt',
#   'vHRHce',
#   'tRDjnB',
#   'yKymdcEHCd',
#   'JBxdYhJBGE',
#   'ISOhb',
#   'rQSrqcJMXi',
#   'SscVw',
#   'LALGhWzu',
#   'zQIP',
#   'ZToDkU',
#   'VmHojWkNlK',
#   'gEXrVJ',
#   'aogx',
#   'HmSaQ',
#   'zZwL',
#   'qZkGrezr',
#   'jlMyHXltC',
#   'ZVvpme',
#   'JwOBzwn',
#   'ETLtS',
#   'tQmfXA',
#   'hujg',
#   'gIAZD',
#   'zadgbZS',
#   'KzIaJJSFhZ',
#   'VKHCbBbfn',
#   'ruDkX',
#   'YgGpbCZTh',
#   'ASJP',
#   'YlMmKFjZmQ',
#   'gssIxTftQ',
#   'opSwhlO',
#   'TzuCewgkA',
#   'TxfWzsqGk',
#   'KHeWK',
#   'EDQJOw',
#   'FmOoCxYh',
#   'hTbOJgg',
#   'kxPd',
#   'eYHLQVRVc',
#   'nEZEeHp',
#   'Pdxs',
#   'qefCWvNz',
#   'hlfrHSv',
#   'GOKjhBjX',
#   'ybdtXPQ',
#   'EdIxWsjb',
#   'VZdW',
#   'wqlpEFVo',
#   'CENIpQf',
#   'KNOaU',
#   'WjJUwciqwv',
#   'ETiUxvxizE',
#   'nRitaq',
#   'lbsp',
#   'rtpfh',
#   'zTxQFTp',
#   'OBJWm',
#   'cVfWRxXoS',
#   'rIlJsG',
#   'roctb',
#   'Csabpdpny',
#   'SayBxn',
#   'VdiL',
#   'yPqRsv',
#   'UrDb',
#   'lNrWzvuXV',
#   'mHHh',
#   'DuYlRpjJsb',
#   'idXMliJ',
#   'brBu',
#   'gFpsNVy',
#   'NMJWGky',
#   'NMkxTlNv',
#   'eDpXWhJcyS',
#   'WySXXHMhMj',
#   'PAnXc',
#   'qTSYwRVV',
#   'mEaVEiHhz',
#   'pPIJpMETO',
#   'QCXlVstVR',
#   'CHkUwFecfV',
#   'zisYhLLJc',
#   'INCpBYh',
#   'sNtp',
#   'BoGrTGjoL',
#   'AbZQqQyBlh',
#   'bJsPa',
#   'OfNZ',
#   'xhIeNXiZIu',
#   'BfaYif',
#   'ycJj',
#   'aFeIu',
#   'XIYAQggeq',
#   'isuBCGY',
#   'kDHsccNjIS',
#   'zTpZ',
#   'DJcH',
#   'XeKDuM',
#   'Fggq',
#   'feKJ',
#   'LtoVD',
#   'OdcOuUV',
#   'skImbUQ',
#   'PVpQkQme',
#   'ENvIIBEvoH',
#   'otVDMQECc',
#   'usIO',
#   'toOItRagEi',
#   'nuJLkxk',
#   'lxfgvXt',
#   'uoLLhWnm',
#   'VhikmjiZa',
#   'KiLIkDvl',
#   'MVEeI',
#   'aLaJEnp',
#   'bzHQDWQOON',
#   'wvAngRY',
#   'WsFGPg',
#   'XZsEODzbEe',
#   'mUvKLtC',
#   'NTNZrll',
#   'AHTkaM',
#   'CLmaUPkV',
#   'XVFO',
#   'MzGgnn',
#   'Olbnypg',
#   'CDOsjIQtlP',
#   'HpQezZTkg',
#   'rtDoJa',
#   'AMJhhqDd',
#   'YRXMLt',
#   'yQEs',
#   'WNfNaLFsN',
#   'WmhuzB',
#   'tEgAXCr',
#   'lKIKYQGjEq',
#   'UVZRUjaplJ',
#   'KHORoZaHWZ',
#   'TODvYmDh',
#   'JYucqr',
#   'pikExXo',
#   'ayySmxT',
#   'NsWRzUQzzi',
#   'uumZYSem',
#   'WRlWCBIR',
#   'jRosplBC',
#   'MwledqFZO',
#   'drsSV',
#   'HaQu',
#   'uQqU',
#   'bWpDoiTea',
#   'DrAle',
#   'XCxUqUtt',
#   'PRJYv',
#   'HHETNYN',
#   'xzGmbbYuUb',
#   'UfFvuCK',
#   'RBtJPwyBS',
#   'LmihO',
#   'loDehrv',
#   'fhQrYfXrSj',
#   'zuAZWmYy',
#   'tUGfKgFL',
#   'skGX',
#   'voBoApp',
#   'MCxybkouI',
#   'rLgddFL',
#   'nQjG',
#   'dluLsbHlot',
#   'VDbYpDny',
#   'mVaQhKF',
#   'bZxm',
#   'ptxlsNxb',
#   'hUzQPo',
#   'rZZL',
#   'drCq',
#   'QuYHjbtQ',
#   'zjSFtPVZG',
#   'hxTRorX',
#   'IuKEzJXk',
#   'PciSje',
#   'vHIsZu',
#   'omqr',
#   'ZNUZ',
#   'bQZSufNJBy',
#   'jIrbb',
#   'YMoO',
#   ...],
#  ['fdYgCb',
#   'EmiHuRcsuG',
#   'LFYdLzTjM',
#   'GByrtshVGt',
#   'OktODd',
#   'swGhCJtlU',
#   'MgwXF',
#   'iVzl',
#   'NqbhOBBuK',
#   'emCOXs',
#   'oDIROugT',
#   'BpGq',
#   'AtLotUE',
#   'jadzjETY',
#   'NZgX',
#   'DWNFCGemiE',
#   'qiCXFNnLmM',
#   'fVPKDfl',
#   'ordncstoOq',
#   'mDunpFYC',
#   'mqkauCLZYt',
#   'jKzPyWXu',
#   'EywsoUQS',
#   'xVwNeE',
#   'kyTYLmDL',
#   'XjLwlLV',
#   'osMV',
#   'Gixp',
#   'fWPxp',
#   'HXqzQkvafX',
#   'fjgsvAuSBe',
#   'sOVLWVs',
#   'RNpURbfQQ',
#   'WFQNBc',
#   'mtYCaV',
#   'vkKwsBbdz',
#   'nRkBpiSpDo',
#   'IDnQPrXdfK',
#   'qFxTUK',
#   'hwyvy',
#   'twFqeZMr',
#   'SvzOiTLPJb',
#   'bCeE',
#   'JxpBVBKlR',
#   'ipiOAr',
#   'sJnwJVv',
#   'shzptAsYg',
#   'HvUEfG',
#   'DxCE',
#   'bRYQBIn',
#   'onbKPE',
#   'pPHV',
#   'lbeCfzkn',
#   'WmfBdiG',
#   'iqfiIMK',
#   'TssaajdL',
#   'QJNtJT',
#   'keFFeMJIm',
#   'saihB',
#   'yYkYIuSw',
#   'NeJQaaLnJ',
#   'NqdZ',
#   'hGQECEo',
#   'ijKnqNfscL',
#   'BXFWOXmnzj',
#   'wnFGzVY',
#   'JLnICKhwV',
#   'fwbGKJ',
#   'Ekzy',
#   'ynlOqUj',
#   'aYbPYXki',
#   'kxGrfwof',
#   'DBtg',
#   'krKbwO',
#   'lpCuBVOF',
#   'mPQeQCV',
#   'SImv',
#   'vgxSQtm',
#   'BvSZoII',
#   'TFvA',
#   'jmlIpXwoxM',
#   'zzZISYcqNr',
#   'HjxfekLxoF',
#   'wNBQ',
#   'xjQOILsmI',
#   'KxPY',
#   'kKooMo',
#   'bQpOfx',
#   'yhYBIwELc',
#   'HRiRbBAjx',
#   'dybIM',
#   'UqOhz',
#   'ghztLK',
#   'guEQS',
#   'iERsQnvjnY',
#   'WCLCnZ',
#   'MVNfueMZ',
#   'pTeIEpqYK',
#   'wdjTK',
#   'uZSB',
#   'MkRbGkBU',
#   'fyMIdi',
#   'WlTAryTgzA',
#   'nzRYK',
#   'uqSkXOvxne',
#   'FcyyLCj',
#   'NvpJh',
#   'nEquzrp',
#   'wwdG',
#   'XvuY',
#   'ryAXg',
#   'Kaxwi',
#   'OFnXND',
#   'IkShzJ',
#   'GwAbg',
#   'HqFxmTTaAM',
#   'SgQiwwe',
#   'NXEuBGww',
#   'pPOhSkDrec',
#   'ysjyq',
#   'JdiIIOCrlK',
#   'trApdWQ',
#   'UjVzZ',
#   'XWpvr',
#   'wsyewpWN',
#   'aisdc',
#   'KNHWDLtoE',
#   'BuyI',
#   'OxVKupbAXV',
#   'cGhAhs',
#   'SNFO',
#   'XYYEk',
#   'oWktMDc',
#   'BLSxXXt',
#   'xWgYs',
#   'sUHXUvcnvo',
#   'lGKNptnHH',
#   'xIsCzuQN',
#   'PWnkUHHsI',
#   'IgoNQeXwO',
#   'eyKV',
#   'wburzVvN',
#   'SINLZB',
#   'AmJHAosj',
#   'WdZxLcpHm',
#   'QCWuAUubrc',
#   'VDwuIiWJPS',
#   'azGiHCgq',
#   'QJqvVE',
#   'jEzTnHnf',
#   'kPHuZawz',
#   'bRJKCxk',
#   'QBzOqc',
#   'JGnUJbe',
#   'lAiV',
#   'nSaRAumqg',
#   'rkXgpY',
#   'kdvbWXoqI',
#   'bFRwH',
#   'VdlYHt',
#   'RZcqJDLm',
#   'KgfJdAM',
#   'yoZPO',
#   'NHNQYb',
#   'KyLxBDSy',
#   'RHhByYBbP',
#   'MZCDSMax',
#   'CVdEaBHj',
#   'NeFuaE',
#   'LdJyhAcWVd',
#   'EpaEkmMy',
#   'oJGxdgWxB',
#   'jeJEUhh',
#   'ZTkKJ',
#   'DlOoJAOer',
#   'DUixBe',
#   'qRIGXD',
#   'kMWRn',
#   'WDcU',
#   'QziQdl',
#   'NswGaPi',
#   'AMiWyb',
#   'CZpWaBJu',
#   'UFGdrsMtkk',
#   'WylqkJw',
#   'LeKs',
#   'HkuSMZWwuG',
#   'VAvygq',
#   'sBjrmpq',
#   'HCvUoGe',
#   'iwUpGE',
#   'EdCMg',
#   'uRHvqpuiVd',
#   'EOODgzqaUJ',
#   'MWni',
#   'GlRrSk',
#   'VzxnA',
#   'tpNu',
#   'QuXbeukUy',
#   'DZwIx',
#   'WgVTyTez',
#   'RvPHMdeAA',
#   'EYdhoBHF',
#   'CirsM',
#   'pCFeCtzlto',
#   'wiGxh',
#   'kxTAm',
#   'siOAgeDn',
#   'wiJNfFZxCD',
#   'MabOZSmsJU',
#   'tUpULBsI',
#   'HYGDVlHIlS',
#   'sKIK',
#   'TlQx',
#   'kXqv',
#   'KhptXBSNU',
#   'tlgxeNSi',
#   'UCloNP',
#   'PzLqZeKtjg',
#   'fanutke',
#   'yyYLHxo',
#   'rpEjdgpxUa',
#   'ppiivYDnfo',
#   'XfAhIAy',
#   'cQQi',
#   'ObxKrmqYi',
#   'WnwLGNlI',
#   'QBFXxOqs',
#   'FlTwEQZm',
#   'ivVetBIe',
#   'RBWbeuYH',
#   'xclHmn',
#   'GAPKpZc',
#   'XTkdWj',
#   'Rfysq',
#   'YdgPqDg',
#   'qlNEVcCA',
#   'aJMrpJHbg',
#   'xDgsrcZ',
#   'muvcQx',
#   'wDSM',
#   'GDPN',
#   'EfwqX',
#   'kKcIzvKIR',
#   'UYkQ',
#   'loULGrIR',
#   'oALh',
#   'bVPXwaX',
#   'ANMkWaJQwP',
#   'dQnjM',
#   'rTcuQ',
#   'SoiNs',
#   'xshssWSqr',
#   'ESSAba',
#   'kYRxeCRDOr',
#   'qSCzfSb',
#   'aroIVQftHw',
#   'iZWmzDiprU',
#   'qJAUsZccq',
#   'rtCgaG',
#   'QGRzGNtc',
#   'RYlImrhrY',
#   'ZyMQLrIEma',
#   'UWDRpVv',
#   'eXYKYfE',
#   'YDGBVr',
#   'CXSiPdgf',
#   'SYyyDmLwbC',
#   'oVtAksIq',
#   'wTQBfs',
#   'DDir',
#   'tNdHHlr',
#   'wUGfTZ',
#   'chNET',
#   'lofs',
#   'pCDd',
#   'NUKxQ',
#   'QqKbHoErqj',
#   'MANsmMS',
#   'pDPvolEJ',
#   'YBOXfg',
#   'RfCXbre',
#   'XjnRKaAB',
#   'xIjaoOCg',
#   'DLnsraF',
#   'WwpwCcJTkl',
#   'HNGvDdxff',
#   'MqdKrkX',
#   'KibcgaYBaL',
#   'vMOosyYXWu',
#   'tNQaC',
#   'YqAURkW',
#   'FnAV',
#   'jYnwnDHvbt',
#   'eBuNvdnBzi',
#   'luKnrInU',
#   'QFzpcuCIE',
#   'TCprSwgzkH',
#   'xHuOTvGH',
#   'oNLlnK',
#   'pFOwyPfrr',
#   'agiK',
#   'cxOdBZh',
#   'wUfyltHv',
#   'DfpgaSlEs',
#   'XWbcQBG',
#   'nCbTAkr',
#   'bJEwYg',
#   'WvzI',
#   'Ibdm',
#   'fohMAuTKZP',
#   'GdrlQrPXz',
#   'hWktx',
#   'GxgczK',
#   'UxeHBLcOT',
#   'dlqgHsndT',
#   'PdawTXVFt',
#   'NbssBDZbz',
#   'NqSkiXMeK',
#   'HoWmoYbDN',
#   'vvqztzNu',
#   'ZoqPIP',
#   'MxhQGxh',
#   'nWBnBfBsWA',
#   'eSqgfzU',
#   'Nuyn',
#   'LefYWQ',
#   'hTDX',
#   'UuMlcSs',
#   'Nzch',
#   'kWgQxRQjXg',
#   'ThPqEFgHD',
#   'WMdBFfp',
#   'ynam',
#   'EUdI',
#   'oKeKH',
#   'ChHFbI',
#   'XTKq',
#   'JUYTlqgML',
#   'nMUVsO',
#   'IaijDd',
#   'ntMnPxcd',
#   'QMwWJ',
#   'mWQiaGL',
#   'xITVSZPrJI',
#   'yUQPuh',
#   'cwhzJ',
#   'MoKzFVS',
#   'rnvbWqLh',
#   'jhKpxyTBa',
#   'HsxToOFe',
#   'XPbwGPCbG',
#   'SFeKr',
#   'AQdljMT',
#   'Vwnukwd',
#   'vBxQPh',
#   'pwGmFV',
#   'OGnbJeuIWE',
#   'lXqzNix',
#   'OrhRb',
#   'ODcDdoYO',
#   'XprzEwmNR',
#   'aYsOWenFMH',
#   'zqmgGLdwO',
#   'xckzyPAU',
#   'OvrHndy',
#   'lvKIoW',
#   'CyGXZQu',
#   'bAbSURgiKS',
#   'iRLK',
#   'gtWdrYojB',
#   'oWFxOr',
#   'EUloisjEB',
#   'AZGBe',
#   'vgUejBpYW',
#   'oxyAnt',
#   'jxlI',
#   'AOWtG',
#   'snilv',
#   'mHDfik',
#   'SdFUvO',
#   'VLFBIQ',
#   'KVIwmVMbkI',
#   'jKTdKZwiP',
#   'ZcygPjs',
#   'pKCkSgufw',
#   'egomDOsMde',
#   'EXfA',
#   'NmcOPLR',
#   'IyCRwtnR',
#   'jgkWy',
#   'BNKe',
#   'WYeNW',
#   'KOHKRljjkd',
#   'TYOFSGsGr',
#   'tjDVQMQQr',
#   'djxHVhB',
#   'lXSfQA',
#   'lRjrkNs',
#   'UNvKe',
#   'KssDBFB',
#   'HbfrQgqW',
#   'KtIW',
#   'NySz',
#   'cmlkdbh',
#   'KNcsXLlz',
#   'bOxsGyt',
#   'JUVTGZIc',
#   'oAHSv',
#   'vejZI',
#   'cJGJo',
#   'qLfnRZE',
#   'NOMoUC',
#   'hCAqGBnhf',
#   'MyCHx',
#   'ArGP',
#   'DSkjXOupVT',
#   'SkOUyers',
#   'UvFvU',
#   'pPWgyBneM',
#   'DSGVFxBvoH',
#   'UmePhx',
#   'iPjerOyhCD',
#   'zbKXzt',
#   'ctdSn',
#   'ZWMdBzGw',
#   'MqbKLuv',
#   'wLiYyL',
#   'dlWVGzo',
#   'FkYpbDuxs',
#   'fjBRNtlI',
#   'RwfgJUakrL',
#   'ZpySwQS',
#   'CibgZuG',
#   'YYwfLluebt',
#   'zkGB',
#   'tFwYBDQrjU',
#   'gqyMjNDV',
#   'qRmOthKGGa',
#   'WVCkLC',
#   'RmdISLC',
#   'NnxxzX',
#   'QAnCar',
#   'qSjWtfjbu',
#   'qNCtGNVr',
#   'jhLLD',
#   'LTnQuUcBI',
#   'vAekxE',
#   'DFBB',
#   'aEaAUhEBJ',
#   'pIVyXnbc',
#   'Lzuqexndm',
#   'XTsg',
#   'kaeYX',
#   'yCcZsD',
#   'twoPT',
#   'BFAzsWXNW',
#   'frmhN',
#   'WFKzkQLsfy',
#   'mdaKY',
#   'mFZyHI',
#   'XuHjnbboNe',
#   'QbaNmjHY',
#   'TtFj',
#   'HYqJ',
#   'tjTqX',
#   'LiWVM',
#   'jcxhxS',
#   'kQUkpnlVn',
#   'GNcRMoS',
#   'TaZB',
#   'Ynjcmz',
#   'OpHVxDFt',
#   'eoDLwDJXZk',
#   'htZXWV',
#   'YJkr',
#   'ihOAem',
#   'dCPBt',
#   'ELLv',
#   'qANF',
#   'UUBej',
#   'kqdm',
#   'ASVX',
#   'afzEits',
#   'FbPdONLlDg',
#   'jOBfLQKK',
#   'NfUrO',
#   'atKwyPJy',
#   'OiAusT',
#   'NAQhHhBPO',
#   'XtJn',
#   'MfhHEIeeaN',
#   'ckPQ',
#   'jxPph',
#   'sovU',
#   'QeicIQPgH',
#   'OktvMtSHr',
#   'hxidyJhaW',
#   'Xizo',
#   'xrhsnnHbhZ',
#   'YcWrEUvz',
#   'ntPJwQ',
#   'kWQUZqbT',
#   'pikTsIww',
#   'ZMTV',
#   'TwvGdScHnP',
#   'FHkEfsZs',
#   'dAaXlmdqES',
#   'VeqJLXWrLh',
#   'IOoUEEX',
#   'njDhcXXWx',
#   'FgwUO',
#   'zXiB',
#   'qPOy',
#   'chjO',
#   'kbrChs',
#   'GTcfTQKvnV',
#   'IHEuRtL',
#   'jVEN',
#   'nMqsXo',
#   'fIYa',
#   'BpPbeGyf',
#   'SQOpqBMPHw',
#   'acQHzUmWrr',
#   'HVFnZj',
#   'kHvGpQJX',
#   'mOOwiDnMDT',
#   'sTMa',
#   'YNKXLPQDT',
#   'kBYnGB',
#   'uwdRcwfcHP',
#   'HCDTM',
#   'vjhE',
#   'iIEnkDphIO',
#   'wMpqVXq',
#   'QzGOX',
#   'sKQjwa',
#   'zgktGZs',
#   'gbLUZw',
#   'IktkpkIb',
#   'AGGrkD',
#   'SwSMGU',
#   'hMveylbqP',
#   'hKqDQ',
#   'scwjOBNipv',
#   'oTgKSC',
#   'fuJiwa',
#   'bVWQraar',
#   'aSpCqdGpHp',
#   'YFTZ',
#   'QHFsdeuygD',
#   'CELfxkBpxJ',
#   'siObkC',
#   'RQwpzoJ',
#   'HYNC',
#   'sUzeYWx',
#   'GddVWyFyWk',
#   'cLcuVgyrV',
#   'VOamLGtHSV',
#   'jIUgkWtniZ',
#   'tKWwy',
#   'kpvNnqOvmV',
#   'uEvrvV',
#   'UGSdFiQxLO',
#   'VRDuuk',
#   'ZPJTN',
#   'uWpHTF',
#   'CsdtylwPY',
#   'BGlUVl',
#   'WIyfwCMgZ',
#   'DOizWn',
#   'ULIDJSEuEQ',
#   'xqgfIt',
#   'TvZsNSAxt',
#   'gmdh',
#   'XaiEqlNAx',
#   'ijNNK',
#   'AUCX',
#   'lcrEBL',
#   'HHcu',
#   'GWlITairng',
#   'niiUJxv',
#   'ziqKdEWSq',
#   'pixECfasG',
#   'PAyC',
#   'vHNEPbqXmx',
#   'wpXV',
#   'DTlnBu',
#   'Iuvm',
#   'gGBnbrXev',
#   'CuFwcPexMN',
#   'WmAjNcGHlx',
#   'BRtGEI',
#   'HxolYq',
#   'BbaSuzdN',
#   'EHdoxAx',
#   'HSVn',
#   'ITZzuJLaJ',
#   'ZftYmnE',
#   'pKklXYTZE',
#   'IOerDZvNZk',
#   'NHQKXgANQ',
#   'PoVSohJJ',
#   'SLKn',
#   'gINOJDTwhn',
#   'YltLu',
#   'OemJKlSGH',
#   'lKXrxktX',
#   'mcTCDMH',
#   'SIeWQKE',
#   'Yebcci',
#   'QZqssyO',
#   'hgwBiVZts',
#   'dxcOBrenI',
#   'wlttVaZZXK',
#   'GuPggHE',
#   'FOLeiwMxdJ',
#   'bTkd',
#   'qeucmCo',
#   'KcPIMf',
#   'BTRznWfi',
#   'kengifzyW',
#   'yJZfuwyST',
#   'glCABJTvPx',
#   'JBSIrt',
#   'CSkity',
#   'aGyewn',
#   'OzWp',
#   'BGrI',
#   'AjsjLe',
#   'lDzIHh',
#   'qFFGVXSg',
#   'EGZt',
#   'lbxjcAa',
#   'SRQlzgsA',
#   'gExFilg',
#   'FdEzkVcnOw',
#   'SygFnW',
#   'VbdWqBNNYw',
#   'VYFKEns',
#   'tWbPnvQ',
#   'lGuCbJMF',
#   'SsMOIoSTIg',
#   'yEIYsiuYHD',
#   'vaFVus',
#   'NWqcyDw',
#   'NozIGFFNnw',
#   'vyCVkOf',
#   'coSURKzx',
#   'qqVCXErUm',
#   'wffvAsDCF',
#   'SqaY',
#   'uHZu',
#   'HzFv',
#   'iIImqdSsDR',
#   'cYssBJWVW',
#   'hsFGiL',
#   'awvmJOgGp',
#   'IGgugbk',
#   'HzFSyOFLU',
#   'aszlnitf',
#   'GjjEkOmNYf',
#   'vAhctL',
#   'sPPIlBrOyA',
#   'PwFGhKVTs',
#   'zDrjSWKXn',
#   'oEeqYAPFIU',
#   'OARYhujBOh',
#   'xguyIjL',
#   'wooby',
#   'Ufmd',
#   'lodwXNLGo',
#   'ionPIBd',
#   'aTjlN',
#   'rjMktMHr',
#   'KjCIO',
#   'sjdfxLIscZ',
#   'rkdOLbOm',
#   'kYuUHrzY',
#   'SgWx',
#   'VbgIh',
#   'nxIHdZl',
#   'aVyZviqVbY',
#   'AxFxfesq',
#   'oYVWaLS',
#   'jhIlWqDuGA',
#   'vRkpUeim',
#   'aCkIGQtKgs',
#   'RUgz',
#   'PzqVQdEOWo',
#   'qzmcCdXNm',
#   'bVlqtfr',
#   'Owdr',
#   'eWKklclL',
#   'SlalHnNjW',
#   'KoMvZ',
#   'ecCC',
#   'dyxChI',
#   'nLrgMtCLCG',
#   'ATtdHjcB',
#   'fosCjLkH',
#   'MadUVzqFEh',
#   'yKyKyXhDcu',
#   'lTihsSasd',
#   'vgsvtYs',
#   'qIKtwmZX',
#   'mRVbn',
#   'BVQoJyG',
#   'PZgpu',
#   'wpqZNw',
#   'rnOoxLVs',
#   'Andk',
#   'tlvOOZaKz',
#   'fThtvklGJm',
#   'DFfaeTr',
#   'tLRuNbMj',
#   'SgWy',
#   'SZtZFNApm',
#   'TDhU',
#   'SybKXQyfB',
#   'CKfWzHIGb',
#   'NHBSsiLT',
#   'eqowKYoMN',
#   'mPwoqeDYX',
#   'NvxE',
#   'mgdXK',
#   'tuVHoe',
#   'MShBbhqwc',
#   'JaEPnZbjf',
#   'WWBpBzKz',
#   'zIQcuRPUkt',
#   'dPoQnmfc',
#   'rwlPFCmYY',
#   'drOpSteStb',
#   'LdLao',
#   'cySMeS',
#   'IvJfzws',
#   'hvSfP',
#   'zrilo',
#   'dZRNatz',
#   'vBeoQIK',
#   'DrPeFzZ',
#   'EriRCWrQO',
#   'gugT',
#   'AJzElTXEi',
#   'URdZaGDt',
#   'MGHCAsKSx',
#   'MejDimxDny',
#   'iUQwTkN',
#   'TrTCDudmP',
#   'cTjUgFoj',
#   'ZuoAIwW',
#   'ndNYNADmad',
#   'vwnxEmzZip',
#   'cVJAi',
#   'zJoQRiClDW',
#   'mdRytTNt',
#   'wwRVgmXFl',
#   'RLXBCa',
#   'iDeQHuYu',
#   'leXM',
#   'buxF',
#   'KifEPYn',
#   'RwaFRegi',
#   'fUcZ',
#   'dfYcvmEC',
#   'TtyceYM',
#   'lbdYy',
#   'AdKLwE',
#   'KzwvLiGIJX',
#   'eaRk',
#   'YrWMo',
#   'gYKD',
#   'JIPunMfCk',
#   'QXVegQJGV',
#   'FwGnESUEav',
#   'IxCLl',
#   'arnXSUqKVp',
#   'mJLupVzs',
#   'BLmSWkP',
#   'ifiL',
#   'XrFSFIkl',
#   'pMvlWOaGB',
#   'HRCSTGVa',
#   'MwgjAw',
#   'JSRyHWkxB',
#   'IIHcsTf',
#   'wpRwGPXL',
#   'nrNWinh',
#   'YFKwQXid',
#   'wVjiS',
#   'nOla',
#   'KKxyrua',
#   'UJtzbAmqgx',
#   'VuhTcRJPN',
#   'ytTzS',
#   'YEgOQwbzoE',
#   'yZCaB',
#   'ItwW',
#   'VLPzYIg',
#   'eQrvWVfU',
#   'qTOZUE',
#   'YrzlmLcHVi',
#   'rfkggJ',
#   'UAfHXYYHY',
#   'XiqFoX',
#   'OKjgNI',
#   'mfJiW',
#   'EdCXBCX',
#   'jMGntjUTS',
#   'YfTXRxVMqT',
#   'TsSSZNrxjt',
#   'vHRHce',
#   'tRDjnB',
#   'yKymdcEHCd',
#   'JBxdYhJBGE',
#   'ISOhb',
#   'rQSrqcJMXi',
#   'SscVw',
#   'LALGhWzu',
#   'zQIP',
#   'ZToDkU',
#   'VmHojWkNlK',
#   'gEXrVJ',
#   'aogx',
#   'HmSaQ',
#   'zZwL',
#   'qZkGrezr',
#   'jlMyHXltC',
#   'ZVvpme',
#   'JwOBzwn',
#   'ETLtS',
#   'tQmfXA',
#   'hujg',
#   'gIAZD',
#   'zadgbZS',
#   'KzIaJJSFhZ',
#   'VKHCbBbfn',
#   'ruDkX',
#   'YgGpbCZTh',
#   'ASJP',
#   'YlMmKFjZmQ',
#   'gssIxTftQ',
#   'opSwhlO',
#   'TzuCewgkA',
#   'TxfWzsqGk',
#   'KHeWK',
#   'EDQJOw',
#   'FmOoCxYh',
#   'hTbOJgg',
#   'kxPd',
#   'eYHLQVRVc',
#   'nEZEeHp',
#   'Pdxs',
#   'qefCWvNz',
#   'hlfrHSv',
#   'GOKjhBjX',
#   'ybdtXPQ',
#   'EdIxWsjb',
#   'VZdW',
#   'wqlpEFVo',
#   'CENIpQf',
#   'KNOaU',
#   'WjJUwciqwv',
#   'ETiUxvxizE',
#   'nRitaq',
#   'lbsp',
#   'rtpfh',
#   'zTxQFTp',
#   'OBJWm',
#   'cVfWRxXoS',
#   'rIlJsG',
#   'roctb',
#   'Csabpdpny',
#   'SayBxn',
#   'VdiL',
#   'yPqRsv',
#   'UrDb',
#   'lNrWzvuXV',
#   'mHHh',
#   'DuYlRpjJsb',
#   'idXMliJ',
#   'brBu',
#   'gFpsNVy',
#   'NMJWGky',
#   'NMkxTlNv',
#   'eDpXWhJcyS',
#   'WySXXHMhMj',
#   'PAnXc',
#   'qTSYwRVV',
#   'mEaVEiHhz',
#   'pPIJpMETO',
#   'QCXlVstVR',
#   'CHkUwFecfV',
#   'zisYhLLJc',
#   'INCpBYh',
#   'sNtp',
#   'BoGrTGjoL',
#   'AbZQqQyBlh',
#   'bJsPa',
#   'OfNZ',
#   'xhIeNXiZIu',
#   'BfaYif',
#   'ycJj',
#   'aFeIu',
#   'XIYAQggeq',
#   'isuBCGY',
#   'kDHsccNjIS',
#   'zTpZ',
#   'DJcH',
#   'XeKDuM',
#   'Fggq',
#   'feKJ',
#   'LtoVD',
#   'OdcOuUV',
#   'skImbUQ',
#   'PVpQkQme',
#   'ENvIIBEvoH',
#   'otVDMQECc',
#   'usIO',
#   'toOItRagEi',
#   'nuJLkxk',
#   'lxfgvXt',
#   'uoLLhWnm',
#   'VhikmjiZa',
#   'KiLIkDvl',
#   'MVEeI',
#   'aLaJEnp',
#   'bzHQDWQOON',
#   'wvAngRY',
#   'WsFGPg',
#   'XZsEODzbEe',
#   'mUvKLtC',
#   'NTNZrll',
#   'AHTkaM',
#   'CLmaUPkV',
#   'XVFO',
#   'MzGgnn',
#   'Olbnypg',
#   'CDOsjIQtlP',
#   'HpQezZTkg',
#   'rtDoJa',
#   'AMJhhqDd',
#   'YRXMLt',
#   'yQEs',
#   'WNfNaLFsN',
#   'WmhuzB',
#   'tEgAXCr',
#   'lKIKYQGjEq',
#   'UVZRUjaplJ',
#   'KHORoZaHWZ',
#   'TODvYmDh',
#   'JYucqr',
#   'pikExXo',
#   'ayySmxT',
#   'NsWRzUQzzi',
#   'uumZYSem',
#   'WRlWCBIR',
#   'jRosplBC',
#   'MwledqFZO',
#   'drsSV',
#   'HaQu',
#   'uQqU',
#   'bWpDoiTea',
#   'DrAle',
#   'XCxUqUtt',
#   'PRJYv',
#   'HHETNYN',
#   'xzGmbbYuUb',
#   'UfFvuCK',
#   'RBtJPwyBS',
#   'LmihO',
#   'loDehrv',
#   'fhQrYfXrSj',
#   'zuAZWmYy',
#   'tUGfKgFL',
#   'skGX',
#   'voBoApp',
#   'MCxybkouI',
#   'rLgddFL',
#   'nQjG',
#   'dluLsbHlot',
#   'VDbYpDny',
#   'mVaQhKF',
#   'bZxm',
#   'ptxlsNxb',
#   'hUzQPo',
#   'rZZL',
#   'drCq',
#   'QuYHjbtQ',
#   'zjSFtPVZG',
#   'hxTRorX',
#   'IuKEzJXk',
#   'PciSje',
#   'vHIsZu',
#   'omqr',
#   'ZNUZ',
#   'bQZSufNJBy',
#   'jIrbb',
#   'YMoO',
#   ...]]

# %% [markdown]
# #### Insert Time Taken

# %%
def InsertTime2(classname, datalist):
    # Remove Duplicates
    seen = {}
    uniqueDatas = []
    for e in datalist:
        if e not in seen:
            seen[e] = True
            uniqueDatas.append(e)
    
    algorithm = classname()
    if str(classname) == str(BloomFilterSet):
        algorithm.initVariables(len(datalist), 0.01, hashFunctions)

    InsertStart = timeit.default_timer()
    res = []
    for word in uniqueDatas:
        # Remove Missing Values
        if word is not None:
            inserted = algorithm.insertElement(word)
            res.append(inserted)
    InsertEnd = timeit.default_timer()
    InsertTime = InsertEnd - InsertStart
    print("Insert time taken is :", InsertTime)
    return algorithm, res

# %%
SEQSyn, BSTSyn, RBTSyn, BTSyn = [], [], [], []
InsertRes1, InsertRes2, InsertRes3, InsertRes4, InsertRes5 = [], [], [], [], []
for i in range(len(SyntheticDataList)):
    print("For", SyntheticDataNames[i], "Case: ")
    print("Sequential Search: ")
    SEQ, res1 = InsertTime2(SequentialSearchSet, SyntheticDataList[i])
    SEQSyn.append(SEQ)
    InsertRes1.append(res1)
    print("Binary Search Tree: ")
    BST, res2 = InsertTime2(BinarySearchTreeSet, SyntheticDataList[i])
    BSTSyn.append(BST)
    InsertRes2.append(res2)
    print("Balanced Search Tree: ")
    RBT, res3 = InsertTime2(BalancedSearchTreeSet, SyntheticDataList[i])
    RBTSyn.append(RBT)
    InsertRes3.append(res3)
    print("2-3 Search Tree: ")
    TTST, res4 = InsertTime2(TwoThreeBSTSet, SyntheticDataList[i])
    RBTSyn.append(RBT)
    InsertRes4.append(res4)
    print("Bloom Filter: ")
    BT, res5 = InsertTime2(BloomFilterSet, SyntheticDataList[i])
    BTSyn.append(BT)
    InsertRes5.append(res5)
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# Out:
# For Normal Case:
# Sequential Search:
# Insert time taken is : 0.03571070000180043
# Binary Search Tree:
# Insert time taken is : 0.8878659999973024
# Balanced Search Tree:
# Insert time taken is : 2.1460892999966745
# 2-3 Search Tree:
# Insert time taken is : 4.547680000003311
# Bloom Filter:
# Insert time taken is : 1.309740700002294
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# For Long String Case:
# Sequential Search:
# Insert time taken is : 0.026569900001049973
# Binary Search Tree:
# Insert time taken is : 0.8863971999962814
# Balanced Search Tree:
# Insert time taken is : 2.2188650999960373
# 2-3 Search Tree:
# Insert time taken is : 5.025363299995661
# Bloom Filter:
# Insert time taken is : 17.53902960000414
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# For Special String Case:
# Sequential Search:
# Insert time taken is : 0.02700880000338657
# Binary Search Tree:
# Insert time taken is : 1.0317727000001469
# Balanced Search Tree:
# Insert time taken is : 2.391821600002004
# 2-3 Search Tree:
# Insert time taken is : 3.830356699996628
# Bloom Filter:
# Insert time taken is : 1.6368333999998868
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# For Ascending Order Case:
# Sequential Search:
# Insert time taken is : 0.03271870000025956
# Binary Search Tree:

# %%
for l in range(len(SyntheticDataList)):
    print(InsertRes1[l][:20], InsertRes2[l][:20], InsertRes3[l][:20], InsertRes4[l][:20], InsertRes5[l][:20])
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True] [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]

# %% [markdown]
# ### Search Time Taken

# %%
def SearchTime2(obj, searchdata):
#     res = []
#     searched = obj.searchElement(searchdata[0])
#     res.append(searched)
    res = []
    SearchStart = timeit.default_timer()
    for ws in searchdata:
        if ws is not None:
            searched = obj.searchElement(ws)
        else:
            searched = None
        res.append(searched)
    SearchEnd = timeit.default_timer()
    SearchTime = SearchEnd - SearchStart
    print("Search time taken is :", SearchTime)
    return res

# %%
class SequentialSearchSet():
    
    def __init__(self):
        self.items = []           
        
    def insertElement(self, element):
        inserted = False
        self.items.append(element)
        inserted = True
        return inserted   

    def searchElement(self, element):
        found = False     
        for item1 in self.items:
            if item1 == element:
                found = True
                return found
        return found

# %%
SearchRes1, SearchRes2, SearchRes3, SearchRes4 = [], [], [], []
# len(synSearchList)
for i in range (1):
    print("For", SyntheticDataNames[i], "Case: ")
    print("Sequential Search: ")
    sres1 = SearchTime2(SEQSyn[i], synSearchList[i])
    SearchRes1.append(sres1)
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
#     print("Binary Search Tree: ")
#     BST, sres2 = SearchTime2(BSTSyn[i], synSearchList[i])
#     SearchRes2.append(sres2)
#     print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
#     print("Balanced Search Tree: ")
#     RBT, sres3 = SearchTime2(RBTSyn[i], synSearchList[i])
#     SearchRes3.append(sres3)
#     print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
    print("Bloom Filter: ")
    sres4 = SearchTime2(BTSyn[i], synSearchList[i])
    SearchRes4.append(sres4)
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
    print("                                                 ")
# Out:
# For Normal Case:
# Sequential Search:
# Search time taken is : 108.61616439999489
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Bloom Filter:
# Search time taken is : 0.5147987000018475
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
print(SearchRes1[0][:20], SearchRes4[0][:20])
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True] [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]

# %% [markdown]
# # --------

# %%
# missing value checker

def isNone(list):
    i = 0
    lst_iter = iter(list)
    while True:
        element = next(lst_iter,"end")
        if element == "end":
            break
        if element is None:
            i += 1
    print("The file contains %d None values" % i)

testList = [1,2,3,None,4,5,6,7,8,9,None]

isNone(words1)
isNone(words2)
isNone(words3)
isNone(testList)
# Out:
# The file contains 0 None values
# The file contains 0 None values
# The file contains 0 None values
# The file contains 2 None values

# %%
rbt = BalancedSearchTreeSet()
rbt.insertElement('b')
rbt.insertElement('a')
rbt.insertElement('c')

print(rbt.searchElement('b'))
print(rbt.searchElement('a'))
print(rbt.searchElement('c'))
# Out:
# True
# True
# True

# %% [markdown]
# Sequential Search

# %%
# for key in files.keys():
#     seqInsertStart = timeit.default_timer()
#     for word in files[key]:
#         SEQs.insertElement(word)
#     seqInsertEnd = timeit.default_timer()
#     seqInsertTime = seqInsertEnd - seqInsertStart
#     print("Insert time taken for ", key, "is : ", seqInsertTime)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27260\2375292265.py in <module>
#       2     seqInsertStart = timeit.default_timer()
#       3     for word in files[key]:
# ----> 4         SEQs.insertElement(word)
#       5     seqInsertEnd = timeit.default_timer()
#       6     seqInsertTime = seqInsertEnd - seqInsertStart
#
# AttributeError: 'list' object has no attribute 'insertElement'

# %% [markdown]
# Sequential Search

# %%
SeqSearchStart = timeit.default_timer()
for ws in wordsforsearch:
    SEQs.searchElement(ws)
SeqSearchEnd = timeit.default_timer()
SeqSearchTime = SeqSearchEnd - SeqSearchStart
print("Search time taken for 'test-search.txt' is : ", SeqSearchTime)

# %% [markdown]
# Binary Search Tree

# %%
for key in files.keys():
    binaryInsertStart = timeit.default_timer()
    for word in files[key]:
        BSTs.insertElement(word)
    binaryInsertEnd = timeit.default_timer()
    
    binaryInsertTime = binaryInsertEnd - binaryInsertStart
    print("Insert time taken for ", key, "is : ", binaryInsertTime)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27260\3371357167.py in <module>
#       2     binaryInsertStart = timeit.default_timer()
#       3     for word in files[key]:
# ----> 4         BSTs.insertElement(word)
#       5     binaryInsertEnd = timeit.default_timer()
#       6     binaryInsertTime = binaryInsertEnd - binaryInsertStart
#
# AttributeError: 'list' object has no attribute 'insertElement'

# %% [markdown]
# Binary Search Tree

# %%
BinarySearchStart = timeit.default_timer()
for ws in wordsforsearch:
    BSTs.searchElement(ws)
BinarySearchEnd = timeit.default_timer()
BinarySearchTime = BinarySearchEnd - BinarySearchStart
print("Search time taken for 'test-search.txt' is : ", BinarySearchTime)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27260\1165406966.py in <module>
#       1 BinarySearchStart = timeit.default_timer()
#       2 for ws in wordsforsearch:
# ----> 3     BSTs.searchElement(ws)
#       4 BinarySearchEnd = timeit.default_timer()
#       5 BinarySearchTime = BinarySearchEnd - BinarySearchStart
#
# AttributeError: 'list' object has no attribute 'searchElement'

# %% [markdown]
# Balanced Search Tree

# %%
for key in files.keys():
    RedBlackInsertStart = timeit.default_timer()
    for word in files[key]:
        RBT.insertElement(word)
    RedBlackInsertEnd = timeit.default_timer()
    RedBlackInsertTime = RedBlackInsertEnd - RedBlackInsertStart
    print("Insert time taken for ", key, "is : ", RedBlackInsertTime)
# Out:
# Insert time taken for  'test1-mobydick.txt' is :  2.1321972999994614
# Insert time taken for  'test2-warpeace.txt' is :  6.030556100000467
# Insert time taken for  'test-search.txt' is :  60.04795980000017

# %% [markdown]
# Balanced Search Tree

# %%
RedBlackSearchStart = timeit.default_timer()
for ws in wordsforsearch:
    RBT.searchElement(ws)
RedBlackSearchEnd = timeit.default_timer()
RedBlackSearchTime = RedBlackSearchEnd - RedBlackSearchStart
print("Search time taken for 'test-search.txt' is : ", RedBlackSearchTime)
# Out:
# Search time taken for 'test-search.txt' is :  0.0031930999994074227

# %% [markdown]
# Bloom Filter

# %%
for key in files.keys():
    BFInsertStart = timeit.default_timer()
    for word in files[key]:
        BF.insertElement(word)
    BFInsertEnd = timeit.default_timer()
    BFInsertTime = BFInsertEnd - BFInsertStart
    print("Insert time taken for ", key, "is : ", BFInsertTime)
# Out:
# Insert time taken for  'test1-mobydick.txt' is :  2.006846799999039
# Insert time taken for  'test2-warpeace.txt' is :  5.462229099999604
# Insert time taken for  'test3-dickens.txt' is :  49.96937220000109

# %% [markdown]
# Bloom Filter

# %%
BFSearchStart = timeit.default_timer()
for word in wordsforsearch:
    BF.searchElement(word)
BFSearchEnd = timeit.default_timer()
BFSearchTime = BFSearchEnd - BFSearchStart
print("Search time taken for 'test-search.txt' is : ", BFSearchTime)
# Out:
# Search time taken for 'test-search.txt' is :  0.005908900000576978

# %%
a = './data/testfiles/test1-mobydick.txt'
b = './data/testfiles/test2-warpeace.txt'
c = './data/testfiles/test3-dickens.txt'
insertFiles = [a,b,c]

for file in insertFiles:
    seqInsertStart = timeit.default_timer()
    seqS.insertElement(file)
    seqInsertEnd = timeit.default_timer()
    seqInsertTime = seqInsertEnd - seqInsertStart
    print(seqInsertTime)

# %%
a = './data/testfiles/test1-mobydick.txt'
b = './data/testfiles/test2-warpeace.txt'
c = './data/testfiles/test3-dickens.txt'
d = "./data/testfiles/test-search.txt"
insertFiles = [a,b,c]
for file in insertFiles:
    seqS.insertElement(file)
    SeqSearchStart = timeit.default_timer()
    seqS.searchElement(d)
    SeqSearchEnd = timeit.default_timer()
    SeqSearchTime = SeqSearchEnd - SeqSearchStart
    print(SeqSearchTime)
# Out:
# False ,['zero'] is not found
# 94.96285220000027
# False ,['zero'] is not found
# 106.49899989999994
# False ,['zero'] is not found
# 183.5646872999996

# %%
a = './data/testfiles/test1-mobydick.txt'
b = './data/testfiles/test2-warpeace.txt'
c = './data/testfiles/test3-dickens.txt'
insertFiles = [a,b,c]

for file in insertFiles:
    BSTInsertStart = timeit.default_timer()
    rbt.insertElement(file)
    BSTInsertEnd = timeit.default_timer()
    BSTInsertTime = BSTInsertEnd - BSTInsertStart
    print(BSTInsertTime)
# Out:
# 1.3200000012147939e-05
# 1.6899999991437653e-05
# 4.79999994240643e-06

# %%
def insert_file():
    a = './data/testfiles/test1-mobydick.txt'
    b = './data/testfiles/test2-warpeace.txt'
    c = './data/testfiles/test3-dickens.txt'
    insertFiles = [a,b,c]
    for file in insertFiles:
        BSTInsertStart = timeit.default_timer()
        bst.insertElement(file)
        BSTInsertEnd = timeit.default_timer()
        BSTInsertTime = BSTInsertEnd - BSTInsertStart
        print(BSTInsertTime)

def insert_real_data_test(words, bst):
    BSTInsertStart = timeit.default_timer() 
    for word in words:
        bst.insertElement(word)
    BSTInsertEnd = timeit.default_timer()
    BSTInsertTime = BSTInsertEnd - BSTInsertStart
    print("Insert time: ", BSTInsertTime)

def search_words_in_set(words, bst):
    BSTSearchStart = timeit.default_timer() 
    for word in words:
        bst.searchElement(word)
    BSTSearchEnd = timeit.default_timer()
    BSTSearchTime = BSTSearchEnd - BSTSearchStart
    print("Search time (word already in set): ", BSTSearchTime)


def search_words(words, bst):
    BSTSearchStart = timeit.default_timer() 
    for word in words:
        bst.searchElement(word)
    BSTSearchEnd = timeit.default_timer()
    BSTSearchTime = BSTSearchEnd - BSTSearchStart
    print("Search time (test-search words): ", BSTSearchTime)


bst1 = BinarySearchTreeSet()
bst2 = BinarySearchTreeSet()
bst3 = BinarySearchTreeSet()

insert_real_data_test(words, bst1)
insert_real_data_test(words2, bst2)
insert_real_data_test(words3, bst3)

search_words_in_set(words, bst1)
search_words_in_set(words2, bst2)
search_words_in_set(words3, bst3)

search_words(words, bst1)
search_words(words2, bst2)
search_words(words3, bst3)

# %%
a = './data/testfiles/test1-mobydick.txt'
b = './data/testfiles/test2-warpeace.txt'
c = './data/testfiles/test3-dickens.txt'
d = "./data/testfiles/test-search.txt"
insertFiles = [a,b,c]

for file in insertFiles:
    rbt.insertElement(file)
    BSTSearchStart = timeit.default_timer()
    rbt.searchElement(d)
    BSTSearchEnd = timeit.default_timer()
    BSTSearchTime = BSTSearchEnd - BSTSearchStart
    print(BSTSearchTime)
# Out:
# 2.4000000848900527e-06
# 8.000001798791345e-07
# 7.000003279244993e-07

# %%
# 1st version

class TestDataGenerator():

    def __init__(self):
            self.syntheticData = []
            
            pass           
            
    # sythetic data -- integers:
    def generateNum(self, size):
        for _ in range(size):
            item = random.randrange(0,1000000)
            self.syntheticData.append(item)
        print(self.syntheticData) # delete when it's finished
        return self.syntheticData   
    
    # sythetic data -- 4-letter string (randomly without real meanings):
    def generateString(self,size):
        letters = string.ascii_lowercase
        for letter in letters:
            for _ in range(size):
                letter1 = ''.join(random.choice(letters))
                letter2 = ''.join(random.choice(letters))
                letter3 = ''.join(random.choice(letters))
                stringGenerated = letter + letter1 + letter2 + letter3
                self.syntheticData.append(stringGenerated)
        print(self.syntheticData) # delete when it's finished
        return self.syntheticData

toGenerate = TestDataGenerator()
toSearch = TestDataGenerator()

toGenerate.generateString(1)
toSearch.generateNum(10)
# Out:
# ['aiet', 'bbrr', 'csgv', 'dmux', 'ezat', 'fxew', 'gfhm', 'hyjd', 'iaby', 'jwzk', 'kshf', 'lwrx', 'mdrk', 'nbfd', 'ogxs', 'pgyh', 'qyvb', 'rxeo', 'sjff', 'tosj', 'ukjl', 'vhgj', 'wlgn', 'xtyg', 'yvhy', 'zchc']
# [634667, 496119, 767303, 410927, 353639, 23654, 399978, 520985, 373862, 726654]
# [634667, 496119, 767303, 410927, 353639, 23654, 399978, 520985, 373862, 726654]
